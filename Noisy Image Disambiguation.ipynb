# %%
import torch as torch
import torchvision as tv
import torch.nn.functional as F
from torchvision import datasets
from torchvision import transforms
import matplotlib.pyplot as plt
import matplotlib.image as image
import cv2 as cv
from PIL import Image
import numpy as np
from torchvision.datasets.vision import VisionDataset
from typing import Any, Callable, Dict, List, Optional, Tuple
import os
import os.path
from torch import nn
from torchvision.datasets.mnist import read_image_file, read_label_file
from torchvision.datasets.utils import download_and_extract_archive, extract_archive, verify_str_arg, check_integrity
from skimage.util import random_noise

# %%
class MNISTsuperimposed(VisionDataset):
    """`MNIST <http://yann.lecun.com/exdb/mnist/>`_ Dataset.

    Args:
        root (string): Root directory of dataset where ``MNIST/processed/training.pt``
            and  ``MNIST/processed/test.pt`` exist.
        train (bool, optional): If True, creates dataset from ``training.pt``,
            otherwise from ``test.pt``.
        download (bool, optional): If true, downloads the dataset from the internet and
            puts it in root directory. If dataset is already downloaded, it is not
            downloaded again.
        transform (callable, optional): A function/transform that  takes in an PIL image
            and returns a transformed version. E.g, ``transforms.RandomCrop``
        target_transform (callable, optional): A function/transform that takes in the
            target and transforms it.
    """

    mirrors = [
        'http://yann.lecun.com/exdb/mnist/',
        'https://ossci-datasets.s3.amazonaws.com/mnist/',
    ]

    resources = [
        ("train-images-idx3-ubyte.gz", "f68b3c2dcbeaaa9fbdd348bbdeb94873"),
        ("train-labels-idx1-ubyte.gz", "d53e105ee54ea40749a09fcbcd1e9432"),
        ("t10k-images-idx3-ubyte.gz", "9fb629c4189551a2d022fa330f9573f3"),
        ("t10k-labels-idx1-ubyte.gz", "ec29112dd5afa0611ce80d1b7f02629c")
    ]

    training_file = 'training.pt'
    test_file = 'test.pt'
    classes = ['0 - zero', '1 - one', '2 - two', '3 - three', '4 - four',
               '5 - five', '6 - six', '7 - seven', '8 - eight', '9 - nine']

    @property
    def train_labels(self):
        warnings.warn("train_labels has been renamed targets")
        return self.targets

    @property
    def test_labels(self):
        warnings.warn("test_labels has been renamed targets")
        return self.targets

    @property
    def train_data(self):
        warnings.warn("train_data has been renamed data")
        return self.data

    @property
    def test_data(self):
        warnings.warn("test_data has been renamed data")
        return self.data

    def __init__(
            self,
            root,
            train= True,
            transform = None,
            target_transform = None,
            download = False,
    ):
        super(MNISTsuperimposed, self).__init__(root, transform=transform,
                                    target_transform=target_transform)
        self.train = train  # training set or test set

        if self._check_legacy_exist():
            self.data, self.targets = self._load_legacy_data()

        if download:
            self.download()

        if not self._check_exists():
            raise RuntimeError('Dataset not found.' +
                               ' You can use download=True to download it')

        self.data, self.targets = self._load_data()

    def _check_legacy_exist(self):
        processed_folder_exists = os.path.exists(self.processed_folder)
        if not processed_folder_exists:
            return False

        return all(
            check_integrity(os.path.join(self.processed_folder, file)) for file in (self.training_file, self.test_file)
        )

    def _load_legacy_data(self):
        # This is for BC only. We no longer cache the data in a custom binary, but simply read from the raw data
        # directly.
        data_file = self.training_file if self.train else self.test_file
        return torch.load(os.path.join(self.processed_folder, data_file))

    def _load_data(self):
        image_file = f"{'train' if self.train else 't10k'}-images-idx3-ubyte"
        data = read_image_file(os.path.join(self.raw_folder, image_file))
        #Technically, we do not even need the labels for now
        # We just need the clean images of both types
        randata = data[torch.randperm(data.shape[0]),:,:]
        targets = (data, randata)
        
        
        # Now do the ambiguation here
        data = data + randata
        return data, targets

    def __getitem__(self, index):
        """
        Args:
            index (int): Index

        Returns:
            tuple: (image, target) where target is index of the target class.
        """
        img, target = self.data[index], (self.targets[0][index], self.targets[1][index])
        # doing this so that it is consistent with all other datasets
        # to return a PIL Imagedata[torch.randperm(data.shape[0]),:,:]
        img = Image.fromarray(img.numpy(), mode='L')
        tgt1 = Image.fromarray(target[0].numpy(), mode='L')
        tgt2 = Image.fromarray(target[1].numpy(), mode='L')

        if self.transform is not None:
            img = self.transform(img)

        if self.target_transform is not None:
            tgt1 = self.target_transform(tgt1)
            tgt2 = self.target_transform(tgt2)
            

        return img, (tgt1, tgt2)

    def __len__(self):
        return len(self.data)

    @property
    def raw_folder(self):
        return os.path.join(self.root, self.__class__.__name__, 'raw')

    @property
    def processed_folder(self) -> str:
        return os.path.join(self.root, self.__class__.__name__, 'processed')

    @property
    def class_to_idx(self):
        return {_class: i for i, _class in enumerate(self.classes)}

    def _check_exists(self):
        return all(
            check_integrity(os.path.join(self.raw_folder, os.path.splitext(os.path.basename(url))[0]))
            for url, _ in self.resources
        )

    def download(self):
        """Download the MNIST data if it doesn't exist already."""

        if self._check_exists():
            return

        os.makedirs(self.raw_folder, exist_ok=True)

        # download files
        for filename, md5 in self.resources:
            for mirror in self.mirrors:
                url = "{}{}".format(mirror, filename)
                try:
                    print("Downloading {}".format(url))
                    download_and_extract_archive(
                        url, download_root=self.raw_folder,
                        filename=filename,
                        md5=md5
                    )
                except URLError as error:
                    print(
                        "Failed to download (trying next):\n{}".format(error)
                    )
                    continue
                finally:
                    print()
                break
            else:
                raise RuntimeError("Error downloading {}".format(filename))

    def extra_repr(self) -> str:
        return "Split: {}".format("Train" if self.train is True else "Test")

# %%
class Downsample(object):
    def __init__(self, size=[1,196]):
        self.size=size

    def __call__(self, tensor):
        img = np.squeeze(tensor)
        m = torch.nn.AvgPool2d(2, stride=2)
        return m(img.unsqueeze(0))

    def __repr__(self):
        return self.__class__.__name__+'({})'.format(self.size)

# %%
class AddGaussNoise(object):
    def __init__(self, mean=0, std=0.001):
        self.std=std
        self.mean=mean
        
    def __call__(self, tensor):
#         print(tensor + torch.randn(tensor.size()) * self.std + self.mean)
        return torch.tensor(random_noise(tensor,mean=self.mean,var=self.std))

    def __repr__(self):
        return self.__class__.__name__+'(mean={0},std={1})'.format(self.mean, self.std)

# %%
transform = transforms.Compose(
    [transforms.Grayscale(),
     transforms.ToTensor(),
     Downsample(),
     AddGaussNoise(0,1e-2)
     ])

target_transform =transforms.Compose(
    [transforms.Grayscale(),
     transforms.ToTensor()     
    ]) 
mnist_superimposed = MNISTsuperimposed("./MNIST data/train", train = True, download = True, transform = transform, target_transform=target_transform)
# Out:
# /opt/conda/lib/python3.8/site-packages/torchvision/datasets/mnist.py:480: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  ../torch/csrc/utils/tensor_numpy.cpp:137.)
#   return torch.from_numpy(parsed.astype(m[2], copy=False)).view(*s)

# %%
from torch.utils.data import DataLoader
batch = 64
trainset = DataLoader(mnist_superimposed, batch_size=batch, shuffle = True)

# %%
def show_images(dataset, training = True):
    
    fig = plt.figure(figsize = (20, 14))
    rows = 3
    columns = 4
    j=0
    for i in range(1,columns*rows+1):
        if i >=1 and i< 5:
            fig.add_subplot(rows, columns, i)
            plt.imshow(dataset[i][0].squeeze(0))
        if i >=5 and i < 9:
            fig.add_subplot(rows, columns, i)
            plt.imshow(dataset[i-4][1][0].squeeze(0))
        if i >= 9 and i<13:
            fig.add_subplot(rows, columns, i)
            plt.imshow(dataset[i-8][1][1].squeeze(0))

# %%
show_images(mnist_superimposed)

# %%
import torch
from torch import nn as nn
from torch.nn import Conv2d, ConvTranspose2d, Linear, Sequential, Flatten, ReLU, LeakyReLU, AvgPool2d, MaxPool2d,Dropout

# %%
class AE(nn.Module):
    def __init__(self, inplace = False):
        super(AE,self).__init__()
        
        self.Upsample_1 = nn.Sequential(
            nn.Flatten(start_dim = 2),
            nn.Linear(196, 256),
            nn.Linear(256, 256),
            nn.ReLU(inplace),
            
            nn.Linear(256, 512),
            nn.Linear(512, 784),
            nn.Linear(784, 784),
            nn.ReLU(inplace),
        )
        
            
        self.initial_Processing = nn.Sequential(
            nn.Conv2d(in_channels = 1, out_channels = 8, kernel_size = 3, padding = 1, stride = 1),
            nn.BatchNorm2d(8),
            nn.ReLU(inplace),
            nn.Conv2d(in_channels = 8, out_channels = 64, kernel_size = 3, padding =1, stride = 1),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace),
        )

        self.Down_1 = nn.Sequential(
            nn.Conv2d(in_channels = 64, out_channels = 1024, kernel_size = (3, 3), padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.Conv2d(in_channels = 1024, out_channels = 1024, kernel_size = (3, 3), padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.MaxPool2d(kernel_size = (2, 2)),
        )

        self.Down_2 = nn.Sequential(
            nn.Conv2d(in_channels = 1024, out_channels = 512, kernel_size = (3, 3), padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.Conv2d(in_channels = 512, out_channels = 512, kernel_size = (3, 3), padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.MaxPool2d(kernel_size = (2, 2)),
        )


        self.Down_3 = nn.Sequential(
            nn.Conv2d(in_channels = 512, out_channels = 256, kernel_size = (3, 3), padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.Conv2d(in_channels = 256, out_channels = 256, kernel_size = (3, 3), padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.MaxPool2d(kernel_size = (2, 2)),
        )

        self.Down_4 = nn.Sequential(
            nn.Conv2d(in_channels = 256, out_channels = 128, kernel_size = (3, 3), padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.Conv2d(in_channels = 128, out_channels = 128, kernel_size = (3, 3), padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.MaxPool2d(kernel_size = (2, 2)),
        )

        self.Up_1 = nn.Sequential(
            nn.Conv2d(in_channels = 128, out_channels = 64, kernel_size = (3, 3), padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.Conv2d(in_channels = 64, out_channels = 128, kernel_size = (3, 3), padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.ConvTranspose2d(in_channels = 128, out_channels = 128, kernel_size = (2, 2))
        )

        self.Up_2 = nn.Sequential(
            nn.Conv2d(in_channels = 256, out_channels = 128, kernel_size = (3, 3), padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.Conv2d(in_channels = 128, out_channels = 256, kernel_size = (3, 3), padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.ConvTranspose2d(in_channels = 256, out_channels = 256, kernel_size = (2, 2))
        )

        self.Up_3 = nn.Sequential(
            nn.Conv2d(in_channels = 512, out_channels = 256, kernel_size = (3, 3), padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.Conv2d(in_channels = 256, out_channels = 512, kernel_size = (3, 3), padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.ConvTranspose2d(in_channels = 512, out_channels = 512, kernel_size = (2, 2))
        )

        self.Up_4 = nn.Sequential(
            nn.Conv2d(in_channels = 1024, out_channels = 512, kernel_size = (3, 3), padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.Conv2d(in_channels = 512, out_channels = 1024, kernel_size = (3, 3), padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.ConvTranspose2d(in_channels = 1024, out_channels = 1024, kernel_size = (2, 2))
        )

        self.Up_5 = nn.Sequential(
            nn.Conv2d(in_channels = 2048, out_channels = 1024, kernel_size = (3, 3), padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.Conv2d(in_channels = 1024, out_channels = 1024, kernel_size = (3, 3), padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.ConvTranspose2d(in_channels = 1024, out_channels = 2, kernel_size = (1, 1))
        )
        
        self.Upsample_2 = nn.Sequential(
            nn.Flatten(start_dim = 1),
            nn.Linear(392, 512),
            nn.Linear(512, 512),
            nn.ReLU(inplace),
            
            nn.Linear(512, 1024),
            nn.Linear(1024, 1568),
            nn.Linear(1568, 1568),
            nn.Sigmoid(),
        )
        
    def forward(self, x):
        
        output = self.Upsample_1(x)
        output = output.reshape(output.shape[0], 1, 28, 28)
        
        output = self.initial_Processing(output)
        
        output = self.Down_1(output)
        output_1 = output
        
        
        output = self.Down_2(output)
        output_2 = output
        
        output = self.Down_3(output)
        output_3 = output
        
        output = self.Down_4(output)
        output_4 = output
        
        
        output = self.Up_1(output)
        diffY = output_4.size()[2] - output.size()[2]
        diffX = output_4.size()[3] - output.size()[3]
        output = F.pad(output, [diffX // 2, diffX - diffX // 2,
                        diffY // 2, diffY - diffY // 2])
        output = torch.cat([output_4, output], dim=1)
        

        output = self.Up_2(output)
        diffY = output_3.size()[2] - output.size()[2]
        diffX = output_3.size()[3] - output.size()[3]
        output = F.pad(output, [diffX // 2, diffX - diffX // 2,
                        diffY // 2, diffY - diffY // 2])
        output = torch.cat([output_3, output], dim=1)


        output = self.Up_3(output)        
        diffY = output_2.size()[2] - output.size()[2]
        diffX = output_2.size()[3] - output.size()[3]
        output = F.pad(output, [diffX // 2, diffX - diffX // 2,
                        diffY // 2, diffY - diffY // 2])
        output = torch.cat([output_2, output], dim=1)


        output = self.Up_4(output)
        diffY = output_1.size()[2] - output.size()[2]
        diffX = output_1.size()[3] - output.size()[3]
        output = F.pad(output, [diffX // 2, diffX - diffX // 2,
                        diffY // 2, diffY - diffY // 2])
        output = torch.cat([output_1, output], dim=1)


        output = self.Up_5(output)

        
        output = self.Upsample_2(output)        
        return output

# %%
device = torch.device('cuda') if torch.cuda.is_available else torch.device('cpu')
AEnet = AE(inplace = True).cuda()

# %%
optimizer = torch.optim.Adam(AEnet.parameters(), lr=0.000005)
criterion = nn.MSELoss()
print(device)
# Out:
# cuda

# %%
def train_test(AEnet, dataset, Training = True):

    if Training:
        epochs = 40
        train_loss = []
        flag = True
        for epoch in range(epochs):
            running_loss = 0.0
            for i, data in enumerate(dataset):
                optimizer.zero_grad()
                outputs = AEnet(data[0].float().to(device))
                output_1 = outputs[:, :784]
                output_2 = outputs[:, 784:]
                loss = criterion(output_1.float().to(device), torch.flatten(data[1][0],1).float().to(device)) + criterion(output_2.float().to(device), torch.flatten(data[1][1],1).float().to(device))
                loss.backward()
                optimizer.step()
                train_loss.append(loss.item())
                running_loss += loss.item()
                if i % 100 == 99:
                    print('[%d, %5d] loss per image: %.6f' %
                          (epoch + 1, i + 1, loss.item()/32))
                    if epoch % 10 == 9:
                        torch.save(AEnet.state_dict(), "./weights.pth")
                
            

            
        print("The lowest was: ", min(train_loss)/32)

        print('Finished Training')
        flag = False
        return outputs, data
            
    else:
        testing_loss = []
        for i, data in enumerate(dataset):
                optimizer.zero_grad()
                outputs = AEnet(data[0].float().to(device))
                output_1 = outputs[:, :784]
                output_2 = outputs[:, 784:]
                loss = criterion(output_1.float().to(device), torch.flatten(data[1][0],1).float().to(device)) + criterion(output_2.float().to(device), torch.flatten(data[1][1],1).float().to(device))
                testing_loss.append(loss.item())
                if i % 50 == 49:
                    print('[%5d] loss per image: %.6f' %
                          (i + 1, loss.item()/32))
                    
        print("The lowest was: ", min(testing_loss)/32)
        print('Finished Testing')
        return outputs, data

# %%
output, data= train_test(AEnet, trainset)
# Out:
# [1,   100] loss per image: 0.004448
# [1,   200] loss per image: 0.004278
# [1,   300] loss per image: 0.004096
# [1,   400] loss per image: 0.003848
# [1,   500] loss per image: 0.004029
# [1,   600] loss per image: 0.003984
# [1,   700] loss per image: 0.003975
# [1,   800] loss per image: 0.003709
# [1,   900] loss per image: 0.003681
# [2,   100] loss per image: 0.003786
# [2,   200] loss per image: 0.003639
# [2,   300] loss per image: 0.003437
# [2,   400] loss per image: 0.003505
# [2,   500] loss per image: 0.003555
# [2,   600] loss per image: 0.003411
# [2,   700] loss per image: 0.003411
# [2,   800] loss per image: 0.003596
# [2,   900] loss per image: 0.003339
# [3,   100] loss per image: 0.003416
# [3,   200] loss per image: 0.003287
# [3,   300] loss per image: 0.003395
# [3,   400] loss per image: 0.003384
# [3,   500] loss per image: 0.003299
# [3,   600] loss per image: 0.003269
# [3,   700] loss per image: 0.003418
# [3,   800] loss per image: 0.003106
# [3,   900] loss per image: 0.003230
# [4,   100] loss per image: 0.003162
# [4,   200] loss per image: 0.003356
# [4,   300] loss per image: 0.003382
# [4,   400] loss per image: 0.003182
# [4,   500] loss per image: 0.003206
# [4,   600] loss per image: 0.003370
# [4,   700] loss per image: 0.003215
# [4,   800] loss per image: 0.003370
# [4,   900] loss per image: 0.003061
# [5,   100] loss per image: 0.003152
# [5,   200] loss per image: 0.003124
# [5,   300] loss per image: 0.003079
# [5,   400] loss per image: 0.003139
# [5,   500] loss per image: 0.003307
# [5,   600] loss per image: 0.003177
# [5,   700] loss per image: 0.003268
# [5,   800] loss per image: 0.003173
# [5,   900] loss per image: 0.003103
# [6,   100] loss per image: 0.003074
# [6,   200] loss per image: 0.003123
# [6,   300] loss per image: 0.003195
# [6,   400] loss per image: 0.003137
# [6,   500] loss per image: 0.003182
# [6,   600] loss per image: 0.003106
# [6,   700] loss per image: 0.003137
# [6,   800] loss per image: 0.002945
# [6,   900] loss per image: 0.003070
# [7,   100] loss per image: 0.003008
# [7,   200] loss per image: 0.003112
# [7,   300] loss per image: 0.003024
# [7,   400] loss per image: 0.003168
# [7,   500] loss per image: 0.003038
# [7,   600] loss per image: 0.003068
# [7,   700] loss per image: 0.002860
# [7,   800] loss per image: 0.003108
# [7,   900] loss per image: 0.003009
# [8,   100] loss per image: 0.002929
# [8,   200] loss per image: 0.003174
# [8,   300] loss per image: 0.002966
# [8,   400] loss per image: 0.002925
# [8,   500] loss per image: 0.003189
# [8,   600] loss per image: 0.003035
# [8,   700] loss per image: 0.003199
# [8,   800] loss per image: 0.003153
# [8,   900] loss per image: 0.003102
# [9,   100] loss per image: 0.003115
# [9,   200] loss per image: 0.003090
# [9,   300] loss per image: 0.002881
# [9,   400] loss per image: 0.003163
# [9,   500] loss per image: 0.003157
# [9,   600] loss per image: 0.003029
# [9,   700] loss per image: 0.003107
# [9,   800] loss per image: 0.003050
# [9,   900] loss per image: 0.003066
# [10,   100] loss per image: 0.002988
# [10,   200] loss per image: 0.003091
# [10,   300] loss per image: 0.003115
# [10,   400] loss per image: 0.002996
# [10,   500] loss per image: 0.002969
# [10,   600] loss per image: 0.003102
# [10,   700] loss per image: 0.003023
# [10,   800] loss per image: 0.003145
# [10,   900] loss per image: 0.002970
# [11,   100] loss per image: 0.002982
# [11,   200] loss per image: 0.003002
# [11,   300] loss per image: 0.003025
# [11,   400] loss per image: 0.002812
# [11,   500] loss per image: 0.002962
# [11,   600] loss per image: 0.002907
# [11,   700] loss per image: 0.002873
# [11,   800] loss per image: 0.003030
# [11,   900] loss per image: 0.002934
# [12,   100] loss per image: 0.003017
# [12,   200] loss per image: 0.002952
# [12,   300] loss per image: 0.002917
# [12,   400] loss per image: 0.002916
# [12,   500] loss per image: 0.002990
# [12,   600] loss per image: 0.002930
# [12,   700] loss per image: 0.002807
# [12,   800] loss per image: 0.002792
# [12,   900] loss per image: 0.002865
# [13,   100] loss per image: 0.003078
# [13,   200] loss per image: 0.002965
# [13,   300] loss per image: 0.002922
# [13,   400] loss per image: 0.002948
# [13,   500] loss per image: 0.002984
# [13,   600] loss per image: 0.003020
# [13,   700] loss per image: 0.002963
# [13,   800] loss per image: 0.003068
# [13,   900] loss per image: 0.002926
# [14,   100] loss per image: 0.003052
# [14,   200] loss per image: 0.002939
# [14,   300] loss per image: 0.002920
# [14,   400] loss per image: 0.002982
# [14,   500] loss per image: 0.002950
# [14,   600] loss per image: 0.002998
# [14,   700] loss per image: 0.003019
# [14,   800] loss per image: 0.002963
# [14,   900] loss per image: 0.002843
# [15,   100] loss per image: 0.002952
# [15,   200] loss per image: 0.003015
# [15,   300] loss per image: 0.002978
# [15,   400] loss per image: 0.002803
# [15,   500] loss per image: 0.002970
# [15,   600] loss per image: 0.002991
# [15,   700] loss per image: 0.002923
# [15,   800] loss per image: 0.002856
# [15,   900] loss per image: 0.002779
# [16,   100] loss per image: 0.002999
# [16,   200] loss per image: 0.002816
# [16,   300] loss per image: 0.002873
# [16,   400] loss per image: 0.002890
# [16,   500] loss per image: 0.002778
# [16,   600] loss per image: 0.002873
# [16,   700] loss per image: 0.002789
# [16,   800] loss per image: 0.003040
# [16,   900] loss per image: 0.002999
# [17,   100] loss per image: 0.002860
# [17,   200] loss per image: 0.002896
# [17,   300] loss per image: 0.002777
# [17,   400] loss per image: 0.002935
# [17,   500] loss per image: 0.002779
# [17,   600] loss per image: 0.002890
# [17,   700] loss per image: 0.002888
# [17,   800] loss per image: 0.003008
# [17,   900] loss per image: 0.002972
# [18,   100] loss per image: 0.002882
# [18,   200] loss per image: 0.002828
# [18,   300] loss per image: 0.002837
# [18,   400] loss per image: 0.002791
# [18,   500] loss per image: 0.002880
# [18,   600] loss per image: 0.002796
# [18,   700] loss per image: 0.002925
# [18,   800] loss per image: 0.002817
# [18,   900] loss per image: 0.002867
# [19,   100] loss per image: 0.002972
# [19,   200] loss per image: 0.002906
# [19,   300] loss per image: 0.002924
# [19,   400] loss per image: 0.002898
# [19,   500] loss per image: 0.002869
# [19,   600] loss per image: 0.002900
# [19,   700] loss per image: 0.002887
# [19,   800] loss per image: 0.002867
# [19,   900] loss per image: 0.003094
# [20,   100] loss per image: 0.002879
# [20,   200] loss per image: 0.002823
# [20,   300] loss per image: 0.002944
# [20,   400] loss per image: 0.002928
# [20,   500] loss per image: 0.002777
# [20,   600] loss per image: 0.002993
# [20,   700] loss per image: 0.002773
# [20,   800] loss per image: 0.002797
# [20,   900] loss per image: 0.002639
# [21,   100] loss per image: 0.002794
# [21,   200] loss per image: 0.002774
# [21,   300] loss per image: 0.002863
# [21,   400] loss per image: 0.002765
# [21,   500] loss per image: 0.002752
# [21,   600] loss per image: 0.002701
# [21,   700] loss per image: 0.002761
# [21,   800] loss per image: 0.002837
# [21,   900] loss per image: 0.002939
# [22,   100] loss per image: 0.002938
# [22,   200] loss per image: 0.002750
# [22,   300] loss per image: 0.002739
# [22,   400] loss per image: 0.002800
# [22,   500] loss per image: 0.002891
# [22,   600] loss per image: 0.002824
# [22,   700] loss per image: 0.002768
# [22,   800] loss per image: 0.002900
# [22,   900] loss per image: 0.002919
# [23,   100] loss per image: 0.002918
# [23,   200] loss per image: 0.002837
# [23,   300] loss per image: 0.002893
# [23,   400] loss per image: 0.002807
# [23,   500] loss per image: 0.002785
# [23,   600] loss per image: 0.002858
# [23,   700] loss per image: 0.002886
# [23,   800] loss per image: 0.002887
# [23,   900] loss per image: 0.002844
# [24,   100] loss per image: 0.002845
# [24,   200] loss per image: 0.002828
# [24,   300] loss per image: 0.002714
# [24,   400] loss per image: 0.002848
# [24,   500] loss per image: 0.002733
# [24,   600] loss per image: 0.002934
# [24,   700] loss per image: 0.002762
# [24,   800] loss per image: 0.002809
# [24,   900] loss per image: 0.002754
# [25,   100] loss per image: 0.002831
# [25,   200] loss per image: 0.002839
# [25,   300] loss per image: 0.002767
# [25,   400] loss per image: 0.002756
# [25,   500] loss per image: 0.002953
# [25,   600] loss per image: 0.002881
# [25,   700] loss per image: 0.002768
# [25,   800] loss per image: 0.002810
# [25,   900] loss per image: 0.002763
# [26,   100] loss per image: 0.002893
# [26,   200] loss per image: 0.002891
# [26,   300] loss per image: 0.002854
# [26,   400] loss per image: 0.002817
# [26,   500] loss per image: 0.002823
# [26,   600] loss per image: 0.002857
# [26,   700] loss per image: 0.002822
# [26,   800] loss per image: 0.002741
# [26,   900] loss per image: 0.002702
# [27,   100] loss per image: 0.002696
# [27,   200] loss per image: 0.002829
# [27,   300] loss per image: 0.002766
# [27,   400] loss per image: 0.002814
# [27,   500] loss per image: 0.002742
# [27,   600] loss per image: 0.002562
# [27,   700] loss per image: 0.002924
# [27,   800] loss per image: 0.002815
# [27,   900] loss per image: 0.002750
# [28,   100] loss per image: 0.002774
# [28,   200] loss per image: 0.002628
# [28,   300] loss per image: 0.002838
# [28,   400] loss per image: 0.002792
# [28,   500] loss per image: 0.002726
# [28,   600] loss per image: 0.002863
# [28,   700] loss per image: 0.002871
# [28,   800] loss per image: 0.002672
# [28,   900] loss per image: 0.002847
# [29,   100] loss per image: 0.002718
# [29,   200] loss per image: 0.002788
# [29,   300] loss per image: 0.002759
# [29,   400] loss per image: 0.002881
# [29,   500] loss per image: 0.002787
# [29,   600] loss per image: 0.002785
# [29,   700] loss per image: 0.002778
# [29,   800] loss per image: 0.002804
# [29,   900] loss per image: 0.002895
# [30,   100] loss per image: 0.002799
# [30,   200] loss per image: 0.002851
# [30,   300] loss per image: 0.002776
# [30,   400] loss per image: 0.002773
# [30,   500] loss per image: 0.002612
# [30,   600] loss per image: 0.002907
# [30,   700] loss per image: 0.002685
# [30,   800] loss per image: 0.002626
# [30,   900] loss per image: 0.002806
# [31,   100] loss per image: 0.002709
# [31,   200] loss per image: 0.002709
# [31,   300] loss per image: 0.002810
# [31,   400] loss per image: 0.002573
# [31,   500] loss per image: 0.002841
# [31,   600] loss per image: 0.002820
# [31,   700] loss per image: 0.002677
# [31,   800] loss per image: 0.002931
# [31,   900] loss per image: 0.002795
# [32,   100] loss per image: 0.002646
# [32,   200] loss per image: 0.002645
# [32,   300] loss per image: 0.002819
# [32,   400] loss per image: 0.002758
# [32,   500] loss per image: 0.002725
# [32,   600] loss per image: 0.002663
# [32,   700] loss per image: 0.002696
# [32,   800] loss per image: 0.002842
# [32,   900] loss per image: 0.002625
# [33,   100] loss per image: 0.002853
# [33,   200] loss per image: 0.002892
# [33,   300] loss per image: 0.002831
# [33,   400] loss per image: 0.002786
# [33,   500] loss per image: 0.002882
# [33,   600] loss per image: 0.002745
# [33,   700] loss per image: 0.002626
# [33,   800] loss per image: 0.002686
# [33,   900] loss per image: 0.002681
# [34,   100] loss per image: 0.002672
# [34,   200] loss per image: 0.002658
# [34,   300] loss per image: 0.002661
# [34,   400] loss per image: 0.002767
# [34,   500] loss per image: 0.002701
# [34,   600] loss per image: 0.002652
# [34,   700] loss per image: 0.002732
# [34,   800] loss per image: 0.002827
# [34,   900] loss per image: 0.002561
# [35,   100] loss per image: 0.002701
# [35,   200] loss per image: 0.002832
# [35,   300] loss per image: 0.002691
# [35,   400] loss per image: 0.002839
# [35,   500] loss per image: 0.002681
# [35,   600] loss per image: 0.002713
# [35,   700] loss per image: 0.002991
# [35,   800] loss per image: 0.002797
# [35,   900] loss per image: 0.002654
# [36,   100] loss per image: 0.002591
# [36,   200] loss per image: 0.002818
# [36,   300] loss per image: 0.002880
# [36,   400] loss per image: 0.002690
# [36,   500] loss per image: 0.002700
# [36,   600] loss per image: 0.002707
# [36,   700] loss per image: 0.002717
# [36,   800] loss per image: 0.002632
# [36,   900] loss per image: 0.002613
# [37,   100] loss per image: 0.002606
# [37,   200] loss per image: 0.002740
# [37,   300] loss per image: 0.002652
# [37,   400] loss per image: 0.002632
# [37,   500] loss per image: 0.002553
# [37,   600] loss per image: 0.002763
# [37,   700] loss per image: 0.002720
# [37,   800] loss per image: 0.002739
# [37,   900] loss per image: 0.002707
# [38,   100] loss per image: 0.002757
# [38,   200] loss per image: 0.002810
# [38,   300] loss per image: 0.002693
# [38,   400] loss per image: 0.002673
# [38,   500] loss per image: 0.002678
# [38,   600] loss per image: 0.002734
# [38,   700] loss per image: 0.002645
# [38,   800] loss per image: 0.002873
# [38,   900] loss per image: 0.002672
# [39,   100] loss per image: 0.002633
# [39,   200] loss per image: 0.002679
# [39,   300] loss per image: 0.002627
# [39,   400] loss per image: 0.002757
# [39,   500] loss per image: 0.002573
# [39,   600] loss per image: 0.002817
# [39,   700] loss per image: 0.002653
# [39,   800] loss per image: 0.002720
# [39,   900] loss per image: 0.002749
# [40,   100] loss per image: 0.002627
# [40,   200] loss per image: 0.002677
# [40,   300] loss per image: 0.002640
# [40,   400] loss per image: 0.002737
# [40,   500] loss per image: 0.002634
# [40,   600] loss per image: 0.002760
# [40,   700] loss per image: 0.002498
# [40,   800] loss per image: 0.002653
# [40,   900] loss per image: 0.002659
# The lowest was:  0.002427800092846155
# Finished Training

# %%
#Print only the output images
def show_output_images(dataset, outputs, training = True):
    
    fig = plt.figure(figsize = (20, 14))
    rows = 5
    columns = 4
    j=0
    for i in range(1,columns*rows+1):
        if training:
            
            
            if i >=1 and i< 5:
                fig.add_subplot(rows, columns, i)
                plt.axis('off')
                plt.imshow(dataset[0][i].squeeze(0), cmap = 'gray')
            if i >=5 and i< 9:
                fig.add_subplot(rows, columns, i)
                plt.axis('off')
                plt.imshow(outputs[i-4][:784].cpu().detach().numpy().reshape(28,28), cmap='gray')
            if i >=9 and i < 13:
                fig.add_subplot(rows, columns, i)
                plt.axis('off')
                plt.imshow(outputs[i-8][784:].cpu().detach().numpy().reshape(28,28), cmap='gray')
            if i >=13 and i < 17:
                fig.add_subplot(rows, columns, i)
                plt.axis('off')
                plt.imshow(dataset[1][0][i-12].cpu().detach().numpy().reshape(28,28), cmap='gray')
            if i >=17 and i < 21:    
                fig.add_subplot(rows, columns, i)
                plt.axis('off')
                plt.imshow(dataset[1][1][i - 16].cpu().detach().numpy().reshape(28,28), cmap='gray')
        else:
            if i >=1 and i< 5:
                fig.add_subplot(rows, columns, i)
                plt.axis('off')
                plt.imshow(dataset[i][0].squeeze(0), cmap = 'gray')
            if i >=5 and i< 9:
                fig.add_subplot(rows, columns, i)
                plt.axis('off')
                plt.imshow(outputs[i-4][:784].cpu().detach().numpy().reshape(28,28), cmap='gray')
            if i >=9 and i < 13:
                fig.add_subplot(rows, columns, i)
                plt.axis('off')
                plt.imshow(outputs[i-8][784:].cpu().detach().numpy().reshape(28,28), cmap='gray')
            if i >=13 and i < 17:
                fig.add_subplot(rows, columns, i)
                plt.axis('off')
                plt.imshow(data[1][0][i-12].cpu().detach().numpy().reshape(28,28), cmap='gray')
            if i >=17 and i < 21:    
                fig.add_subplot(rows, columns, i)
                plt.axis('off')
                plt.imshow(data[1][1][i - 16].cpu().detach().numpy().reshape(28,28), cmap='gray')

# %%
show_output_images(data, output)

# %%
testing_superimposed = MNISTsuperimposed("./MNIST data/train", train = False, download = True, transform = transform, target_transform=target_transform)
testset = DataLoader(testing_superimposed, batch_size=128, shuffle = False)
outputs, test_data = train_test(AEnet, testset, False)
# Out:
# [   50] loss per image: 0.002936
# The lowest was:  0.002505631186068058
# Finished Testing

# %%
show_output_images(test_data, outputs, False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-4b376b6f0646> in <module>
# ----> 1 show_output_images(test_data, outputs, False)
#
# <ipython-input-15-231fc66f8585> in show_output_images(dataset, outputs, training)
#      34                 fig.add_subplot(rows, columns, i)
#      35                 plt.axis('off')
# ---> 36                 plt.imshow(dataset[i][0].squeeze(0), cmap = 'gray')
#      37             if i >=5 and i< 9:
#      38                 fig.add_subplot(rows, columns, i)
#
# /opt/conda/lib/python3.8/site-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, data, **kwargs)
#    2722         filternorm=True, filterrad=4.0, resample=None, url=None,
#    2723         data=None, **kwargs):
# -> 2724     __ret = gca().imshow(
#    2725         X, cmap=cmap, norm=norm, aspect=aspect,
#    2726         interpolation=interpolation, alpha=alpha, vmin=vmin,
#
# /opt/conda/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# -> 1447             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448
#    1449         bound = new_sig.bind(ax, *args, **kwargs)
#
# /opt/conda/lib/python3.8/site-packages/matplotlib/axes/_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, **kwargs)
#    5521                               resample=resample, **kwargs)
#    5522
# -> 5523         im.set_data(X)
#    5524         im.set_alpha(alpha)
#    5525         if im.get_clip_path() is None:
#
# /opt/conda/lib/python3.8/site-packages/matplotlib/image.py in set_data(self, A)
#     709         if not (self._A.ndim == 2
#     710                 or self._A.ndim == 3 and self._A.shape[-1] in [3, 4]):
# --> 711             raise TypeError("Invalid shape {} for image data"
#     712                             .format(self._A.shape))
#     713
#
# TypeError: Invalid shape (16, 1, 28, 28) for image data

# %%
device = torch.device('cuda') if torch.cuda.is_available else torch.device('cpu')
AEnet2 = AE(inplace = True).cuda()

# %%
AEnet2.load_state_dict(torch.load('./best_weights.pth'))
# Out:
# <All keys matched successfully>

# %%
optimizer = torch.optim.Adam(AEnet2.parameters(), lr=0.00005)
criterion = nn.MSELoss()

# %%
testing_superimposed = MNISTsuperimposed("./MNIST data/train", train = False, download = True, transform = transform, target_transform=target_transform)
testset = DataLoader(testing_superimposed, batch_size=128, shuffle = False)
outputs = train_test(AEnet2, testset, False)
# Out:
# [   50] loss per image: 0.003968
# The lowest was:  0.003526956308633089
# Finished Testing

# %%
show_output_images(testing_superimposed, outputs, False)
