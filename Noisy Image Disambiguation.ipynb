# %%
import torch as torch
import torchvision as tv
import torch.nn.functional as F
from torchvision import datasets
from torchvision import transforms
import matplotlib.pyplot as plt
import matplotlib.image as image
import cv2 as cv
from PIL import Image
import numpy as np
from torchvision.datasets.vision import VisionDataset
from typing import Any, Callable, Dict, List, Optional, Tuple
import os
import os.path
from torch import nn
from torchvision.datasets.mnist import read_image_file, read_label_file
from torchvision.datasets.utils import download_and_extract_archive, extract_archive, verify_str_arg, check_integrity
from skimage.util import random_noise

# %%
class MNISTsuperimposed(VisionDataset):
    """`MNIST <http://yann.lecun.com/exdb/mnist/>`_ Dataset.

    Args:
        root (string): Root directory of dataset where ``MNIST/processed/training.pt``
            and  ``MNIST/processed/test.pt`` exist.
        train (bool, optional): If True, creates dataset from ``training.pt``,
            otherwise from ``test.pt``.
        download (bool, optional): If true, downloads the dataset from the internet and
            puts it in root directory. If dataset is already downloaded, it is not
            downloaded again.
        transform (callable, optional): A function/transform that  takes in an PIL image
            and returns a transformed version. E.g, ``transforms.RandomCrop``
        target_transform (callable, optional): A function/transform that takes in the
            target and transforms it.
    """

    mirrors = [
        'http://yann.lecun.com/exdb/mnist/',
        'https://ossci-datasets.s3.amazonaws.com/mnist/',
    ]

    resources = [
        ("train-images-idx3-ubyte.gz", "f68b3c2dcbeaaa9fbdd348bbdeb94873"),
        ("train-labels-idx1-ubyte.gz", "d53e105ee54ea40749a09fcbcd1e9432"),
        ("t10k-images-idx3-ubyte.gz", "9fb629c4189551a2d022fa330f9573f3"),
        ("t10k-labels-idx1-ubyte.gz", "ec29112dd5afa0611ce80d1b7f02629c")
    ]

    training_file = 'training.pt'
    test_file = 'test.pt'
    classes = ['0 - zero', '1 - one', '2 - two', '3 - three', '4 - four',
               '5 - five', '6 - six', '7 - seven', '8 - eight', '9 - nine']

    @property
    def train_labels(self):
        warnings.warn("train_labels has been renamed targets")
        return self.targets

    @property
    def test_labels(self):
        warnings.warn("test_labels has been renamed targets")
        return self.targets

    @property
    def train_data(self):
        warnings.warn("train_data has been renamed data")
        return self.data

    @property
    def test_data(self):
        warnings.warn("test_data has been renamed data")
        return self.data

    def __init__(
            self,
            root,
            train= True,
            transform = None,
            target_transform = None,
            download = False,
    ):
        super(MNISTsuperimposed, self).__init__(root, transform=transform,
                                    target_transform=target_transform)
        self.train = train  # training set or test set

        if self._check_legacy_exist():
            self.data, self.targets = self._load_legacy_data()

        if download:
            self.download()

        if not self._check_exists():
            raise RuntimeError('Dataset not found.' +
                               ' You can use download=True to download it')

        self.data, self.targets = self._load_data()

    def _check_legacy_exist(self):
        processed_folder_exists = os.path.exists(self.processed_folder)
        if not processed_folder_exists:
            return False

        return all(
            check_integrity(os.path.join(self.processed_folder, file)) for file in (self.training_file, self.test_file)
        )

    def _load_legacy_data(self):
        # This is for BC only. We no longer cache the data in a custom binary, but simply read from the raw data
        # directly.
        data_file = self.training_file if self.train else self.test_file
        return torch.load(os.path.join(self.processed_folder, data_file))

    def _load_data(self):
        image_file = f"{'train' if self.train else 't10k'}-images-idx3-ubyte"
        data = read_image_file(os.path.join(self.raw_folder, image_file))
        #Technically, we do not even need the labels for now
        # We just need the clean images of both types
        randata = data[torch.randperm(data.shape[0]),:,:]
        targets = (data, randata)
        
        
        # Now do the ambiguation here
        data = data + randata
        return data, targets

    def __getitem__(self, index):
        """
        Args:
            index (int): Index

        Returns:
            tuple: (image, target) where target is index of the target class.
        """
        img, target = self.data[index], (self.targets[0][index], self.targets[1][index])
        # doing this so that it is consistent with all other datasets
        # to return a PIL Imagedata[torch.randperm(data.shape[0]),:,:]
        img = Image.fromarray(img.numpy(), mode='L')
        tgt1 = Image.fromarray(target[0].numpy(), mode='L')
        tgt2 = Image.fromarray(target[1].numpy(), mode='L')

        if self.transform is not None:
            img = self.transform(img)

        if self.target_transform is not None:
            tgt1 = self.target_transform(tgt1)
            tgt2 = self.target_transform(tgt2)
            

        return img, (tgt1, tgt2)

    def __len__(self):
        return len(self.data)

    @property
    def raw_folder(self):
        return os.path.join(self.root, self.__class__.__name__, 'raw')

    @property
    def processed_folder(self) -> str:
        return os.path.join(self.root, self.__class__.__name__, 'processed')

    @property
    def class_to_idx(self):
        return {_class: i for i, _class in enumerate(self.classes)}

    def _check_exists(self):
        return all(
            check_integrity(os.path.join(self.raw_folder, os.path.splitext(os.path.basename(url))[0]))
            for url, _ in self.resources
        )

    def download(self):
        """Download the MNIST data if it doesn't exist already."""

        if self._check_exists():
            return

        os.makedirs(self.raw_folder, exist_ok=True)

        # download files
        for filename, md5 in self.resources:
            for mirror in self.mirrors:
                url = "{}{}".format(mirror, filename)
                try:
                    print("Downloading {}".format(url))
                    download_and_extract_archive(
                        url, download_root=self.raw_folder,
                        filename=filename,
                        md5=md5
                    )
                except URLError as error:
                    print(
                        "Failed to download (trying next):\n{}".format(error)
                    )
                    continue
                finally:
                    print()
                break
            else:
                raise RuntimeError("Error downloading {}".format(filename))

    def extra_repr(self) -> str:
        return "Split: {}".format("Train" if self.train is True else "Test")

# %%
class Downsample(object):
    def __init__(self, size=[1,196]):
        self.size=size

    def __call__(self, tensor):
        img = np.squeeze(tensor)
        m = torch.nn.AvgPool2d(2, stride=2)
        return m(img.unsqueeze(0))

    def __repr__(self):
        return self.__class__.__name__+'({})'.format(self.size)

# %%
class AddGaussNoise(object):
    def __init__(self, mean=0, std=0.001):
        self.std=std
        self.mean=mean
        
    def __call__(self, tensor):
#         print(tensor + torch.randn(tensor.size()) * self.std + self.mean)
        return torch.tensor(random_noise(tensor,mean=self.mean,var=self.std))

    def __repr__(self):
        return self.__class__.__name__+'(mean={0},std={1})'.format(self.mean, self.std)

# %%
transform = transforms.Compose(
    [transforms.Grayscale(),
     transforms.ToTensor(),
     Downsample(),
     AddGaussNoise(0,1e-2)
     ])

target_transform =transforms.Compose(
    [transforms.Grayscale(),
     transforms.ToTensor()     
    ]) 
mnist_superimposed = MNISTsuperimposed("./MNIST data/train", train = True, download = True, transform = transform, target_transform=target_transform)
# Out:
# /opt/conda/lib/python3.8/site-packages/torchvision/datasets/mnist.py:480: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  ../torch/csrc/utils/tensor_numpy.cpp:137.)
#   return torch.from_numpy(parsed.astype(m[2], copy=False)).view(*s)

# %%
from torch.utils.data import DataLoader
batch = 96
trainset = DataLoader(mnist_superimposed, batch_size=batch, shuffle = True)

# %%
def show_images(dataset, training = True):
    
    fig = plt.figure(figsize = (20, 14))
    rows = 3
    columns = 4
    j=0
    for i in range(1,columns*rows+1):
        if i >=1 and i< 5:
            fig.add_subplot(rows, columns, i)
            plt.imshow(dataset[i][0].squeeze(0))
        if i >=5 and i < 9:
            fig.add_subplot(rows, columns, i)
            plt.imshow(dataset[i-4][1][0].squeeze(0))
        if i >= 9 and i<13:
            fig.add_subplot(rows, columns, i)
            plt.imshow(dataset[i-8][1][1].squeeze(0))

# %%
show_images(mnist_superimposed)

# %%
import torch
from torch import nn as nn
from torch.nn import Conv2d, ConvTranspose2d, Linear, Sequential, Flatten, ReLU, LeakyReLU, AvgPool2d, MaxPool2d,Dropout

# %%
class AE(nn.Module):
    def __init__(self, inplace = False):
        super(AE,self).__init__()
        
        self.Upsample_1 = nn.Sequential(
            nn.Flatten(start_dim = 2),
            nn.Linear(196, 256),
            nn.Linear(256, 256),
            nn.ReLU(inplace),
            
            nn.Linear(256, 512),
            nn.Linear(512, 784),
            nn.Linear(784, 784),
            nn.ReLU(inplace),
        )
        
            
        self.initial_Processing = nn.Sequential(
            nn.Conv2d(in_channels = 1, out_channels = 64, kernel_size = 3, padding = 1, stride = 1),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace),
            nn.Conv2d(in_channels = 64, out_channels = 128, kernel_size = 3, padding =1, stride = 1),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace),
        )

        self.Down_1 = nn.Sequential(
            nn.Conv2d(in_channels = 128, out_channels = 512, kernel_size = (3, 3), padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.Conv2d(in_channels = 512, out_channels = 512, kernel_size = (3, 3), padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.MaxPool2d(kernel_size = (2, 2)),
        )

        self.Down_2 = nn.Sequential(
            nn.Conv2d(in_channels = 512, out_channels = 256, kernel_size = (3, 3), padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.Conv2d(in_channels = 256, out_channels = 256, kernel_size = (3, 3), padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.MaxPool2d(kernel_size = (2, 2)),
        )


        self.Down_3 = nn.Sequential(
            nn.Conv2d(in_channels = 256, out_channels = 128, kernel_size = (3, 3), padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.Conv2d(in_channels = 128, out_channels = 128, kernel_size = (3, 3), padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.MaxPool2d(kernel_size = (2, 2)),
        )

        self.Down_4 = nn.Sequential(
            nn.Conv2d(in_channels = 128, out_channels = 64, kernel_size = (3, 3), padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.Conv2d(in_channels = 64, out_channels = 64, kernel_size = (3, 3), padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.MaxPool2d(kernel_size = (2, 2)),
        )

        self.Up_1 = nn.Sequential(
            nn.Conv2d(in_channels = 64, out_channels = 64, kernel_size = (3, 3), padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.Conv2d(in_channels = 64, out_channels = 32, kernel_size = (3, 3), padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.ConvTranspose2d(in_channels = 32, out_channels = 64, kernel_size = (2, 2))
        )

        self.Up_2 = nn.Sequential(
            nn.Conv2d(in_channels = 128, out_channels = 128, kernel_size = (3, 3), padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.Conv2d(in_channels = 128, out_channels = 64, kernel_size = (3, 3), padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.ConvTranspose2d(in_channels = 64, out_channels = 128, kernel_size = (2, 2))
        )

        self.Up_3 = nn.Sequential(
            nn.Conv2d(in_channels = 256, out_channels = 256, kernel_size = (3, 3), padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.Conv2d(in_channels = 256, out_channels = 128, kernel_size = (3, 3), padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.ConvTranspose2d(in_channels = 128, out_channels = 256, kernel_size = (2, 2))
        )

        self.Up_4 = nn.Sequential(
            nn.Conv2d(in_channels = 512, out_channels = 512, kernel_size = (3, 3), padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.Conv2d(in_channels = 512, out_channels = 256, kernel_size = (3, 3), padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.ConvTranspose2d(in_channels = 256, out_channels = 512, kernel_size = (2, 2))
        )

        self.Up_5 = nn.Sequential(
            nn.Conv2d(in_channels = 1024, out_channels = 512, kernel_size = (3, 3), padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.Conv2d(in_channels = 512, out_channels = 512, kernel_size = (3, 3), padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.ConvTranspose2d(in_channels = 512, out_channels = 2, kernel_size = (1, 1))
        )
        
        self.Upsample_2 = nn.Sequential(
            nn.Flatten(start_dim = 1),
            nn.Linear(392, 512),
            nn.Linear(512, 512),
            nn.ReLU(inplace),
            
            nn.Linear(512, 1024),
            nn.Linear(1024, 1568),
            nn.Linear(1568, 1568),
            nn.Sigmoid(),
        )
        
    def forward(self, x):
        
        #First Dip
        output = self.Upsample_1(x)
        output = output.reshape(output.shape[0], 1, 28, 28)
#         print(output.shape)
        
        output = self.initial_Processing(output)
#         print(output.shape)
        
        output = self.Down_1(output)
        output_1 = output
#         print(output.shape)
        
        
        output = self.Down_2(output)
        output_2 = output
#         print(output.shape)
        
        output = self.Down_3(output)
        output_3 = output
#         print(output.shape)
        
        output = self.Down_4(output)
        output_4 = output
#         print(output.shape)
        
        
        
        
        output = self.Up_1(output)
#         print("After Up1", output.shape)
        diffY = output_4.size()[2] - output.size()[2]
        diffX = output_4.size()[3] - output.size()[3]
        output = F.pad(output, [diffX // 2, diffX - diffX // 2,
                        diffY // 2, diffY - diffY // 2])
        output = torch.cat([output_4, output], dim=1)
        

        output = self.Up_2(output)
#         print("After Up2",output.shape)
        diffY = output_3.size()[2] - output.size()[2]
        diffX = output_3.size()[3] - output.size()[3]
        output = F.pad(output, [diffX // 2, diffX - diffX // 2,
                        diffY // 2, diffY - diffY // 2])
        output = torch.cat([output_3, output], dim=1)


        output = self.Up_3(output)
#         print("After Up3",output.shape)
        diffY = output_2.size()[2] - output.size()[2]
        diffX = output_2.size()[3] - output.size()[3]
        output = F.pad(output, [diffX // 2, diffX - diffX // 2,
                        diffY // 2, diffY - diffY // 2])
        output = torch.cat([output_2, output], dim=1)


        output = self.Up_4(output)
#         print("After Up4",output.shape)
        diffY = output_1.size()[2] - output.size()[2]
        diffX = output_1.size()[3] - output.size()[3]
        output = F.pad(output, [diffX // 2, diffX - diffX // 2,
                        diffY // 2, diffY - diffY // 2])
        output = torch.cat([output_1, output], dim=1)


        output = self.Up_5(output)
#         print(output.shape)

        
        output = self.Upsample_2[:2](output)
        output = self.Upsample_2[3:6](output + self.Upsample_2[2](output))
        output = self.Upsample_2[7](output + self.Upsample_2[6](output))
                
                
        return output

# %%
device = torch.device('cuda') if torch.cuda.is_available else torch.device('cpu')
AEnet = AE(inplace = True).cuda()

# %%
optimizer = torch.optim.Adam(AEnet.parameters(), lr=0.000080)
criterion = nn.MSELoss()
print(device)
# Out:
# cuda

# %%
len(trainset)
# Out:
# 625

# %%
def train_test(AEnet, dataset, Training = True):

    if Training:
        epochs = 100
        train_loss = []
        t_loss = []
        flag = True
        for epoch in range(epochs):
            running_loss = 0.0
            for i, data in enumerate(dataset):
                optimizer.zero_grad()
                outputs = AEnet(data[0].float().to(device))
                output_1 = outputs[:, :784]
                output_2 = outputs[:, 784:]
                loss = criterion(output_1.float().to(device), torch.flatten(data[1][0],1).float().to(device)) + criterion(output_2.float().to(device), torch.flatten(data[1][1],1).float().to(device))
                loss.backward()
                optimizer.step()
                train_loss.append(loss.item())
                running_loss += loss.item()
                if i % 150 == 149:
                    print('[%d, %5d] loss per image: %.6f' %
                          (epoch + 1, i + 1, loss.item()/32))
                    t_loss.append(loss.item()/32)
                    if epoch % 10 == 9:
                        torch.save(AEnet.state_dict(), "./weights.pth")
                
            

            
        print("The lowest was: ", min(train_loss)/32)

        print('Finished Training')
        flag = False
        return outputs, data, t_loss
            
    else:
        testing_loss = []
        t_loss = []
        with torch.no_grad():
            for i, data in enumerate(dataset):
                    optimizer.zero_grad()
                    outputs = AEnet(data[0].float().to(device))
                    output_1 = outputs[:, :784]
                    output_2 = outputs[:, 784:]
                    loss = criterion(output_1.float().to(device), torch.flatten(data[1][0],1).float().to(device)) + criterion(output_2.float().to(device), torch.flatten(data[1][1],1).float().to(device))
                    testing_loss.append(loss.item())
                    if i % 10 == 9:
                        print('[%5d] loss per image: %.6f' %
                              (i + 1, loss.item()/32))
                        t_loss.append(loss.item()/32)
                    
        print("The lowest was: ", min(testing_loss)/32)
        print('Finished Testing')
        return outputs, data, t_loss

# %%
output, data, training_loss= train_test(AEnet, trainset)
# Out:
# [1,   150] loss per image: 0.003614
# [1,   300] loss per image: 0.003363
# [1,   450] loss per image: 0.003158
# [1,   600] loss per image: 0.003176
# [2,   150] loss per image: 0.003122
# [2,   300] loss per image: 0.003094
# [2,   450] loss per image: 0.003062
# [2,   600] loss per image: 0.003045
# [3,   150] loss per image: 0.003052
# [3,   300] loss per image: 0.002974
# [3,   450] loss per image: 0.003116
# [3,   600] loss per image: 0.003005
# [4,   150] loss per image: 0.002957
# [4,   300] loss per image: 0.002950
# [4,   450] loss per image: 0.003064
# [4,   600] loss per image: 0.002907
# [5,   150] loss per image: 0.002833
# [5,   300] loss per image: 0.002811
# [5,   450] loss per image: 0.002933
# [5,   600] loss per image: 0.002929
# [6,   150] loss per image: 0.002932
# [6,   300] loss per image: 0.002974
# [6,   450] loss per image: 0.002770
# [6,   600] loss per image: 0.002699
# [7,   150] loss per image: 0.002949
# [7,   300] loss per image: 0.002847
# [7,   450] loss per image: 0.002830
# [7,   600] loss per image: 0.002875
# [8,   150] loss per image: 0.002801
# [8,   300] loss per image: 0.002740
# [8,   450] loss per image: 0.002799
# [8,   600] loss per image: 0.002856
# [9,   150] loss per image: 0.002804
# [9,   300] loss per image: 0.002804
# [9,   450] loss per image: 0.002871
# [9,   600] loss per image: 0.002737
# [10,   150] loss per image: 0.002869
# [10,   300] loss per image: 0.002766
# [10,   450] loss per image: 0.002808
# [10,   600] loss per image: 0.002745
# [11,   150] loss per image: 0.002843
# [11,   300] loss per image: 0.002719
# [11,   450] loss per image: 0.002748
# [11,   600] loss per image: 0.002696
# [12,   150] loss per image: 0.002649
# [12,   300] loss per image: 0.002705
# [12,   450] loss per image: 0.002606
# [12,   600] loss per image: 0.002724
# [13,   150] loss per image: 0.002667
# [13,   300] loss per image: 0.002667
# [13,   450] loss per image: 0.002749
# [13,   600] loss per image: 0.002755
# [14,   150] loss per image: 0.002757
# [14,   300] loss per image: 0.002658
# [14,   450] loss per image: 0.002661
# [14,   600] loss per image: 0.002671
# [15,   150] loss per image: 0.002717
# [15,   300] loss per image: 0.002743
# [15,   450] loss per image: 0.002754
# [15,   600] loss per image: 0.002640
# [16,   150] loss per image: 0.002694
# [16,   300] loss per image: 0.002634
# [16,   450] loss per image: 0.002719
# [16,   600] loss per image: 0.002849
# [17,   150] loss per image: 0.002580
# [17,   300] loss per image: 0.002608
# [17,   450] loss per image: 0.002724
# [17,   600] loss per image: 0.002675
# [18,   150] loss per image: 0.002644
# [18,   300] loss per image: 0.002645
# [18,   450] loss per image: 0.002573
# [18,   600] loss per image: 0.002621
# [19,   150] loss per image: 0.002517
# [19,   300] loss per image: 0.002537
# [19,   450] loss per image: 0.002442
# [19,   600] loss per image: 0.002688
# [20,   150] loss per image: 0.002359
# [20,   300] loss per image: 0.002456
# [20,   450] loss per image: 0.002460
# [20,   600] loss per image: 0.002613
# [21,   150] loss per image: 0.002464
# [21,   300] loss per image: 0.002431
# [21,   450] loss per image: 0.002403
# [21,   600] loss per image: 0.002484
# [22,   150] loss per image: 0.002169
# [22,   300] loss per image: 0.002477
# [22,   450] loss per image: 0.002423
# [22,   600] loss per image: 0.002341
# [23,   150] loss per image: 0.002157
# [23,   300] loss per image: 0.002325
# [23,   450] loss per image: 0.002291
# [23,   600] loss per image: 0.002384
# [24,   150] loss per image: 0.002209
# [24,   300] loss per image: 0.002330
# [24,   450] loss per image: 0.002153
# [24,   600] loss per image: 0.002272
# [25,   150] loss per image: 0.002122
# [25,   300] loss per image: 0.002173
# [25,   450] loss per image: 0.002248
# [25,   600] loss per image: 0.002238
# [26,   150] loss per image: 0.002050
# [26,   300] loss per image: 0.002102
# [26,   450] loss per image: 0.002393
# [26,   600] loss per image: 0.002144
# [27,   150] loss per image: 0.002025
# [27,   300] loss per image: 0.002240
# [27,   450] loss per image: 0.002138
# [27,   600] loss per image: 0.002169
# [28,   150] loss per image: 0.002137
# [28,   300] loss per image: 0.002090
# [28,   450] loss per image: 0.002021
# [28,   600] loss per image: 0.002105
# [29,   150] loss per image: 0.001843
# [29,   300] loss per image: 0.001956
# [29,   450] loss per image: 0.001954
# [29,   600] loss per image: 0.002072
# [30,   150] loss per image: 0.001976
# [30,   300] loss per image: 0.002007
# [30,   450] loss per image: 0.001951
# [30,   600] loss per image: 0.002052
# [31,   150] loss per image: 0.002082
# [31,   300] loss per image: 0.001861
# [31,   450] loss per image: 0.001875
# [31,   600] loss per image: 0.001997
# [32,   150] loss per image: 0.001889
# [32,   300] loss per image: 0.001874
# [32,   450] loss per image: 0.001869
# [32,   600] loss per image: 0.001849
# [33,   150] loss per image: 0.001838
# [33,   300] loss per image: 0.001969
# [33,   450] loss per image: 0.001748
# [33,   600] loss per image: 0.001953
# [34,   150] loss per image: 0.001783
# [34,   300] loss per image: 0.001839
# [34,   450] loss per image: 0.002025
# [34,   600] loss per image: 0.001735
# [35,   150] loss per image: 0.001819
# [35,   300] loss per image: 0.001835
# [35,   450] loss per image: 0.001787
# [35,   600] loss per image: 0.001745
# [36,   150] loss per image: 0.001818
# [36,   300] loss per image: 0.001880
# [36,   450] loss per image: 0.001812
# [36,   600] loss per image: 0.001644
# [37,   150] loss per image: 0.001645
# [37,   300] loss per image: 0.001860
# [37,   450] loss per image: 0.001660
# [37,   600] loss per image: 0.001790
# [38,   150] loss per image: 0.001594
# [38,   300] loss per image: 0.001812
# [38,   450] loss per image: 0.001688
# [38,   600] loss per image: 0.001864
# [39,   150] loss per image: 0.001627
# [39,   300] loss per image: 0.001645
# [39,   450] loss per image: 0.001820
# [39,   600] loss per image: 0.001629
# [40,   150] loss per image: 0.001536
# [40,   300] loss per image: 0.001678
# [40,   450] loss per image: 0.001666
# [40,   600] loss per image: 0.001743
# [41,   150] loss per image: 0.001614
# [41,   300] loss per image: 0.001682
# [41,   450] loss per image: 0.001700
# [41,   600] loss per image: 0.001640
# [42,   150] loss per image: 0.001700
# [42,   300] loss per image: 0.001740
# [42,   450] loss per image: 0.001719
# [42,   600] loss per image: 0.001626
# [43,   150] loss per image: 0.001533
# [43,   300] loss per image: 0.001645
# [43,   450] loss per image: 0.001741
# [43,   600] loss per image: 0.001597
# [44,   150] loss per image: 0.001689
# [44,   300] loss per image: 0.001584
# [44,   450] loss per image: 0.001542
# [44,   600] loss per image: 0.001672
# [45,   150] loss per image: 0.001550
# [45,   300] loss per image: 0.001607
# [45,   450] loss per image: 0.001631
# [45,   600] loss per image: 0.001564
# [46,   150] loss per image: 0.001530
# [46,   300] loss per image: 0.001654
# [46,   450] loss per image: 0.001594
# [46,   600] loss per image: 0.001635
# [47,   150] loss per image: 0.001525
# [47,   300] loss per image: 0.001628
# [47,   450] loss per image: 0.001677
# [47,   600] loss per image: 0.001677
# [48,   150] loss per image: 0.001505
# [48,   300] loss per image: 0.001487
# [48,   450] loss per image: 0.001548
# [48,   600] loss per image: 0.001488
# [49,   150] loss per image: 0.001481
# [49,   300] loss per image: 0.001611
# [49,   450] loss per image: 0.001477
# [49,   600] loss per image: 0.001582
# [50,   150] loss per image: 0.001525
# [50,   300] loss per image: 0.001452
# [50,   450] loss per image: 0.001520
# [50,   600] loss per image: 0.001622
# [51,   150] loss per image: 0.001460
# [51,   300] loss per image: 0.001569
# [51,   450] loss per image: 0.001493
# [51,   600] loss per image: 0.001663
# [52,   150] loss per image: 0.001383
# [52,   300] loss per image: 0.001542
# [52,   450] loss per image: 0.001559
# [52,   600] loss per image: 0.001518
# [53,   150] loss per image: 0.001498
# [53,   300] loss per image: 0.001526
# [53,   450] loss per image: 0.001573
# [53,   600] loss per image: 0.001502
# [54,   150] loss per image: 0.001524
# [54,   300] loss per image: 0.001495
# [54,   450] loss per image: 0.001513
# [54,   600] loss per image: 0.001498
# [55,   150] loss per image: 0.001466
# [55,   300] loss per image: 0.001476
# [55,   450] loss per image: 0.001454
# [55,   600] loss per image: 0.001513
# [56,   150] loss per image: 0.001460
# [56,   300] loss per image: 0.001485
# [56,   450] loss per image: 0.001424
# [56,   600] loss per image: 0.001414
# [57,   150] loss per image: 0.001443
# [57,   300] loss per image: 0.001415
# [57,   450] loss per image: 0.001365
# [57,   600] loss per image: 0.001378
# [58,   150] loss per image: 0.001411
# [58,   300] loss per image: 0.001418
# [58,   450] loss per image: 0.001435
# [58,   600] loss per image: 0.001434
# [59,   150] loss per image: 0.001464
# [59,   300] loss per image: 0.001383
# [59,   450] loss per image: 0.001478
# [59,   600] loss per image: 0.001508
# [60,   150] loss per image: 0.001504
# [60,   300] loss per image: 0.001440
# [60,   450] loss per image: 0.001382
# [60,   600] loss per image: 0.001453
# [61,   150] loss per image: 0.001398
# [61,   300] loss per image: 0.001359
# [61,   450] loss per image: 0.001397
# [61,   600] loss per image: 0.001359
# [62,   150] loss per image: 0.001391
# [62,   300] loss per image: 0.001377
# [62,   450] loss per image: 0.001406
# [62,   600] loss per image: 0.001516
# [63,   150] loss per image: 0.001310
# [63,   300] loss per image: 0.001369
# [63,   450] loss per image: 0.001323
# [63,   600] loss per image: 0.001400
# [64,   150] loss per image: 0.001419
# [64,   300] loss per image: 0.001284
# [64,   450] loss per image: 0.001408
# [64,   600] loss per image: 0.001290
# [65,   150] loss per image: 0.001386
# [65,   300] loss per image: 0.001348
# [65,   450] loss per image: 0.001385
# [65,   600] loss per image: 0.001412
# [66,   150] loss per image: 0.001339
# [66,   300] loss per image: 0.001353
# [66,   450] loss per image: 0.001336
# [66,   600] loss per image: 0.001315
# [67,   150] loss per image: 0.001363
# [67,   300] loss per image: 0.001285
# [67,   450] loss per image: 0.001448
# [67,   600] loss per image: 0.001283
# [68,   150] loss per image: 0.001334
# [68,   300] loss per image: 0.001345
# [68,   450] loss per image: 0.001314
# [68,   600] loss per image: 0.001462
# [69,   150] loss per image: 0.001344
# [69,   300] loss per image: 0.001277
# [69,   450] loss per image: 0.001368
# [69,   600] loss per image: 0.001334
# [70,   150] loss per image: 0.001317
# [70,   300] loss per image: 0.001267
# [70,   450] loss per image: 0.001342
# [70,   600] loss per image: 0.001376
# [71,   150] loss per image: 0.001389
# [71,   300] loss per image: 0.001289
# [71,   450] loss per image: 0.001301
# [71,   600] loss per image: 0.001376
# [72,   150] loss per image: 0.001348
# [72,   300] loss per image: 0.001244
# [72,   450] loss per image: 0.001297
# [72,   600] loss per image: 0.001238
# [73,   150] loss per image: 0.001284
# [73,   300] loss per image: 0.001249
# [73,   450] loss per image: 0.001305
# [73,   600] loss per image: 0.001389
# [74,   150] loss per image: 0.001231
# [74,   300] loss per image: 0.001157
# [74,   450] loss per image: 0.001339
# [74,   600] loss per image: 0.001308
# [75,   150] loss per image: 0.001214
# [75,   300] loss per image: 0.001346
# [75,   450] loss per image: 0.001296
# [75,   600] loss per image: 0.001374
# [76,   150] loss per image: 0.001239
# [76,   300] loss per image: 0.001253
# [76,   450] loss per image: 0.001221
# [76,   600] loss per image: 0.001277
# [77,   150] loss per image: 0.001323
# [77,   300] loss per image: 0.001265
# [77,   450] loss per image: 0.001274
# [77,   600] loss per image: 0.001346
# [78,   150] loss per image: 0.001222
# [78,   300] loss per image: 0.001242
# [78,   450] loss per image: 0.001263
# [78,   600] loss per image: 0.001366
# [79,   150] loss per image: 0.001220
# [79,   300] loss per image: 0.001273
# [79,   450] loss per image: 0.001229
# [79,   600] loss per image: 0.001322
# [80,   150] loss per image: 0.001215
# [80,   300] loss per image: 0.001230
# [80,   450] loss per image: 0.001159
# [80,   600] loss per image: 0.001310
# [81,   150] loss per image: 0.001257
# [81,   300] loss per image: 0.001220
# [81,   450] loss per image: 0.001256
# [81,   600] loss per image: 0.001237
# [82,   150] loss per image: 0.001270
# [82,   300] loss per image: 0.001230
# [82,   450] loss per image: 0.001196
# [82,   600] loss per image: 0.001255
# [83,   150] loss per image: 0.001157
# [83,   300] loss per image: 0.001248
# [83,   450] loss per image: 0.001242
# [83,   600] loss per image: 0.001159
# [84,   150] loss per image: 0.001234
# [84,   300] loss per image: 0.001158
# [84,   450] loss per image: 0.001259
# [84,   600] loss per image: 0.001213
# [85,   150] loss per image: 0.001232
# [85,   300] loss per image: 0.001164
# [85,   450] loss per image: 0.001220
# [85,   600] loss per image: 0.001238
# [86,   150] loss per image: 0.001251
# [86,   300] loss per image: 0.001237
# [86,   450] loss per image: 0.001255
# [86,   600] loss per image: 0.001283
# [87,   150] loss per image: 0.001206
# [87,   300] loss per image: 0.001139
# [87,   450] loss per image: 0.001196
# [87,   600] loss per image: 0.001213
# [88,   150] loss per image: 0.001073
# [88,   300] loss per image: 0.001175
# [88,   450] loss per image: 0.001183
# [88,   600] loss per image: 0.001200
# [89,   150] loss per image: 0.001168
# [89,   300] loss per image: 0.001192
# [89,   450] loss per image: 0.001143
# [89,   600] loss per image: 0.001162
# [90,   150] loss per image: 0.001191
# [90,   300] loss per image: 0.001236
# [90,   450] loss per image: 0.001279
# [90,   600] loss per image: 0.001178
# [91,   150] loss per image: 0.001140
# [91,   300] loss per image: 0.001145
# [91,   450] loss per image: 0.001189
# [91,   600] loss per image: 0.001200
# [92,   150] loss per image: 0.001175
# [92,   300] loss per image: 0.001188
# [92,   450] loss per image: 0.001242
# [92,   600] loss per image: 0.001158
# [93,   150] loss per image: 0.001187
# [93,   300] loss per image: 0.001231
# [93,   450] loss per image: 0.001162
# [93,   600] loss per image: 0.001137
# [94,   150] loss per image: 0.001175
# [94,   300] loss per image: 0.001115
# [94,   450] loss per image: 0.001187
# [94,   600] loss per image: 0.001125
# [95,   150] loss per image: 0.001117
# [95,   300] loss per image: 0.001164
# [95,   450] loss per image: 0.001116
# [95,   600] loss per image: 0.001221
# [96,   150] loss per image: 0.001073
# [96,   300] loss per image: 0.001166
# [96,   450] loss per image: 0.001200
# [96,   600] loss per image: 0.001171
# [97,   150] loss per image: 0.001126
# [97,   300] loss per image: 0.001124
# [97,   450] loss per image: 0.001204
# [97,   600] loss per image: 0.001157
# [98,   150] loss per image: 0.001166
# [98,   300] loss per image: 0.001247
# [98,   450] loss per image: 0.001088
# [98,   600] loss per image: 0.001150
# [99,   150] loss per image: 0.001174
# [99,   300] loss per image: 0.001070
# [99,   450] loss per image: 0.001162
# [99,   600] loss per image: 0.001134
# [100,   150] loss per image: 0.001137
# [100,   300] loss per image: 0.001075
# [100,   450] loss per image: 0.001096
# [100,   600] loss per image: 0.001044
# The lowest was:  0.0009628041880205274
# Finished Training

# %%
def plot_loss(loss, train = True):
    fig = plt.figure(figsize = (10, 7))
    
    
    if(train):
        x = list(np.arange(0.0, 100.0, 0.25))
        plt.axis("on")
        plt.ylabel('Loss')
        plt.xlabel('Epoch')
        plt.title("Training Loss")
        plt.plot(x, loss)
    else:
        x = list(np.arange(0.0, 7.0, 1.0))
        plt.axis("on")
        plt.ylabel('Loss')
        plt.xlabel('Epoch')
        plt.title("Testing Loss")
        plt.plot(x, loss)

# %%
plot_loss(training_loss)

# %%
#Print only the output images
def show_output_images(dataset, outputs, training = True):
    
    fig = plt.figure(figsize = (20, 14))
    rows = 5
    columns = 4
    j=0
    for i in range(1,columns*rows+1):            
            if i >=1 and i< 5:
                fig.add_subplot(rows, columns, i)
                plt.axis('off')
                plt.imshow(dataset[0][i].squeeze(0), cmap = 'gray')
            if i >=5 and i< 9:
                fig.add_subplot(rows, columns, i)
                plt.axis('off')
                plt.imshow(outputs[i-4][:784].cpu().detach().numpy().reshape(28,28), cmap='gray')
            if i >=9 and i < 13:
                fig.add_subplot(rows, columns, i)
                plt.axis('off')
                plt.imshow(outputs[i-8][784:].cpu().detach().numpy().reshape(28,28), cmap='gray')
            if i >=13 and i < 17:
                fig.add_subplot(rows, columns, i)
                plt.axis('off')
                plt.imshow(dataset[1][0][i-12].cpu().detach().numpy().reshape(28,28), cmap='gray')
            if i >=17 and i < 21:    
                fig.add_subplot(rows, columns, i)
                plt.axis('off')
                plt.imshow(dataset[1][1][i - 16].cpu().detach().numpy().reshape(28,28), cmap='gray')

# %%
show_output_images(data, output)

# %%
testing_superimposed = MNISTsuperimposed("./MNIST data/train", train = False, download = True, transform = transform, target_transform=target_transform)
testset = DataLoader(testing_superimposed, batch_size=128, shuffle = False)
outputs, test_data, test_loss = train_test(AEnet, testset, False)
# Out:
# [   10] loss per image: 0.003413
# [   20] loss per image: 0.003575
# [   30] loss per image: 0.003337
# [   40] loss per image: 0.003234
# [   50] loss per image: 0.003372
# [   60] loss per image: 0.003254
# [   70] loss per image: 0.003712
# The lowest was:  0.0030254521407186985
# Finished Testing

# %%
show_output_images(test_data, outputs, False)

# %%
plot_loss(test_loss, False)
