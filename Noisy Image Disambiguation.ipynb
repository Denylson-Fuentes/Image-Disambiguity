# %%
import torch as torch
import torchvision as tv
import torch.nn.functional as F
from torchvision import datasets
from torchvision import transforms
import matplotlib.pyplot as plt
import matplotlib.image as image
import cv2 as cv
from PIL import Image
import numpy as np
from torchvision.datasets.vision import VisionDataset
from typing import Any, Callable, Dict, List, Optional, Tuple
import os
import os.path
from torch import nn
from torchvision.datasets.mnist import read_image_file, read_label_file
from torchvision.datasets.utils import download_and_extract_archive, extract_archive, verify_str_arg, check_integrity
from skimage.util import random_noise

# %%
class MNISTsuperimposed(VisionDataset):
    """`MNIST <http://yann.lecun.com/exdb/mnist/>`_ Dataset.

    Args:
        root (string): Root directory of dataset where ``MNIST/processed/training.pt``
            and  ``MNIST/processed/test.pt`` exist.
        train (bool, optional): If True, creates dataset from ``training.pt``,
            otherwise from ``test.pt``.
        download (bool, optional): If true, downloads the dataset from the internet and
            puts it in root directory. If dataset is already downloaded, it is not
            downloaded again.
        transform (callable, optional): A function/transform that  takes in an PIL image
            and returns a transformed version. E.g, ``transforms.RandomCrop``
        target_transform (callable, optional): A function/transform that takes in the
            target and transforms it.
    """

    mirrors = [
        'http://yann.lecun.com/exdb/mnist/',
        'https://ossci-datasets.s3.amazonaws.com/mnist/',
    ]

    resources = [
        ("train-images-idx3-ubyte.gz", "f68b3c2dcbeaaa9fbdd348bbdeb94873"),
        ("train-labels-idx1-ubyte.gz", "d53e105ee54ea40749a09fcbcd1e9432"),
        ("t10k-images-idx3-ubyte.gz", "9fb629c4189551a2d022fa330f9573f3"),
        ("t10k-labels-idx1-ubyte.gz", "ec29112dd5afa0611ce80d1b7f02629c")
    ]

    training_file = 'training.pt'
    test_file = 'test.pt'
    classes = ['0 - zero', '1 - one', '2 - two', '3 - three', '4 - four',
               '5 - five', '6 - six', '7 - seven', '8 - eight', '9 - nine']

    @property
    def train_labels(self):
        warnings.warn("train_labels has been renamed targets")
        return self.targets

    @property
    def test_labels(self):
        warnings.warn("test_labels has been renamed targets")
        return self.targets

    @property
    def train_data(self):
        warnings.warn("train_data has been renamed data")
        return self.data

    @property
    def test_data(self):
        warnings.warn("test_data has been renamed data")
        return self.data

    def __init__(
            self,
            root,
            train= True,
            transform = None,
            target_transform = None,
            download = False,
    ):
        super(MNISTsuperimposed, self).__init__(root, transform=transform,
                                    target_transform=target_transform)
        self.train = train  # training set or test set

        if self._check_legacy_exist():
            self.data, self.targets = self._load_legacy_data()

        if download:
            self.download()

        if not self._check_exists():
            raise RuntimeError('Dataset not found.' +
                               ' You can use download=True to download it')

        self.data, self.targets = self._load_data()

    def _check_legacy_exist(self):
        processed_folder_exists = os.path.exists(self.processed_folder)
        if not processed_folder_exists:
            return False

        return all(
            check_integrity(os.path.join(self.processed_folder, file)) for file in (self.training_file, self.test_file)
        )

    def _load_legacy_data(self):
        # This is for BC only. We no longer cache the data in a custom binary, but simply read from the raw data
        # directly.
        data_file = self.training_file if self.train else self.test_file
        return torch.load(os.path.join(self.processed_folder, data_file))

    def _load_data(self):
        image_file = f"{'train' if self.train else 't10k'}-images-idx3-ubyte"
        data = read_image_file(os.path.join(self.raw_folder, image_file))
        #Technically, we do not even need the labels for now
        # We just need the clean images of both types
        randata = data[torch.randperm(data.shape[0]),:,:]
        targets = (data, randata)
        
        
        # Now do the ambiguation here
        data = data + randata
        return data, targets

    def __getitem__(self, index):
        """
        Args:
            index (int): Index

        Returns:
            tuple: (image, target) where target is index of the target class.
        """
        img, target = self.data[index], (self.targets[0][index], self.targets[1][index])
        # doing this so that it is consistent with all other datasets
        # to return a PIL Imagedata[torch.randperm(data.shape[0]),:,:]
        img = Image.fromarray(img.numpy(), mode='L')
        tgt1 = Image.fromarray(target[0].numpy(), mode='L')
        tgt2 = Image.fromarray(target[1].numpy(), mode='L')

        if self.transform is not None:
            img = self.transform(img)

        if self.target_transform is not None:
            tgt1 = self.target_transform(tgt1)
            tgt2 = self.target_transform(tgt2)
            

        return img, (tgt1, tgt2)

    def __len__(self):
        return len(self.data)

    @property
    def raw_folder(self):
        return os.path.join(self.root, self.__class__.__name__, 'raw')

    @property
    def processed_folder(self) -> str:
        return os.path.join(self.root, self.__class__.__name__, 'processed')

    @property
    def class_to_idx(self):
        return {_class: i for i, _class in enumerate(self.classes)}

    def _check_exists(self):
        return all(
            check_integrity(os.path.join(self.raw_folder, os.path.splitext(os.path.basename(url))[0]))
            for url, _ in self.resources
        )

    def download(self):
        """Download the MNIST data if it doesn't exist already."""

        if self._check_exists():
            return

        os.makedirs(self.raw_folder, exist_ok=True)

        # download files
        for filename, md5 in self.resources:
            for mirror in self.mirrors:
                url = "{}{}".format(mirror, filename)
                try:
                    print("Downloading {}".format(url))
                    download_and_extract_archive(
                        url, download_root=self.raw_folder,
                        filename=filename,
                        md5=md5
                    )
                except URLError as error:
                    print(
                        "Failed to download (trying next):\n{}".format(error)
                    )
                    continue
                finally:
                    print()
                break
            else:
                raise RuntimeError("Error downloading {}".format(filename))

    def extra_repr(self) -> str:
        return "Split: {}".format("Train" if self.train is True else "Test")

# %%
class Downsample(object):
    def __init__(self, size=[1,196]):
        self.size=size

    def __call__(self, tensor):
        img = np.squeeze(tensor)
        m = torch.nn.AvgPool2d(2, stride=2)
        return m(img.unsqueeze(0))

    def __repr__(self):
        return self.__class__.__name__+'({})'.format(self.size)

# %%
class AddGaussNoise(object):
    def __init__(self, mean=0, std=0.001):
        self.std=std
        self.mean=mean
        
    def __call__(self, tensor):
#         print(tensor + torch.randn(tensor.size()) * self.std + self.mean)
        return torch.tensor(random_noise(tensor,mean=self.mean,var=self.std))

    def __repr__(self):
        return self.__class__.__name__+'(mean={0},std={1})'.format(self.mean, self.std)

# %%
transform = transforms.Compose(
    [transforms.Grayscale(),
     transforms.ToTensor(),
     Downsample(),
     AddGaussNoise(0,1e-2)
     ])

target_transform =transforms.Compose(
    [transforms.Grayscale(),
     transforms.ToTensor()     
    ]) 
mnist_superimposed = MNISTsuperimposed("./MNIST data/train", train = True, download = True, transform = transform, target_transform=target_transform)
# Out:
# /opt/conda/lib/python3.8/site-packages/torchvision/datasets/mnist.py:480: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  ../torch/csrc/utils/tensor_numpy.cpp:137.)
#   return torch.from_numpy(parsed.astype(m[2], copy=False)).view(*s)

# %%
from torch.utils.data import DataLoader
batch = 128
trainset = DataLoader(mnist_superimposed, batch_size=batch, shuffle = True)

# %%
def show_images(dataset, training = True):
    
    fig = plt.figure(figsize = (20, 14))
    rows = 3
    columns = 4
    j=0
    for i in range(1,columns*rows+1):
        if i >=1 and i< 5:
            fig.add_subplot(rows, columns, i)
            plt.imshow(dataset[i][0].squeeze(0))
        if i >=5 and i < 9:
            fig.add_subplot(rows, columns, i)
            plt.imshow(dataset[i-4][1][0].squeeze(0))
        if i >= 9 and i<13:
            fig.add_subplot(rows, columns, i)
            plt.imshow(dataset[i-8][1][1].squeeze(0))

# %%
show_images(mnist_superimposed)

# %%
import torch
from torch import nn as nn
from torch.nn import Conv2d, ConvTranspose2d, Linear, Sequential, Flatten, ReLU, LeakyReLU, AvgPool2d, MaxPool2d,Dropout

# %%
class AE(nn.Module):
    def __init__(self, inplace = False):
        super(AE,self).__init__()
        
        self.Upsample_1 = nn.Sequential(
            nn.Flatten(start_dim = 2),
            nn.Linear(196, 256),
            nn.Linear(256, 256),
            nn.ReLU(inplace),
            
            nn.Linear(256, 512),
            nn.Linear(512, 784),
            nn.Linear(784, 784),
            nn.ReLU(inplace),
        )
        
            
        self.initial_Processing = nn.Sequential(
            nn.Conv2d(in_channels = 1, out_channels = 64, kernel_size = 3, padding = 1, stride = 1),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace),
            nn.Conv2d(in_channels = 64, out_channels = 128, kernel_size = 3, padding =1, stride = 1),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace),
        )

        self.Down_1 = nn.Sequential(
            nn.Conv2d(in_channels = 128, out_channels = 512, kernel_size = (3, 3), padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.Conv2d(in_channels = 512, out_channels = 512, kernel_size = (3, 3), padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.MaxPool2d(kernel_size = (2, 2)),
        )

        self.Down_2 = nn.Sequential(
            nn.Conv2d(in_channels = 512, out_channels = 256, kernel_size = (3, 3), padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.Conv2d(in_channels = 256, out_channels = 256, kernel_size = (3, 3), padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.MaxPool2d(kernel_size = (2, 2)),
        )


        self.Down_3 = nn.Sequential(
            nn.Conv2d(in_channels = 256, out_channels = 128, kernel_size = (3, 3), padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.Conv2d(in_channels = 128, out_channels = 128, kernel_size = (3, 3), padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.MaxPool2d(kernel_size = (2, 2)),
        )

        self.Down_4 = nn.Sequential(
            nn.Conv2d(in_channels = 128, out_channels = 64, kernel_size = (3, 3), padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.Conv2d(in_channels = 64, out_channels = 64, kernel_size = (3, 3), padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.MaxPool2d(kernel_size = (2, 2)),
        )

        self.Up_1 = nn.Sequential(
            nn.Conv2d(in_channels = 64, out_channels = 64, kernel_size = (3, 3), padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.Conv2d(in_channels = 64, out_channels = 32, kernel_size = (3, 3), padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.ConvTranspose2d(in_channels = 32, out_channels = 64, kernel_size = (2, 2))
        )

        self.Up_2 = nn.Sequential(
            nn.Conv2d(in_channels = 128, out_channels = 128, kernel_size = (3, 3), padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.Conv2d(in_channels = 128, out_channels = 64, kernel_size = (3, 3), padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.ConvTranspose2d(in_channels = 64, out_channels = 128, kernel_size = (2, 2))
        )

        self.Up_3 = nn.Sequential(
            nn.Conv2d(in_channels = 256, out_channels = 256, kernel_size = (3, 3), padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.Conv2d(in_channels = 256, out_channels = 128, kernel_size = (3, 3), padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.ConvTranspose2d(in_channels = 128, out_channels = 256, kernel_size = (2, 2))
        )

        self.Up_4 = nn.Sequential(
            nn.Conv2d(in_channels = 512, out_channels = 512, kernel_size = (3, 3), padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.Conv2d(in_channels = 512, out_channels = 256, kernel_size = (3, 3), padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.ConvTranspose2d(in_channels = 256, out_channels = 512, kernel_size = (2, 2))
        )

        self.Up_5 = nn.Sequential(
            nn.Conv2d(in_channels = 1024, out_channels = 512, kernel_size = (3, 3), padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.Conv2d(in_channels = 512, out_channels = 512, kernel_size = (3, 3), padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.ConvTranspose2d(in_channels = 512, out_channels = 2, kernel_size = (1, 1))
        )
        
        self.Upsample_2 = nn.Sequential(
            nn.Flatten(start_dim = 1),
            nn.Linear(392, 512),
            nn.Linear(512, 512),
            nn.ReLU(inplace),
            
            nn.Linear(512, 1024),
            nn.Linear(1024, 1568),
            nn.Linear(1568, 1568),
            nn.Sigmoid(),
        )
        
    def forward(self, x):
        
        #First Dip
        output = self.Upsample_1(x)
        output = output.reshape(output.shape[0], 1, 28, 28)
        
        output = self.initial_Processing(output)
        
        output = self.Down_1(output)
        output_1 = output
        
        
        output = self.Down_2(output)
        output_2 = output
        
        output = self.Down_3(output)
        output_3 = output
        
        output = self.Down_4(output)
        output_4 = output
        
        
        
        
        output = self.Up_1(output)
        diffY = output_4.size()[2] - output.size()[2]
        diffX = output_4.size()[3] - output.size()[3]
        output = F.pad(output, [diffX // 2, diffX - diffX // 2,
                        diffY // 2, diffY - diffY // 2])
        output = torch.cat([output_4, output], dim=1)
        

        output = self.Up_2(output)
        diffY = output_3.size()[2] - output.size()[2]
        diffX = output_3.size()[3] - output.size()[3]
        output = F.pad(output, [diffX // 2, diffX - diffX // 2,
                        diffY // 2, diffY - diffY // 2])
        output = torch.cat([output_3, output], dim=1)


        output = self.Up_3(output)        
        diffY = output_2.size()[2] - output.size()[2]
        diffX = output_2.size()[3] - output.size()[3]
        output = F.pad(output, [diffX // 2, diffX - diffX // 2,
                        diffY // 2, diffY - diffY // 2])
        output = torch.cat([output_2, output], dim=1)


        output = self.Up_4(output)
        diffY = output_1.size()[2] - output.size()[2]
        diffX = output_1.size()[3] - output.size()[3]
        output = F.pad(output, [diffX // 2, diffX - diffX // 2,
                        diffY // 2, diffY - diffY // 2])
        output = torch.cat([output_1, output], dim=1)


        output = self.Up_5(output)

        
        output = self.Upsample_2[:2](output)
        output = self.Upsample_2[3:6](output + self.Upsample_2[2](output))
        output = self.Upsample_2[7](output + self.Upsample_2[6](output))
        
                
        return output

# %%
device = torch.device('cuda') if torch.cuda.is_available else torch.device('cpu')
AEnet = AE(inplace = True).cuda()

# %%
optimizer = torch.optim.Adam(AEnet.parameters(), lr=0.000085)
criterion = nn.MSELoss()
print(device)
# Out:
# cuda

# %%
len(trainset)
# Out:
# 469

# %%
def train_test(AEnet, dataset, Training = True):

    if Training:
        epochs = 100
        train_loss = []
        t_loss = []
        flag = True
        for epoch in range(epochs):
            running_loss = 0.0
            for i, data in enumerate(dataset):
                optimizer.zero_grad()
                outputs = AEnet(data[0].float().to(device))
                output_1 = outputs[:, :784]
                output_2 = outputs[:, 784:]
                loss = criterion(output_1.float().to(device), torch.flatten(data[1][0],1).float().to(device)) + criterion(output_2.float().to(device), torch.flatten(data[1][1],1).float().to(device))
                loss.backward()
                optimizer.step()
                train_loss.append(loss.item())
                running_loss += loss.item()
                if i % 100 == 99:
                    print('[%d, %5d] loss per image: %.6f' %
                          (epoch + 1, i + 1, loss.item()/32))
                    t_loss.append(loss.item()/32)
                    if epoch % 10 == 9:
                        torch.save(AEnet.state_dict(), "./weights.pth")
                
            

            
        print("The lowest was: ", min(train_loss)/32)

        print('Finished Training')
        flag = False
        return outputs, data, t_loss
            
    else:
        testing_loss = []
        t_loss = []
        for i, data in enumerate(dataset):
                optimizer.zero_grad()
                outputs = AEnet(data[0].float().to(device))
                output_1 = outputs[:, :784]
                output_2 = outputs[:, 784:]
                loss = criterion(output_1.float().to(device), torch.flatten(data[1][0],1).float().to(device)) + criterion(output_2.float().to(device), torch.flatten(data[1][1],1).float().to(device))
                testing_loss.append(loss.item())
                if i % 10 == 9:
                    print('[%5d] loss per image: %.6f' %
                          (i + 1, loss.item()/32))
                    t_loss.append(loss.item()/32)
                    
        print("The lowest was: ", min(testing_loss)/32)
        print('Finished Testing')
        return outputs, data, t_loss

# %%
output, data, training_loss= train_test(AEnet, trainset)
# Out:
# [1,   100] loss per image: 0.003866
# [1,   200] loss per image: 0.003499
# [1,   300] loss per image: 0.003450
# [1,   400] loss per image: 0.003172
# [2,   100] loss per image: 0.003157
# [2,   200] loss per image: 0.003121
# [2,   300] loss per image: 0.003087
# [2,   400] loss per image: 0.003088
# [3,   100] loss per image: 0.003087
# [3,   200] loss per image: 0.002978
# [3,   300] loss per image: 0.003036
# [3,   400] loss per image: 0.002961
# [4,   100] loss per image: 0.003026
# [4,   200] loss per image: 0.002866
# [4,   300] loss per image: 0.003029
# [4,   400] loss per image: 0.002904
# [5,   100] loss per image: 0.002847
# [5,   200] loss per image: 0.002916
# [5,   300] loss per image: 0.002846
# [5,   400] loss per image: 0.002845
# [6,   100] loss per image: 0.002942
# [6,   200] loss per image: 0.002832
# [6,   300] loss per image: 0.003006
# [6,   400] loss per image: 0.002767
# [7,   100] loss per image: 0.002764
# [7,   200] loss per image: 0.002840
# [7,   300] loss per image: 0.002749
# [7,   400] loss per image: 0.002949
# [8,   100] loss per image: 0.002882
# [8,   200] loss per image: 0.002759
# [8,   300] loss per image: 0.002778
# [8,   400] loss per image: 0.002804
# [9,   100] loss per image: 0.002821
# [9,   200] loss per image: 0.002863
# [9,   300] loss per image: 0.002869
# [9,   400] loss per image: 0.002773
# [10,   100] loss per image: 0.002806
# [10,   200] loss per image: 0.002788
# [10,   300] loss per image: 0.002849
# [10,   400] loss per image: 0.002816
# [11,   100] loss per image: 0.002798
# [11,   200] loss per image: 0.002757
# [11,   300] loss per image: 0.002759
# [11,   400] loss per image: 0.002818
# [12,   100] loss per image: 0.002786
# [12,   200] loss per image: 0.002776
# [12,   300] loss per image: 0.002691
# [12,   400] loss per image: 0.002669
# [13,   100] loss per image: 0.002810
# [13,   200] loss per image: 0.002758
# [13,   300] loss per image: 0.002643
# [13,   400] loss per image: 0.002760
# [14,   100] loss per image: 0.002694
# [14,   200] loss per image: 0.002738
# [14,   300] loss per image: 0.002671
# [14,   400] loss per image: 0.002781
# [15,   100] loss per image: 0.002632
# [15,   200] loss per image: 0.002701
# [15,   300] loss per image: 0.002606
# [15,   400] loss per image: 0.002812
# [16,   100] loss per image: 0.002611
# [16,   200] loss per image: 0.002684
# [16,   300] loss per image: 0.002703
# [16,   400] loss per image: 0.002720
# [17,   100] loss per image: 0.002715
# [17,   200] loss per image: 0.002646
# [17,   300] loss per image: 0.002687
# [17,   400] loss per image: 0.002713
# [18,   100] loss per image: 0.002657
# [18,   200] loss per image: 0.002721
# [18,   300] loss per image: 0.002780
# [18,   400] loss per image: 0.002658
# [19,   100] loss per image: 0.002644
# [19,   200] loss per image: 0.002639
# [19,   300] loss per image: 0.002709
# [19,   400] loss per image: 0.002619
# [20,   100] loss per image: 0.002686
# [20,   200] loss per image: 0.002680
# [20,   300] loss per image: 0.002599
# [20,   400] loss per image: 0.002645
# [21,   100] loss per image: 0.002548
# [21,   200] loss per image: 0.002610
# [21,   300] loss per image: 0.002527
# [21,   400] loss per image: 0.002608
# [22,   100] loss per image: 0.002496
# [22,   200] loss per image: 0.002468
# [22,   300] loss per image: 0.002521
# [22,   400] loss per image: 0.002505
# [23,   100] loss per image: 0.002337
# [23,   200] loss per image: 0.002496
# [23,   300] loss per image: 0.002457
# [23,   400] loss per image: 0.002423
# [24,   100] loss per image: 0.002361
# [24,   200] loss per image: 0.002335
# [24,   300] loss per image: 0.002344
# [24,   400] loss per image: 0.002533
# [25,   100] loss per image: 0.002309
# [25,   200] loss per image: 0.002315
# [25,   300] loss per image: 0.002288
# [25,   400] loss per image: 0.002232
# [26,   100] loss per image: 0.002211
# [26,   200] loss per image: 0.002210
# [26,   300] loss per image: 0.002261
# [26,   400] loss per image: 0.002383
# [27,   100] loss per image: 0.002245
# [27,   200] loss per image: 0.002140
# [27,   300] loss per image: 0.002093
# [27,   400] loss per image: 0.002233
# [28,   100] loss per image: 0.002148
# [28,   200] loss per image: 0.002233
# [28,   300] loss per image: 0.002124
# [28,   400] loss per image: 0.002143
# [29,   100] loss per image: 0.001982
# [29,   200] loss per image: 0.002045
# [29,   300] loss per image: 0.002053
# [29,   400] loss per image: 0.002117
# [30,   100] loss per image: 0.002060
# [30,   200] loss per image: 0.001996
# [30,   300] loss per image: 0.001881
# [30,   400] loss per image: 0.002081
# [31,   100] loss per image: 0.001901
# [31,   200] loss per image: 0.002020
# [31,   300] loss per image: 0.002130
# [31,   400] loss per image: 0.002048
# [32,   100] loss per image: 0.001811
# [32,   200] loss per image: 0.002000
# [32,   300] loss per image: 0.001916
# [32,   400] loss per image: 0.001935
# [33,   100] loss per image: 0.001936
# [33,   200] loss per image: 0.001909
# [33,   300] loss per image: 0.001839
# [33,   400] loss per image: 0.001919
# [34,   100] loss per image: 0.001928
# [34,   200] loss per image: 0.001947
# [34,   300] loss per image: 0.001840
# [34,   400] loss per image: 0.001898
# [35,   100] loss per image: 0.001876
# [35,   200] loss per image: 0.001865
# [35,   300] loss per image: 0.001840
# [35,   400] loss per image: 0.001770
# [36,   100] loss per image: 0.001709
# [36,   200] loss per image: 0.001768
# [36,   300] loss per image: 0.001829
# [36,   400] loss per image: 0.001804
# [37,   100] loss per image: 0.001707
# [37,   200] loss per image: 0.001758
# [37,   300] loss per image: 0.001808
# [37,   400] loss per image: 0.001888
# [38,   100] loss per image: 0.001723
# [38,   200] loss per image: 0.001822
# [38,   300] loss per image: 0.001824
# [38,   400] loss per image: 0.001886
# [39,   100] loss per image: 0.001842
# [39,   200] loss per image: 0.001782
# [39,   300] loss per image: 0.001778
# [39,   400] loss per image: 0.001763
# [40,   100] loss per image: 0.001624
# [40,   200] loss per image: 0.001730
# [40,   300] loss per image: 0.001720
# [40,   400] loss per image: 0.001684
# [41,   100] loss per image: 0.001654
# [41,   200] loss per image: 0.001715
# [41,   300] loss per image: 0.001719
# [41,   400] loss per image: 0.001741
# [42,   100] loss per image: 0.001680
# [42,   200] loss per image: 0.001746
# [42,   300] loss per image: 0.001679
# [42,   400] loss per image: 0.001621
# [43,   100] loss per image: 0.001697
# [43,   200] loss per image: 0.001688
# [43,   300] loss per image: 0.001695
# [43,   400] loss per image: 0.001721
# [44,   100] loss per image: 0.001584
# [44,   200] loss per image: 0.001633
# [44,   300] loss per image: 0.001620
# [44,   400] loss per image: 0.001667
# [45,   100] loss per image: 0.001764
# [45,   200] loss per image: 0.001587
# [45,   300] loss per image: 0.001811
# [45,   400] loss per image: 0.001651
# [46,   100] loss per image: 0.001527
# [46,   200] loss per image: 0.001606
# [46,   300] loss per image: 0.001661
# [46,   400] loss per image: 0.001683
# [47,   100] loss per image: 0.001608
# [47,   200] loss per image: 0.001553
# [47,   300] loss per image: 0.001586
# [47,   400] loss per image: 0.001543
# [48,   100] loss per image: 0.001543
# [48,   200] loss per image: 0.001556
# [48,   300] loss per image: 0.001552
# [48,   400] loss per image: 0.001553
# [49,   100] loss per image: 0.001531
# [49,   200] loss per image: 0.001588
# [49,   300] loss per image: 0.001595
# [49,   400] loss per image: 0.001601
# [50,   100] loss per image: 0.001541
# [50,   200] loss per image: 0.001570
# [50,   300] loss per image: 0.001577
# [50,   400] loss per image: 0.001457
# [51,   100] loss per image: 0.001464
# [51,   200] loss per image: 0.001448
# [51,   300] loss per image: 0.001538
# [51,   400] loss per image: 0.001514
# [52,   100] loss per image: 0.001418
# [52,   200] loss per image: 0.001406
# [52,   300] loss per image: 0.001522
# [52,   400] loss per image: 0.001621
# [53,   100] loss per image: 0.001541
# [53,   200] loss per image: 0.001521
# [53,   300] loss per image: 0.001554
# [53,   400] loss per image: 0.001531
# [54,   100] loss per image: 0.001523
# [54,   200] loss per image: 0.001424
# [54,   300] loss per image: 0.001463
# [54,   400] loss per image: 0.001469
# [55,   100] loss per image: 0.001442
# [55,   200] loss per image: 0.001486
# [55,   300] loss per image: 0.001466
# [55,   400] loss per image: 0.001563
# [56,   100] loss per image: 0.001423
# [56,   200] loss per image: 0.001527
# [56,   300] loss per image: 0.001425
# [56,   400] loss per image: 0.001431
# [57,   100] loss per image: 0.001518
# [57,   200] loss per image: 0.001480
# [57,   300] loss per image: 0.001400
# [57,   400] loss per image: 0.001417
# [58,   100] loss per image: 0.001361
# [58,   200] loss per image: 0.001450
# [58,   300] loss per image: 0.001472
# [58,   400] loss per image: 0.001466
# [59,   100] loss per image: 0.001384
# [59,   200] loss per image: 0.001418
# [59,   300] loss per image: 0.001367
# [59,   400] loss per image: 0.001400
# [60,   100] loss per image: 0.001429
# [60,   200] loss per image: 0.001384
# [60,   300] loss per image: 0.001416
# [60,   400] loss per image: 0.001480
# [61,   100] loss per image: 0.001350
# [61,   200] loss per image: 0.001393
# [61,   300] loss per image: 0.001404
# [61,   400] loss per image: 0.001374
# [62,   100] loss per image: 0.001412
# [62,   200] loss per image: 0.001404
# [62,   300] loss per image: 0.001334
# [62,   400] loss per image: 0.001446
# [63,   100] loss per image: 0.001359
# [63,   200] loss per image: 0.001382
# [63,   300] loss per image: 0.001345
# [63,   400] loss per image: 0.001456
# [64,   100] loss per image: 0.001408
# [64,   200] loss per image: 0.001425
# [64,   300] loss per image: 0.001415
# [64,   400] loss per image: 0.001328
# [65,   100] loss per image: 0.001330
# [65,   200] loss per image: 0.001328
# [65,   300] loss per image: 0.001384
# [65,   400] loss per image: 0.001417
# [66,   100] loss per image: 0.001359
# [66,   200] loss per image: 0.001414
# [66,   300] loss per image: 0.001418
# [66,   400] loss per image: 0.001411
# [67,   100] loss per image: 0.001342
# [67,   200] loss per image: 0.001352
# [67,   300] loss per image: 0.001367
# [67,   400] loss per image: 0.001394
# [68,   100] loss per image: 0.001318
# [68,   200] loss per image: 0.001398
# [68,   300] loss per image: 0.001408
# [68,   400] loss per image: 0.001331
# [69,   100] loss per image: 0.001380
# [69,   200] loss per image: 0.001319
# [69,   300] loss per image: 0.001335
# [69,   400] loss per image: 0.001339
# [70,   100] loss per image: 0.001315
# [70,   200] loss per image: 0.001339
# [70,   300] loss per image: 0.001388
# [70,   400] loss per image: 0.001342
# [71,   100] loss per image: 0.001343
# [71,   200] loss per image: 0.001309
# [71,   300] loss per image: 0.001325
# [71,   400] loss per image: 0.001369
# [72,   100] loss per image: 0.001315
# [72,   200] loss per image: 0.001328
# [72,   300] loss per image: 0.001361
# [72,   400] loss per image: 0.001427
# [73,   100] loss per image: 0.001297
# [73,   200] loss per image: 0.001299
# [73,   300] loss per image: 0.001304
# [73,   400] loss per image: 0.001367
# [74,   100] loss per image: 0.001279
# [74,   200] loss per image: 0.001311
# [74,   300] loss per image: 0.001299
# [74,   400] loss per image: 0.001328
# [75,   100] loss per image: 0.001256
# [75,   200] loss per image: 0.001290
# [75,   300] loss per image: 0.001286
# [75,   400] loss per image: 0.001271
# [76,   100] loss per image: 0.001254
# [76,   200] loss per image: 0.001289
# [76,   300] loss per image: 0.001281
# [76,   400] loss per image: 0.001227
# [77,   100] loss per image: 0.001205
# [77,   200] loss per image: 0.001239
# [77,   300] loss per image: 0.001267
# [77,   400] loss per image: 0.001190
# [78,   100] loss per image: 0.001286
# [78,   200] loss per image: 0.001258
# [78,   300] loss per image: 0.001284
# [78,   400] loss per image: 0.001319
# [79,   100] loss per image: 0.001263
# [79,   200] loss per image: 0.001273
# [79,   300] loss per image: 0.001241
# [79,   400] loss per image: 0.001284
# [80,   100] loss per image: 0.001243
# [80,   200] loss per image: 0.001211
# [80,   300] loss per image: 0.001230
# [80,   400] loss per image: 0.001300
# [81,   100] loss per image: 0.001254
# [81,   200] loss per image: 0.001253
# [81,   300] loss per image: 0.001255
# [81,   400] loss per image: 0.001193
# [82,   100] loss per image: 0.001209
# [82,   200] loss per image: 0.001184
# [82,   300] loss per image: 0.001251
# [82,   400] loss per image: 0.001311
# [83,   100] loss per image: 0.001187
# [83,   200] loss per image: 0.001238
# [83,   300] loss per image: 0.001188
# [83,   400] loss per image: 0.001194
# [84,   100] loss per image: 0.001189
# [84,   200] loss per image: 0.001206
# [84,   300] loss per image: 0.001201
# [84,   400] loss per image: 0.001178
# [85,   100] loss per image: 0.001221
# [85,   200] loss per image: 0.001228
# [85,   300] loss per image: 0.001155
# [85,   400] loss per image: 0.001282
# [86,   100] loss per image: 0.001233
# [86,   200] loss per image: 0.001222
# [86,   300] loss per image: 0.001171
# [86,   400] loss per image: 0.001238
# [87,   100] loss per image: 0.001212
# [87,   200] loss per image: 0.001212
# [87,   300] loss per image: 0.001134
# [87,   400] loss per image: 0.001253
# [88,   100] loss per image: 0.001177
# [88,   200] loss per image: 0.001191
# [88,   300] loss per image: 0.001235
# [88,   400] loss per image: 0.001232
# [89,   100] loss per image: 0.001213
# [89,   200] loss per image: 0.001117
# [89,   300] loss per image: 0.001134
# [89,   400] loss per image: 0.001260
# [90,   100] loss per image: 0.001235
# [90,   200] loss per image: 0.001068
# [90,   300] loss per image: 0.001230
# [90,   400] loss per image: 0.001196
# [91,   100] loss per image: 0.001172
# [91,   200] loss per image: 0.001149
# [91,   300] loss per image: 0.001158
# [91,   400] loss per image: 0.001167
# [92,   100] loss per image: 0.001170
# [92,   200] loss per image: 0.001139
# [92,   300] loss per image: 0.001198
# [92,   400] loss per image: 0.001144
# [93,   100] loss per image: 0.001165
# [93,   200] loss per image: 0.001149
# [93,   300] loss per image: 0.001172
# [93,   400] loss per image: 0.001195
# [94,   100] loss per image: 0.001088
# [94,   200] loss per image: 0.001118
# [94,   300] loss per image: 0.001183
# [94,   400] loss per image: 0.001181
# [95,   100] loss per image: 0.001138
# [95,   200] loss per image: 0.001111
# [95,   300] loss per image: 0.001189
# [95,   400] loss per image: 0.001129
# [96,   100] loss per image: 0.001120
# [96,   200] loss per image: 0.001159
# [96,   300] loss per image: 0.001172
# [96,   400] loss per image: 0.001178
# [97,   100] loss per image: 0.001176
# [97,   200] loss per image: 0.001221
# [97,   300] loss per image: 0.001109
# [97,   400] loss per image: 0.001093
# [98,   100] loss per image: 0.001157
# [98,   200] loss per image: 0.001142
# [98,   300] loss per image: 0.001133
# [98,   400] loss per image: 0.001145
# [99,   100] loss per image: 0.001101
# [99,   200] loss per image: 0.001167
# [99,   300] loss per image: 0.001097
# [99,   400] loss per image: 0.001185
# [100,   100] loss per image: 0.001142
# [100,   200] loss per image: 0.001091
# [100,   300] loss per image: 0.001129
# [100,   400] loss per image: 0.001226
# The lowest was:  0.0009935481939464808
# Finished Training

# %%
def plot_loss(loss, train = True):
    fig = plt.figure(figsize = (10, 7))
    
    
    if(train):
        x = list(np.arange(0.0, 100.0, 0.25))
        plt.axis("on")
        plt.ylabel('Loss')
        plt.xlabel('Epoch')
        plt.title("Training Loss")
        plt.plot(x, loss)
    else:
        x = list(np.arange(0.0, 7.0, 1.0))
        plt.axis("on")
        plt.ylabel('Loss')
        plt.xlabel('Epoch')
        plt.title("Testing Loss")
        plt.plot(x, loss)

# %%
plot_loss(training_loss)

# %%
#Print only the output images
def show_output_images(dataset, outputs, training = True):
    
    fig = plt.figure(figsize = (20, 14))
    rows = 5
    columns = 4
    j=0
    for i in range(1,columns*rows+1):
        if training:
            
            
            if i >=1 and i< 5:
                fig.add_subplot(rows, columns, i)
                plt.axis('off')
                plt.imshow(dataset[0][i].squeeze(0), cmap = 'gray')
            if i >=5 and i< 9:
                fig.add_subplot(rows, columns, i)
                plt.axis('off')
                plt.imshow(outputs[i-4][:784].cpu().detach().numpy().reshape(28,28), cmap='gray')
            if i >=9 and i < 13:
                fig.add_subplot(rows, columns, i)
                plt.axis('off')
                plt.imshow(outputs[i-8][784:].cpu().detach().numpy().reshape(28,28), cmap='gray')
            if i >=13 and i < 17:
                fig.add_subplot(rows, columns, i)
                plt.axis('off')
                plt.imshow(dataset[1][0][i-12].cpu().detach().numpy().reshape(28,28), cmap='gray')
            if i >=17 and i < 21:    
                fig.add_subplot(rows, columns, i)
                plt.axis('off')
                plt.imshow(dataset[1][1][i - 16].cpu().detach().numpy().reshape(28,28), cmap='gray')
        else:
            if i >=1 and i< 5:
                fig.add_subplot(rows, columns, i)
                plt.axis('off')
                plt.imshow(dataset[0][i].squeeze(0), cmap = 'gray')
            if i >=5 and i< 9:
                fig.add_subplot(rows, columns, i)
                plt.axis('off')
                plt.imshow(outputs[i-4][:784].cpu().detach().numpy().reshape(28,28), cmap='gray')
            if i >=9 and i < 13:
                fig.add_subplot(rows, columns, i)
                plt.axis('off')
                plt.imshow(outputs[i-8][784:].cpu().detach().numpy().reshape(28,28), cmap='gray')
            if i >=13 and i < 17:
                fig.add_subplot(rows, columns, i)
                plt.axis('off')
                plt.imshow(dataset[1][0][i-12].cpu().detach().numpy().reshape(28,28), cmap='gray')
            if i >=17 and i < 21:    
                fig.add_subplot(rows, columns, i)
                plt.axis('off')
                plt.imshow(dataset[1][1][i - 16].cpu().detach().numpy().reshape(28,28), cmap='gray')

# %%
show_output_images(data, output)

# %%
testing_superimposed = MNISTsuperimposed("./MNIST data/train", train = False, download = True, transform = transform, target_transform=target_transform)
testset = DataLoader(testing_superimposed, batch_size=128, shuffle = False)
outputs, test_data, test_loss = train_test(AEnet, testset, False)
# Out:
# [   10] loss per image: 0.003596
# [   20] loss per image: 0.003513
# [   30] loss per image: 0.003582
# [   40] loss per image: 0.003778
# [   50] loss per image: 0.003501
# [   60] loss per image: 0.003112
# [   70] loss per image: 0.003439
# The lowest was:  0.002813220489770174
# Finished Testing

# %%
show_output_images(test_data, outputs, False)

# %%
plot_loss(test_loss, False)

# %% [markdown]
# # Architectures #

# %% [markdown]
#  ## Original Reversed ##

# %%
# class AE(nn.Module):
#     def __init__(self, inplace = False):
#         super(AE,self).__init__()
        
#         self.Upsample_1 = nn.Sequential(
#             nn.Flatten(start_dim = 2),
#             nn.Linear(196, 256),
#             nn.Linear(256, 256),
#             nn.ReLU(inplace),
            
#             nn.Linear(256, 512),
#             nn.Linear(512, 784),
#             nn.Linear(784, 784),
#             nn.ReLU(inplace),
#         )
        
            
#         self.initial_Processing = nn.Sequential(
#             nn.Conv2d(in_channels = 1, out_channels = 8, kernel_size = 3, padding = 1, stride = 1),
#             nn.BatchNorm2d(8),
#             nn.ReLU(inplace),
#             nn.Conv2d(in_channels = 8, out_channels = 64, kernel_size = 3, padding =1, stride = 1),
#             nn.BatchNorm2d(64),
#             nn.ReLU(inplace),
#         )

#         self.Down_1 = nn.Sequential(
#             nn.Conv2d(in_channels = 64, out_channels = 1024, kernel_size = (3, 3), padding = 1, stride = 1),
#             nn.ReLU(inplace),
#             nn.Conv2d(in_channels = 1024, out_channels = 1024, kernel_size = (3, 3), padding = 1, stride = 1),
#             nn.ReLU(inplace),
#             nn.MaxPool2d(kernel_size = (2, 2)),
#         )

#         self.Down_2 = nn.Sequential(
#             nn.Conv2d(in_channels = 1024, out_channels = 512, kernel_size = (3, 3), padding = 1, stride = 1),
#             nn.ReLU(inplace),
#             nn.Conv2d(in_channels = 512, out_channels = 512, kernel_size = (3, 3), padding = 1, stride = 1),
#             nn.Dropout(0.1),
#             nn.ReLU(inplace),
#             nn.MaxPool2d(kernel_size = (2, 2)),
#         )


#         self.Down_3 = nn.Sequential(
#             nn.Conv2d(in_channels = 512, out_channels = 256, kernel_size = (3, 3), padding = 1, stride = 1),
#             nn.ReLU(inplace),
#             nn.Conv2d(in_channels = 256, out_channels = 256, kernel_size = (3, 3), padding = 1, stride = 1),
#             nn.Dropout(0.1),
#             nn.ReLU(inplace),
#             nn.MaxPool2d(kernel_size = (2, 2)),
#         )

#         self.Down_4 = nn.Sequential(
#             nn.Conv2d(in_channels = 256, out_channels = 128, kernel_size = (3, 3), padding = 1, stride = 1),
#             nn.ReLU(inplace),
#             nn.Conv2d(in_channels = 128, out_channels = 128, kernel_size = (3, 3), padding = 1, stride = 1),
#             nn.ReLU(inplace),
#             nn.MaxPool2d(kernel_size = (2, 2)),
#         )

#         self.Up_1 = nn.Sequential(
#             nn.Conv2d(in_channels = 128, out_channels = 64, kernel_size = (3, 3), padding = 1, stride = 1),
#             nn.ReLU(inplace),
#             nn.Conv2d(in_channels = 64, out_channels = 128, kernel_size = (3, 3), padding = 1, stride = 1),
#             nn.Dropout(0.1),
#             nn.ReLU(inplace),
#             nn.ConvTranspose2d(in_channels = 128, out_channels = 128, kernel_size = (2, 2))
#         )

#         self.Up_2 = nn.Sequential(
#             nn.Conv2d(in_channels = 256, out_channels = 128, kernel_size = (3, 3), padding = 1, stride = 1),
#             nn.ReLU(inplace),
#             nn.Conv2d(in_channels = 128, out_channels = 256, kernel_size = (3, 3), padding = 1, stride = 1),
#             nn.ReLU(inplace),
#             nn.ConvTranspose2d(in_channels = 256, out_channels = 256, kernel_size = (2, 2))
#         )

#         self.Up_3 = nn.Sequential(
#             nn.Conv2d(in_channels = 512, out_channels = 256, kernel_size = (3, 3), padding = 1, stride = 1),
#             nn.ReLU(inplace),
#             nn.Conv2d(in_channels = 256, out_channels = 512, kernel_size = (3, 3), padding = 1, stride = 1),
#             nn.Dropout(0.1),
#             nn.ReLU(inplace),
#             nn.ConvTranspose2d(in_channels = 512, out_channels = 512, kernel_size = (2, 2))
#         )

#         self.Up_4 = nn.Sequential(
#             nn.Conv2d(in_channels = 1024, out_channels = 512, kernel_size = (3, 3), padding = 1, stride = 1),
#             nn.ReLU(inplace),
#             nn.Conv2d(in_channels = 512, out_channels = 1024, kernel_size = (3, 3), padding = 1, stride = 1),
#             nn.ReLU(inplace),
#             nn.ConvTranspose2d(in_channels = 1024, out_channels = 1024, kernel_size = (2, 2))
#         )

#         self.Up_5 = nn.Sequential(
#             nn.Conv2d(in_channels = 2048, out_channels = 1024, kernel_size = (3, 3), padding = 1, stride = 1),
#             nn.ReLU(inplace),
#             nn.Conv2d(in_channels = 1024, out_channels = 1024, kernel_size = (3, 3), padding = 1, stride = 1),
#             nn.Dropout(0.25),
#             nn.ReLU(inplace),
#             nn.ConvTranspose2d(in_channels = 1024, out_channels = 2, kernel_size = (1, 1))
#         )
        
        
        
        
        
#         self.Upsample_2 = nn.Sequential(
#             nn.Flatten(start_dim = 1),
#             nn.Linear(392, 512),
#             nn.Linear(512, 512),
#             nn.ReLU(inplace),
            
#             nn.Linear(512, 1024),
#             nn.Linear(1024, 1568),
#             nn.Linear(1568, 1568),
#             nn.Sigmoid(),
#         )
        
#     def forward(self, x):
        
#         output = self.Upsample_1(x)
#         output = output.reshape(output.shape[0], 1, 28, 28)
        
#         output = self.initial_Processing(output)
        
#         output = self.Down_1(output)
#         output_1 = output
        
        
#         output = self.Down_2(output)
#         output_2 = output
        
#         output = self.Down_3(output)
#         output_3 = output
        
#         output = self.Down_4(output)
#         output_4 = output
        
        
        
        
#         output = self.Up_1(output)
#         diffY = output_4.size()[2] - output.size()[2]
#         diffX = output_4.size()[3] - output.size()[3]
#         output = F.pad(output, [diffX // 2, diffX - diffX // 2,
#                         diffY // 2, diffY - diffY // 2])
#         output = torch.cat([output_4, output], dim=1)
        

#         output = self.Up_2(output)
#         diffY = output_3.size()[2] - output.size()[2]
#         diffX = output_3.size()[3] - output.size()[3]
#         output = F.pad(output, [diffX // 2, diffX - diffX // 2,
#                         diffY // 2, diffY - diffY // 2])
#         output = torch.cat([output_3, output], dim=1)


#         output = self.Up_3(output)        
#         diffY = output_2.size()[2] - output.size()[2]
#         diffX = output_2.size()[3] - output.size()[3]
#         output = F.pad(output, [diffX // 2, diffX - diffX // 2,
#                         diffY // 2, diffY - diffY // 2])
#         output = torch.cat([output_2, output], dim=1)


#         output = self.Up_4(output)
#         diffY = output_1.size()[2] - output.size()[2]
#         diffX = output_1.size()[3] - output.size()[3]
#         output = F.pad(output, [diffX // 2, diffX - diffX // 2,
#                         diffY // 2, diffY - diffY // 2])
#         output = torch.cat([output_1, output], dim=1)


#         output = self.Up_5(output)

        
#         output = self.Upsample_2(output)        
#         return output

# %% [markdown]
# ## SEcond UNET Layer (W-NET)

# %%
# class AE(nn.Module):
#     def __init__(self, inplace = False):
#         super(AE,self).__init__()
        
#         self.Upsample_1 = nn.Sequential(
#             nn.Flatten(start_dim = 2),
#             nn.Linear(196, 256),
#             nn.Linear(256, 256),
#             nn.ReLU(inplace),
            
#             nn.Linear(256, 512),
#             nn.Linear(512, 784),
#             nn.Linear(784, 784),
#             nn.ReLU(inplace),
#         )
        
            
#         self.initial_Processing = nn.Sequential(
#             nn.Conv2d(in_channels = 1, out_channels = 8, kernel_size = 3, padding = 1, stride = 1),
#             nn.BatchNorm2d(8),
#             nn.ReLU(inplace),
#             nn.Conv2d(in_channels = 8, out_channels = 2, kernel_size = 3, padding =1, stride = 1),
#             nn.BatchNorm2d(2),
#             nn.ReLU(inplace),
#         )

#         self.Down_1 = nn.Sequential(
#             nn.Conv2d(in_channels = 2, out_channels = 4, kernel_size = (3, 3), padding = 1, stride = 1),
#             nn.ReLU(inplace),
#             nn.Conv2d(in_channels = 4, out_channels = 4, kernel_size = (3, 3), padding = 1, stride = 1),
#             nn.ReLU(inplace),
#             nn.MaxPool2d(kernel_size = (2, 2)),
#         )

#         self.Down_2 = nn.Sequential(
#             nn.Conv2d(in_channels = 4, out_channels = 8, kernel_size = (3, 3), padding = 1, stride = 1),
#             nn.ReLU(inplace),
#             nn.Conv2d(in_channels = 8, out_channels = 8, kernel_size = (3, 3), padding = 1, stride = 1),
#             nn.ReLU(inplace),
#             nn.MaxPool2d(kernel_size = (2, 2)),
#         )


#         self.Down_3 = nn.Sequential(
#             nn.Conv2d(in_channels = 8, out_channels = 16, kernel_size = (3, 3), padding = 1, stride = 1),
#             nn.ReLU(inplace),
#             nn.Conv2d(in_channels = 16, out_channels = 16, kernel_size = (3, 3), padding = 1, stride = 1),
#             nn.ReLU(inplace),
#             nn.MaxPool2d(kernel_size = (2, 2)),
#         )

#         self.Down_4 = nn.Sequential(
#             nn.Conv2d(in_channels = 16, out_channels = 32, kernel_size = (3, 3), padding = 1, stride = 1),
#             nn.ReLU(inplace),
#             nn.Conv2d(in_channels = 32, out_channels = 32, kernel_size = (3, 3), padding = 1, stride = 1),
#             nn.ReLU(inplace),
#             nn.MaxPool2d(kernel_size = (2, 2)),
#         )

#         self.Up_1 = nn.Sequential(
#             nn.Conv2d(in_channels = 32, out_channels = 64, kernel_size = (3, 3), padding = 1, stride = 1),
#             nn.ReLU(inplace),
#             nn.Conv2d(in_channels = 64, out_channels = 64, kernel_size = (3, 3), padding = 1, stride = 1),
#             nn.ReLU(inplace),
#             nn.ConvTranspose2d(in_channels = 64, out_channels = 32, kernel_size = (2, 2))
#         )

#         self.Up_2 = nn.Sequential(
#             nn.Conv2d(in_channels = 64, out_channels = 128, kernel_size = (3, 3), padding = 1, stride = 1),
#             nn.ReLU(inplace),
#             nn.Conv2d(in_channels = 128, out_channels = 128, kernel_size = (3, 3), padding = 1, stride = 1),
#             nn.ReLU(inplace),
#             nn.ConvTranspose2d(in_channels = 128, out_channels = 16, kernel_size = (2, 2))
#         )

#         self.Up_3 = nn.Sequential(
#             nn.Conv2d(in_channels = 32, out_channels = 256, kernel_size = (3, 3), padding = 1, stride = 1),
#             nn.ReLU(inplace),
#             nn.Conv2d(in_channels = 256, out_channels = 256, kernel_size = (3, 3), padding = 1, stride = 1),
#             nn.ReLU(inplace),
#             nn.ConvTranspose2d(in_channels = 256, out_channels = 8, kernel_size = (2, 2))
#         )

#         self.Up_4 = nn.Sequential(
#             nn.Conv2d(in_channels = 16, out_channels = 512, kernel_size = (3, 3), padding = 1, stride = 1),
#             nn.ReLU(inplace),
#             nn.Conv2d(in_channels = 512, out_channels = 512, kernel_size = (3, 3), padding = 1, stride = 1),
#             nn.ReLU(inplace),
#             nn.ConvTranspose2d(in_channels = 512, out_channels = 4, kernel_size = (2, 2))
#         )

#         self.Up_5 = nn.Sequential(
#             nn.Conv2d(in_channels = 8, out_channels = 1024, kernel_size = (3, 3), padding = 1, stride = 1),
#             nn.ReLU(inplace),
#             nn.Conv2d(in_channels = 1024, out_channels = 1024, kernel_size = (3, 3), padding = 1, stride = 1),
#             nn.ReLU(inplace),
#             nn.ConvTranspose2d(in_channels = 1024, out_channels = 2, kernel_size = (1, 1))
#         )
        
#         self.Upsample_2 = nn.Sequential(
#             nn.Flatten(start_dim = 1),
#             nn.Linear(392, 512),
#             nn.Linear(512, 512),
#             nn.ReLU(inplace),
            
#             nn.Linear(512, 1024),
#             nn.Linear(1024, 1568),
#             nn.Linear(1568, 1568),
#         )
        
        
#         self.initial_Processing_2 = nn.Sequential(
#             nn.Conv2d(in_channels = 2, out_channels = 8, kernel_size = 3, padding = 1, stride = 1),
#             nn.BatchNorm2d(8),
#             nn.ReLU(inplace),
#             nn.Conv2d(in_channels = 8, out_channels = 16, kernel_size = 3, padding =1, stride = 1),
#             nn.BatchNorm2d(16),
#             nn.ReLU(inplace),
#         )

#         self.Down_5 = nn.Sequential(
#             nn.Conv2d(in_channels = 16, out_channels = 64, kernel_size = (3, 3), padding = 1, stride = 1),
#             nn.ReLU(inplace),
#             nn.Conv2d(in_channels = 64, out_channels = 64, kernel_size = (3, 3), padding = 1, stride = 1),
#             nn.ReLU(inplace),
#             nn.MaxPool2d(kernel_size = (2, 2)),
#         )

#         self.Down_6 = nn.Sequential(
#             nn.Conv2d(in_channels = 64, out_channels = 128, kernel_size = (3, 3), padding = 1, stride = 1),
#             nn.ReLU(inplace),
#             nn.Conv2d(in_channels = 128, out_channels = 128, kernel_size = (3, 3), padding = 1, stride = 1),
#             nn.ReLU(inplace),
#             nn.MaxPool2d(kernel_size = (2, 2)),
#         )


#         self.Down_7 = nn.Sequential(
#             nn.Conv2d(in_channels = 128, out_channels = 256, kernel_size = (3, 3), padding = 1, stride = 1),
#             nn.ReLU(inplace),
#             nn.Conv2d(in_channels = 256, out_channels = 256, kernel_size = (3, 3), padding = 1, stride = 1),
#             nn.ReLU(inplace),
#             nn.MaxPool2d(kernel_size = (2, 2)),
#         )

#         self.Down_8 = nn.Sequential(
#             nn.Conv2d(in_channels = 256, out_channels = 512, kernel_size = (3, 3), padding = 1, stride = 1),
#             nn.ReLU(inplace),
#             nn.Conv2d(in_channels = 512, out_channels = 512, kernel_size = (3, 3), padding = 1, stride = 1),
#             nn.ReLU(inplace),
#             nn.MaxPool2d(kernel_size = (2, 2)),
#         )

#         self.Up_6 = nn.Sequential(
#             nn.Conv2d(in_channels = 512, out_channels = 1024, kernel_size = (3, 3), padding = 1, stride = 1),
#             nn.ReLU(inplace),
#             nn.Conv2d(in_channels = 1024, out_channels = 1024, kernel_size = (3, 3), padding = 1, stride = 1),
#             nn.ReLU(inplace),
#             nn.ConvTranspose2d(in_channels = 1024, out_channels = 512, kernel_size = (2, 2))
#         )

#         self.Up_7 = nn.Sequential(
#             nn.Conv2d(in_channels = 1024, out_channels = 512, kernel_size = (3, 3), padding = 1, stride = 1),
#             nn.ReLU(inplace),
#             nn.Conv2d(in_channels = 512, out_channels = 512, kernel_size = (3, 3), padding = 1, stride = 1),
#             nn.ReLU(inplace),
#             nn.ConvTranspose2d(in_channels = 512, out_channels = 256, kernel_size = (2, 2))
#         )

#         self.Up_8 = nn.Sequential(
#             nn.Conv2d(in_channels = 512, out_channels = 256, kernel_size = (3, 3), padding = 1, stride = 1),
#             nn.ReLU(inplace),
#             nn.Conv2d(in_channels = 256, out_channels = 256, kernel_size = (3, 3), padding = 1, stride = 1),
#             nn.ReLU(inplace),
#             nn.ConvTranspose2d(in_channels = 256, out_channels = 128, kernel_size = (2, 2))
#         )

#         self.Up_9 = nn.Sequential(
#             nn.Conv2d(in_channels = 256, out_channels = 128, kernel_size = (3, 3), padding = 1, stride = 1),
#             nn.ReLU(inplace),
#             nn.Conv2d(in_channels = 128, out_channels = 128, kernel_size = (3, 3), padding = 1, stride = 1),
#             nn.ReLU(inplace),
#             nn.ConvTranspose2d(in_channels = 128, out_channels = 64, kernel_size = (2, 2))
#         )

#         self.Up_10 = nn.Sequential(
#             nn.Conv2d(in_channels = 128, out_channels = 64, kernel_size = (3, 3), padding = 1, stride = 1),
#             nn.ReLU(inplace),
#             nn.Conv2d(in_channels = 64, out_channels = 64, kernel_size = (3, 3), padding = 1, stride = 1),
#             nn.ReLU(inplace),
#             nn.ConvTranspose2d(in_channels = 64, out_channels = 2, kernel_size = (1, 1))
#         )
        
#         self.Upsample_3 = nn.Sequential(
#             nn.Flatten(start_dim = 1),
#             nn.Linear(392, 512),
#             nn.Linear(512, 512),
#             nn.ReLU(inplace),
            
#             nn.Linear(512, 1024),
#             nn.Linear(1024, 1568),
#             nn.Linear(1568, 1568),
#             nn.Sigmoid(),
#         )
        
#     def forward(self, x):
        
#         #First Dip
#         output = self.Upsample_1(x)
#         output = output.reshape(output.shape[0], 1, 28, 28)
        
#         output = self.initial_Processing(output)
        
#         output = self.Down_1(output)
#         output_1 = output
        
        
#         output = self.Down_2(output)
#         output_2 = output
        
#         output = self.Down_3(output)
#         output_3 = output
        
#         output = self.Down_4(output)
#         output_4 = output
        
        
        
        
#         output = self.Up_1(output)
#         diffY = output_4.size()[2] - output.size()[2]
#         diffX = output_4.size()[3] - output.size()[3]
#         output = F.pad(output, [diffX // 2, diffX - diffX // 2,
#                         diffY // 2, diffY - diffY // 2])
#         output = torch.cat([output_4, output], dim=1)
        

#         output = self.Up_2(output)
#         diffY = output_3.size()[2] - output.size()[2]
#         diffX = output_3.size()[3] - output.size()[3]
#         output = F.pad(output, [diffX // 2, diffX - diffX // 2,
#                         diffY // 2, diffY - diffY // 2])
#         output = torch.cat([output_3, output], dim=1)


#         output = self.Up_3(output)        
#         diffY = output_2.size()[2] - output.size()[2]
#         diffX = output_2.size()[3] - output.size()[3]
#         output = F.pad(output, [diffX // 2, diffX - diffX // 2,
#                         diffY // 2, diffY - diffY // 2])
#         output = torch.cat([output_2, output], dim=1)


#         output = self.Up_4(output)
#         diffY = output_1.size()[2] - output.size()[2]
#         diffX = output_1.size()[3] - output.size()[3]
#         output = F.pad(output, [diffX // 2, diffX - diffX // 2,
#                         diffY // 2, diffY - diffY // 2])
#         output = torch.cat([output_1, output], dim=1)


#         output = self.Up_5(output)

        
#         output = self.Upsample_2(output)
        
#         output = output.reshape(output.shape[0], 2, 28, 28)
        
#         #Second Dip
#         output = self.initial_Processing_2(output)
        
#         output = self.Down_5(output)
#         output_1 = output
        
        
#         output = self.Down_6(output)
#         output_2 = output
        
#         output = self.Down_7(output)
#         output_3 = output
        
#         output = self.Down_8(output)
#         output_4 = output
        
#         output = self.Up_6(output)
#         diffY = output_4.size()[2] - output.size()[2]
#         diffX = output_4.size()[3] - output.size()[3]
#         output = F.pad(output, [diffX // 2, diffX - diffX // 2,
#                         diffY // 2, diffY - diffY // 2])
#         output = torch.cat([output_4, output], dim=1)
        

#         output = self.Up_7(output)
#         diffY = output_3.size()[2] - output.size()[2]
#         diffX = output_3.size()[3] - output.size()[3]
#         output = F.pad(output, [diffX // 2, diffX - diffX // 2,
#                         diffY // 2, diffY - diffY // 2])
#         output = torch.cat([output_3, output], dim=1)


#         output = self.Up_8(output)        
#         diffY = output_2.size()[2] - output.size()[2]
#         diffX = output_2.size()[3] - output.size()[3]
#         output = F.pad(output, [diffX // 2, diffX - diffX // 2,
#                         diffY // 2, diffY - diffY // 2])
#         output = torch.cat([output_2, output], dim=1)


#         output = self.Up_9(output)
#         diffY = output_1.size()[2] - output.size()[2]
#         diffX = output_1.size()[3] - output.size()[3]
#         output = F.pad(output, [diffX // 2, diffX - diffX // 2,
#                         diffY // 2, diffY - diffY // 2])
#         output = torch.cat([output_1, output], dim=1)


#         output = self.Up_10(output)

        
#         output = self.Upsample_3(output)
        
#         return output
