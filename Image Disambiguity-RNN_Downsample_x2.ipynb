# %%
import torch as torch
import torchvision as tv
import torch.nn.functional as F
from torchvision import datasets
from torchvision import transforms
import matplotlib.pyplot as plt
import matplotlib.image as image
import cv2 as cv
from PIL import Image
import numpy as np
from torchvision.datasets.vision import VisionDataset
from typing import Any, Callable, Dict, List, Optional, Tuple
import os
import os.path
from torch import nn
from torchvision.datasets.mnist import read_image_file, read_label_file
from torchvision.datasets.utils import download_and_extract_archive, extract_archive, verify_str_arg, check_integrity
from skimage.util import random_noise

# %%
class MNISTsuperimposed(VisionDataset):
    """`MNIST <http://yann.lecun.com/exdb/mnist/>`_ Dataset.

    Args:
        root (string): Root directory of dataset where ``MNIST/processed/training.pt``
            and  ``MNIST/processed/test.pt`` exist.
        train (bool, optional): If True, creates dataset from ``training.pt``,
            otherwise from ``test.pt``.
        download (bool, optional): If true, downloads the dataset from the internet and
            puts it in root directory. If dataset is already downloaded, it is not
            downloaded again.
        transform (callable, optional): A function/transform that  takes in an PIL image
            and returns a transformed version. E.g, ``transforms.RandomCrop``
        target_transform (callable, optional): A function/transform that takes in the
            target and transforms it.
    """

    mirrors = [
        'http://yann.lecun.com/exdb/mnist/',
        'https://ossci-datasets.s3.amazonaws.com/mnist/',
    ]

    resources = [
        ("train-images-idx3-ubyte.gz", "f68b3c2dcbeaaa9fbdd348bbdeb94873"),
        ("train-labels-idx1-ubyte.gz", "d53e105ee54ea40749a09fcbcd1e9432"),
        ("t10k-images-idx3-ubyte.gz", "9fb629c4189551a2d022fa330f9573f3"),
        ("t10k-labels-idx1-ubyte.gz", "ec29112dd5afa0611ce80d1b7f02629c")
    ]

    training_file = 'training.pt'
    test_file = 'test.pt'
    classes = ['0 - zero', '1 - one', '2 - two', '3 - three', '4 - four',
               '5 - five', '6 - six', '7 - seven', '8 - eight', '9 - nine']

    @property
    def train_labels(self):
        warnings.warn("train_labels has been renamed targets")
        return self.targets

    @property
    def test_labels(self):
        warnings.warn("test_labels has been renamed targets")
        return self.targets

    @property
    def train_data(self):
        warnings.warn("train_data has been renamed data")
        return self.data

    @property
    def test_data(self):
        warnings.warn("test_data has been renamed data")
        return self.data

    def __init__(
            self,
            root,
            train= True,
            transform = None,
            target_transform = None,
            download = False,
    ):
        super(MNISTsuperimposed, self).__init__(root, transform=transform,
                                    target_transform=target_transform)
        self.train = train  # training set or test set

        if self._check_legacy_exist():
            self.data, self.targets, self.targets = self._load_legacy_data()

        if download:
            self.download()

        if not self._check_exists():
            raise RuntimeError('Dataset not found.' +
                               ' You can use download=True to download it')

        self.data, self.targets = self._load_data()
        
    def _check_legacy_exist(self):
        processed_folder_exists = os.path.exists(self.processed_folder)
        if not processed_folder_exists:
            return False

        return all(
            check_integrity(os.path.join(self.processed_folder, file)) for file in (self.training_file, self.test_file)
        )

    def _load_legacy_data(self):
        # This is for BC only. We no longer cache the data in a custom binary, but simply read from the raw data
        # directly.
        data_file = self.training_file if self.train else self.test_file
        return torch.load(os.path.join(self.processed_folder, data_file))

    def _load_data(self):
        image_file = f"{'train' if self.train else 't10k'}-images-idx3-ubyte"
        data = read_image_file(os.path.join(self.raw_folder, image_file))
        #Technically, we do not even need the labels for now
        # We just need the clean images of both types
        randata = data[torch.randperm(data.shape[0]),:,:]
        targets = (data, randata)
        
        
        # Now do the ambiguation here
        data1 = data + randata
        targets = (data1, data, randata)
        return data1, targets

    def __getitem__(self, index):
        """
        Args:
            index (int): Index

        Returns:
            tuple: (image, target) where target is index of the target class.
        """
        img, target = self.data[index], (self.targets[0][index], self.targets[1][index], self.targets[2][index])
        # doing this so that it is consistent with all other datasets
        # to return a PIL Imagedata[torch.randperm(data.shape[0]),:,:]
        img = Image.fromarray(img.numpy(), mode='L')
        target0 = Image.fromarray(target[0].numpy(), mode='L')
        target1 = Image.fromarray(target[1].numpy(), mode='L')
        target2 = Image.fromarray(target[2].numpy(), mode='L')

        if self.transform is not None:
            img = self.transform(img)

        if self.target_transform is not None:
            target = (self.target_transform[0](target0), self.target_transform[1](target0), self.target_transform[1](target1), self.target_transform[1](target2))
            

        return img, target

    def __len__(self):
        return len(self.data)

    @property
    def raw_folder(self):
        return os.path.join(self.root, self.__class__.__name__, 'raw')

    @property
    def processed_folder(self) -> str:
        return os.path.join(self.root, self.__class__.__name__, 'processed')

    @property
    def class_to_idx(self):
        return {_class: i for i, _class in enumerate(self.classes)}

    def _check_exists(self):
        return all(
            check_integrity(os.path.join(self.raw_folder, os.path.splitext(os.path.basename(url))[0]))
            for url, _ in self.resources
        )

    def download(self):
        """Download the MNIST data if it doesn't exist already."""

        if self._check_exists():
            return

        os.makedirs(self.raw_folder, exist_ok=True)

        # download files
        for filename, md5 in self.resources:
            for mirror in self.mirrors:
                url = "{}{}".format(mirror, filename)
                try:
                    print("Downloading {}".format(url))
                    download_and_extract_archive(
                        url, download_root=self.raw_folder,
                        filename=filename,
                        md5=md5
                    )
                except URLError as error:
                    print(
                        "Failed to download (trying next):\n{}".format(error)
                    )
                    continue
                finally:
                    print()
                break
            else:
                raise RuntimeError("Error downloading {}".format(filename))

    def extra_repr(self) -> str:
        return "Split: {}".format("Train" if self.train is True else "Test")

# %%
class Downsample(object):
    def __init__(self, size=[1,196]):
        self.size=size

    def __call__(self, tensor):
        img = np.squeeze(tensor)
        m = torch.nn.AvgPool2d(2, stride=2)
        return m(img.unsqueeze(0))

    def __repr__(self):
        return self.__class__.__name__+'({})'.format(self.size)

# %%
class AddGaussNoise(object):
    def __init__(self, mean=0, std=0.001):
        self.std=std
        self.mean=mean
        
    def __call__(self, tensor):
#         print(tensor + torch.randn(tensor.size()) * self.std + self.mean)
        return torch.tensor(random_noise(tensor,mean=self.mean,var=self.std))

    def __repr__(self):
        return self.__class__.__name__+'(mean={0},std={1})'.format(self.mean, self.std)

# %%
transform = transforms.Compose(
    [transforms.Grayscale(),
     transforms.ToTensor(),
     Downsample(),
     Downsample(),
     AddGaussNoise(0,1e-4)
     ])
target1_transform= transforms.Compose(
    [transforms.Grayscale(),
     transforms.ToTensor(),
     Downsample(),
     Downsample(),
     ])
target2_transform = transforms.Compose(
    [transforms.Grayscale(),
     transforms.ToTensor(),
     ])

target_transform = [target1_transform, target2_transform]
mnist_superimposed = MNISTsuperimposed("./MNIST data/train", train = True, download = True, transform = transform, target_transform=target_transform)
# Out:
# /opt/conda/lib/python3.8/site-packages/torchvision/datasets/mnist.py:480: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  ../torch/csrc/utils/tensor_numpy.cpp:137.)
#   return torch.from_numpy(parsed.astype(m[2], copy=False)).view(*s)

# %%
# transform = transforms.Compose(
#     [transforms.Grayscale(),
#      transforms.ToTensor(),
#      Downsample()
#      ])

# target_transform =transforms.Compose(
#     [transforms.Grayscale(),
#      transforms.ToTensor()     
#     ]) 
# mnist_superimposed = MNISTsuperimposed("./MNIST data/train", train = True, download = True, transform = transform, target_transform=target_transform)

# %%
from torch.utils.data import DataLoader
batch = 32
trainset = DataLoader(mnist_superimposed, batch_size=batch, shuffle = False)

# %%
def show_images(dataset, training = True):
    
    fig = plt.figure(figsize = (20, 14))
    rows = 5
    columns = 4
    j=0
    for i in range(1,columns*rows+1):
        
        if i >=1 and i<5:
            fig.add_subplot(rows, columns, i)
            plt.imshow(dataset[i][0].squeeze(0), cmap='gray')
            
        if i >=5 and i<9:
            fig.add_subplot(rows, columns, i)
            plt.imshow(dataset[i-4][1][0].squeeze(0), cmap='gray')
            
        if i >=9 and i < 13:
            fig.add_subplot(rows, columns, i)
            plt.imshow(dataset[i-8][1][1].squeeze(0), cmap='gray')
            
        if i >= 13 and i<17:
            fig.add_subplot(rows, columns, i)
            plt.imshow(dataset[i-12][1][2].squeeze(0), cmap='gray')
        
        if i >= 17 and i<21:
            fig.add_subplot(rows, columns, i)
            plt.imshow(dataset[i-16][1][3].squeeze(0), cmap='gray')

# %%
show_images(mnist_superimposed)

# %%
import torch
from torch import nn as nn
from torch.nn import Conv2d, ConvTranspose2d, Linear, Sequential, Flatten, ReLU

# %%
print(torch.cuda.is_available())
# Out:
# True

# %%
class Trash(nn.Module):
    def __init__(self, inplace = False):
        super(Trash,self).__init__()
            
        self.Encoder = nn.Sequential(
            nn.Conv2d(1, 8, kernel_size = 3, padding = 1, stride = 1),
            nn.BatchNorm2d(8),
            nn.ReLU(inplace),
            nn.Conv2d(8, 16, kernel_size = 3, padding = 1, stride = 1),
            nn.BatchNorm2d(16),
            nn.ReLU(inplace),

            nn.Conv2d(16, 32, kernel_size = 3, padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.Conv2d(32, 64, kernel_size = 3, padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.MaxPool2d(kernel_size = (2, 2)),                      
        )

        self.Decoder = nn.Sequential(
            nn.Conv2d(64, 32, kernel_size = 3, padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.Conv2d(32, 32, kernel_size = 3, padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.ConvTranspose2d(in_channels = 32, out_channels = 16, kernel_size = (2, 2), stride = 2),
            nn.ReLU(inplace),
            
            nn.Conv2d(16, 16, kernel_size = 3, padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.Conv2d(16, 8, kernel_size = 3, padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.ConvTranspose2d(in_channels = 8, out_channels = 1, kernel_size = 4, stride = 1, padding = 1),
            nn.ReLU(inplace),
        )
        
        self.Upsample = nn.Sequential(
            nn.Flatten(start_dim = 1), #0
            nn.Linear(49, 49),  #1
            nn.Linear(49, 64),  #2
            nn.Linear(64, 64),  #3
            nn.Linear(64, 64),  #4
            nn.Linear(64, 64),  #5
            nn.ReLU(inplace),   #6
            
            nn.Linear(64, 64),  #7
            nn.Linear(64, 256), #8
            nn.Linear(256, 256),#9
            nn.Linear(256, 256),#10
            nn.Linear(256, 256),#11
            nn.ReLU(inplace),   #12
            
            nn.Linear(256, 256),#13
            nn.Linear(256, 784),#14
            nn.Linear(784, 784),#15
            nn.Linear(784, 784),#16
            nn.Linear(784, 784),#17
            nn.Sigmoid(),       #18
        )
        
        self.initial_Processing = nn.Sequential(
            nn.Conv2d(in_channels = 1, out_channels = 16, kernel_size = 3, padding = 1, stride = 1),
            nn.BatchNorm2d(16),
            nn.ReLU(inplace),
            nn.Conv2d(in_channels = 16, out_channels = 32, kernel_size = 3, padding =1, stride = 1),
            nn.BatchNorm2d(32),
            nn.ReLU(inplace),
        )

        self.Down_1 = nn.Sequential(
            nn.Conv2d(in_channels = 32, out_channels = 128, kernel_size = (3, 3), padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.Conv2d(in_channels = 128, out_channels = 512, kernel_size = (3, 3), padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.MaxPool2d(kernel_size = (2, 2)),
        )

        self.Down_2 = nn.Sequential(
            nn.Conv2d(in_channels = 512, out_channels = 128, kernel_size = (3, 3), padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.Conv2d(in_channels = 128, out_channels = 256, kernel_size = (3, 3), padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.MaxPool2d(kernel_size = (2, 2)),
        )


        self.Down_3 = nn.Sequential(
            nn.Conv2d(in_channels = 256, out_channels = 128, kernel_size = (3, 3), padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.Conv2d(in_channels = 128, out_channels = 128, kernel_size = (3, 3), padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.MaxPool2d(kernel_size = (2, 2)),
        )
        
        self.Down_4 = nn.Sequential(
            nn.Conv2d(in_channels = 128, out_channels = 128, kernel_size = (3, 3), padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.Conv2d(in_channels = 128, out_channels = 64, kernel_size = (3, 3), padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.MaxPool2d(kernel_size = (2, 2)),
        )
        
        self.Up_1 = nn.Sequential(
            nn.Conv2d(in_channels = 64, out_channels = 64, kernel_size = (3, 3), padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.Conv2d(in_channels = 64, out_channels = 64, kernel_size = (3, 3), padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.ConvTranspose2d(in_channels = 64, out_channels = 64, kernel_size = (2, 2))
        )

        self.Up_2 = nn.Sequential(
            nn.Conv2d(in_channels = 128, out_channels = 128, kernel_size = (3, 3), padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.Conv2d(in_channels = 128, out_channels = 128, kernel_size = (3, 3), padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.ConvTranspose2d(in_channels = 128, out_channels = 128, kernel_size = (2, 2))
        )

        self.Up_3 = nn.Sequential(
            nn.Conv2d(in_channels = 256, out_channels = 256, kernel_size = (3, 3), padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.Conv2d(in_channels = 256, out_channels = 256, kernel_size = (3, 3), padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.ConvTranspose2d(in_channels = 256, out_channels = 256, kernel_size = (2, 2))
        )

        self.Up_4 = nn.Sequential(
            nn.Conv2d(in_channels = 512, out_channels = 512, kernel_size = (3, 3), padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.Conv2d(in_channels = 512, out_channels = 512, kernel_size = (3, 3), padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.ConvTranspose2d(in_channels = 512, out_channels = 512, kernel_size = (2, 2))
        )

        self.Up_5 = nn.Sequential(
            nn.Conv2d(in_channels = 1024, out_channels = 1024, kernel_size = (3, 3), padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.Conv2d(in_channels = 1024, out_channels = 1024, kernel_size = (3, 3), padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.ConvTranspose2d(in_channels = 1024, out_channels = 2, kernel_size = (1, 1)),
        )
        
        self.Final = nn.Sequential(
            nn.Flatten(start_dim = 1),
            nn.Linear(392, 512),
            nn.Linear(512, 512),
            nn.ReLU(inplace),
            
            nn.Linear(512, 1024),
            nn.Linear(1024, 1568),
            nn.Linear(1568, 1568),
            nn.Sigmoid(),
        )
        
    def forward(self,x, flag):
#         print(x[0].shape, x[1].shape, x[2].shape)
        outputs=[]
        
        
        if flag:
            
            # ENCODER
            output = self.Encoder(x[0])
            
            # DECODER
            output = self.Decoder(output)
            outputs.append(output)
            
            # UPSAMPLE

            output = self.Upsample(x[1])
#             output = self.Upsample[:5](x[1])
#             output = self.Upsample[6](output + self.Upsample[5](output))
            
#             output = self.Upsample[7:11](output)
#             output = self.Upsample[12](output + self.Upsample[11](output))
            
#             output = self.Upsample[13:17](output)
#             output = self.Upsample[18](output + self.Upsample[17](output))

            outputs.append(output)
            
            
            # DISAMBIGUATION
            
            output = self.initial_Processing(x[2])
            
            output = self.Down_1(output)
            output_1 = output


            output = self.Down_2(output)
            output_2 = output

            output = self.Down_3(output)
            output_3 = output
            
            output = self.Down_4(output)
            output_4 = output

            output = self.Up_1(output)
            diffY = output_4.size()[2] - output.size()[2]
            diffX = output_4.size()[3] - output.size()[3]
            output = F.pad(output, [diffX // 2, diffX - diffX // 2,
                            diffY // 2, diffY - diffY // 2])
            output = torch.cat([output_4, output], dim=1)

            output = self.Up_2(output)
            diffY = output_3.size()[2] - output.size()[2]
            diffX = output_3.size()[3] - output.size()[3]
            output = F.pad(output, [diffX // 2, diffX - diffX // 2,
                            diffY // 2, diffY - diffY // 2])
            output = torch.cat([output_3, output], dim=1)


            output = self.Up_3(output)
            diffY = output_2.size()[2] - output.size()[2]
            diffX = output_2.size()[3] - output.size()[3]
            output = F.pad(output, [diffX // 2, diffX - diffX // 2,
                            diffY // 2, diffY - diffY // 2])
            output = torch.cat([output_2, output], dim=1)


            output = self.Up_4(output)
            diffY = output_1.size()[2] - output.size()[2]
            diffX = output_1.size()[3] - output.size()[3]
            output = F.pad(output, [diffX // 2, diffX - diffX // 2,
                            diffY // 2, diffY - diffY // 2])
            output = torch.cat([output_1, output], dim=1)


            output = self.Up_5(output)  
            
            output = self.Final(output)
            
            outputs.append(output)
            
        
            
        else:
            # ENCODER
            output = self.Encoder(x)
            
            # DECODER
            output = self.Decoder(output)
            outputs.append(output)
            
            # UPSAMPLE
            output = self.Upsample(output)
#             output = self.Upsample[:5](output)
#             output = self.Upsample[6](output + self.Upsample[5](output))
            
#             output = self.Upsample[7:11](output)
#             output = self.Upsample[12](output + self.Upsample[11](output))
            
#             output = self.Upsample[13:17](output)
#             output = self.Upsample[18](output + self.Upsample[17](output))

            outputs.append(output)
            
            output = output.reshape(output.shape[0], 1, 28, 28)
            # DISAMBIGUATION
            
            output = self.initial_Processing(output)
            
            output = self.Down_1(output)
            output_1 = output


            output = self.Down_2(output)
            output_2 = output

            output = self.Down_3(output)
            output_3 = output

            output = self.Down_4(output)
            output_4 = output

            output = self.Up_1(output)
            diffY = output_4.size()[2] - output.size()[2]
            diffX = output_4.size()[3] - output.size()[3]
            output = F.pad(output, [diffX // 2, diffX - diffX // 2,
                            diffY // 2, diffY - diffY // 2])
            output = torch.cat([output_4, output], dim=1)
            
            output = self.Up_2(output)
            diffY = output_3.size()[2] - output.size()[2]
            diffX = output_3.size()[3] - output.size()[3]
            output = F.pad(output, [diffX // 2, diffX - diffX // 2,
                            diffY // 2, diffY - diffY // 2])
            output = torch.cat([output_3, output], dim=1)


            output = self.Up_3(output)
            diffY = output_2.size()[2] - output.size()[2]
            diffX = output_2.size()[3] - output.size()[3]
            output = F.pad(output, [diffX // 2, diffX - diffX // 2,
                            diffY // 2, diffY - diffY // 2])
            output = torch.cat([output_2, output], dim=1)


            output = self.Up_4(output)
            diffY = output_1.size()[2] - output.size()[2]
            diffX = output_1.size()[3] - output.size()[3]
            output = F.pad(output, [diffX // 2, diffX - diffX // 2,
                            diffY // 2, diffY - diffY // 2])
            output = torch.cat([output_1, output], dim=1)


            output = self.Up_5(output)      
            
            output = self.Final(output)
            
            outputs.append(output)
            
        
#         print(outputs[0].shape, outputs[1].shape, outputs[2].shape)
            
        return outputs

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
AEnet = Trash(inplace = True).to(device)
optimizer = torch.optim.Adam(AEnet.parameters(), lr=0.00005)
# criterion2 = nn.BCEWithLogitsLoss()
criterion2 = nn.MSELoss()
print(device)
# Out:
# cuda

# %%
def train_test(AEnet, dataset, Training = True):

    if Training:
        epochs = 50
        train_loss = []
        t_loss = []
        flag = True
        for epoch in range(epochs):
            running_loss = 0.0
            for i, data in enumerate(dataset):
                optimizer.zero_grad()
                outputs = AEnet((data[0].float().to(device), data[1][0].float().to(device), data[1][1].float().to(device)), flag=True)

                loss1 = criterion2(torch.flatten(outputs[0],1).float().to(device),torch.flatten(data[1][0],1).float().to(device))
                loss2 = criterion2(outputs[1].float().to(device),torch.flatten(data[1][1],1).float().to(device))
                loss3 = criterion2(outputs[2][:, :784].float().to(device),torch.flatten(data[1][2],1).float().to(device))
                loss4 = criterion2(outputs[2][:, 784:].float().to(device),torch.flatten(data[1][3],1).float().to(device))

                loss = loss1 + loss2 + loss3 + loss4
                loss.backward()
                optimizer.step()
                train_loss.append(loss.item())
                running_loss += loss.item()
                if i % 400 == 399:
                    print('[%d, %5d] loss per section; Denoising: %.6f, Upsampling: %.6f, Disamiguation: %.6f'% (epoch + 1, i + 1, loss1.item()/32, loss2.item()/32, (loss3.item()+loss4.item())/32))
                    print('[%d, %5d] loss : %.6f' %
                          (epoch + 1, i + 1, loss.item()/32))
                    t_loss.append(loss.item()/32)
                
            

            
        print("The lowest was: ", min(train_loss)/32)

        print('Finished Training')
        flag = False
        return outputs, data, t_loss
            
    else:
        testing_loss = []
        t_loss = []
        with torch.no_grad():
            for i, data in enumerate(dataset):
                    optimizer.zero_grad()
                    outputs = AEnet(data[0].float().to(device), flag = False)
                    loss1 = criterion2(torch.flatten(outputs[0],1).float().to(device),torch.flatten(data[1][0],1).float().to(device))
                    loss2 = criterion2(outputs[1].float().to(device),torch.flatten(data[1][1],1).float().to(device))
                    loss3 = criterion2(outputs[2][:, :784].float().to(device),torch.flatten(data[1][2],1).float().to(device))
                    loss4 = criterion2(outputs[2][:, 784:].float().to(device),torch.flatten(data[1][3],1).float().to(device))

                    loss = loss1 + loss2 + loss3 + loss4
                    testing_loss.append(loss.item()/32)
                    if i % 10 == 9:
                        print('[%5d] loss per image: %.6f' %
                              (i + 1, loss.item()/32))
                        t_loss.append(loss.item()/32)
                    
            print("The lowest was: ", min(testing_loss)/32)
            print('Finished Testing')
            return outputs, data, t_loss

# %%
output, data, training_loss= train_test(AEnet, trainset)
# Out:
# [1,   400] loss per section; Denoising: 0.000621, Upsampling: 0.002164, Disamiguation: 0.003059
# [1,   400] loss : 0.005843
# [1,   800] loss per section; Denoising: 0.000490, Upsampling: 0.002061, Disamiguation: 0.002801
# [1,   800] loss : 0.005351
# [1,  1200] loss per section; Denoising: 0.000301, Upsampling: 0.002006, Disamiguation: 0.002591
# [1,  1200] loss : 0.004899
# [1,  1600] loss per section; Denoising: 0.000287, Upsampling: 0.002210, Disamiguation: 0.002941
# [1,  1600] loss : 0.005438
# [2,   400] loss per section; Denoising: 0.000173, Upsampling: 0.001937, Disamiguation: 0.002459
# [2,   400] loss : 0.004570
# [2,   800] loss per section; Denoising: 0.000187, Upsampling: 0.002032, Disamiguation: 0.002449
# [2,   800] loss : 0.004668
# [2,  1200] loss per section; Denoising: 0.000141, Upsampling: 0.001914, Disamiguation: 0.002340
# [2,  1200] loss : 0.004395
# [2,  1600] loss per section; Denoising: 0.000159, Upsampling: 0.002123, Disamiguation: 0.002787
# [2,  1600] loss : 0.005069
# [3,   400] loss per section; Denoising: 0.000100, Upsampling: 0.001793, Disamiguation: 0.002333
# [3,   400] loss : 0.004225
# [3,   800] loss per section; Denoising: 0.000131, Upsampling: 0.001875, Disamiguation: 0.002361
# [3,   800] loss : 0.004367
# [3,  1200] loss per section; Denoising: 0.000089, Upsampling: 0.001780, Disamiguation: 0.002255
# [3,  1200] loss : 0.004124
# [3,  1600] loss per section; Denoising: 0.000107, Upsampling: 0.001933, Disamiguation: 0.002722
# [3,  1600] loss : 0.004761
# [4,   400] loss per section; Denoising: 0.000069, Upsampling: 0.001638, Disamiguation: 0.002288
# [4,   400] loss : 0.003994
# [4,   800] loss per section; Denoising: 0.000105, Upsampling: 0.001717, Disamiguation: 0.002320
# [4,   800] loss : 0.004141
# [4,  1200] loss per section; Denoising: 0.000069, Upsampling: 0.001653, Disamiguation: 0.002211
# [4,  1200] loss : 0.003934
# [4,  1600] loss per section; Denoising: 0.000084, Upsampling: 0.001833, Disamiguation: 0.002683
# [4,  1600] loss : 0.004600
# [5,   400] loss per section; Denoising: 0.000057, Upsampling: 0.001612, Disamiguation: 0.002257
# [5,   400] loss : 0.003925
# [5,   800] loss per section; Denoising: 0.000094, Upsampling: 0.001686, Disamiguation: 0.002295
# [5,   800] loss : 0.004075
# [5,  1200] loss per section; Denoising: 0.000058, Upsampling: 0.001621, Disamiguation: 0.002180
# [5,  1200] loss : 0.003859
# [5,  1600] loss per section; Denoising: 0.000069, Upsampling: 0.001816, Disamiguation: 0.002654
# [5,  1600] loss : 0.004539
# [6,   400] loss per section; Denoising: 0.000047, Upsampling: 0.001598, Disamiguation: 0.002234
# [6,   400] loss : 0.003879
# [6,   800] loss per section; Denoising: 0.000089, Upsampling: 0.001676, Disamiguation: 0.002279
# [6,   800] loss : 0.004044
# [6,  1200] loss per section; Denoising: 0.000048, Upsampling: 0.001609, Disamiguation: 0.002153
# [6,  1200] loss : 0.003810
# [6,  1600] loss per section; Denoising: 0.000058, Upsampling: 0.001796, Disamiguation: 0.002634
# [6,  1600] loss : 0.004489
# [7,   400] loss per section; Denoising: 0.000043, Upsampling: 0.001583, Disamiguation: 0.002212
# [7,   400] loss : 0.003839
# [7,   800] loss per section; Denoising: 0.000082, Upsampling: 0.001654, Disamiguation: 0.002274
# [7,   800] loss : 0.004010
# [7,  1200] loss per section; Denoising: 0.000040, Upsampling: 0.001587, Disamiguation: 0.002127
# [7,  1200] loss : 0.003754
# [7,  1600] loss per section; Denoising: 0.000050, Upsampling: 0.001736, Disamiguation: 0.002624
# [7,  1600] loss : 0.004410
# [8,   400] loss per section; Denoising: 0.000038, Upsampling: 0.001531, Disamiguation: 0.002206
# [8,   400] loss : 0.003775
# [8,   800] loss per section; Denoising: 0.000076, Upsampling: 0.001574, Disamiguation: 0.002270
# [8,   800] loss : 0.003921
# [8,  1200] loss per section; Denoising: 0.000035, Upsampling: 0.001549, Disamiguation: 0.002108
# [8,  1200] loss : 0.003692
# [8,  1600] loss per section; Denoising: 0.000044, Upsampling: 0.001699, Disamiguation: 0.002605
# [8,  1600] loss : 0.004348
# [9,   400] loss per section; Denoising: 0.000034, Upsampling: 0.001496, Disamiguation: 0.002198
# [9,   400] loss : 0.003729
# [9,   800] loss per section; Denoising: 0.000073, Upsampling: 0.001553, Disamiguation: 0.002270
# [9,   800] loss : 0.003896
# [9,  1200] loss per section; Denoising: 0.000030, Upsampling: 0.001536, Disamiguation: 0.002102
# [9,  1200] loss : 0.003668
# [9,  1600] loss per section; Denoising: 0.000039, Upsampling: 0.001683, Disamiguation: 0.002482
# [9,  1600] loss : 0.004205
# [10,   400] loss per section; Denoising: 0.000031, Upsampling: 0.001480, Disamiguation: 0.001967
# [10,   400] loss : 0.003478
# [10,   800] loss per section; Denoising: 0.000070, Upsampling: 0.001539, Disamiguation: 0.002116
# [10,   800] loss : 0.003724
# [10,  1200] loss per section; Denoising: 0.000028, Upsampling: 0.001520, Disamiguation: 0.002030
# [10,  1200] loss : 0.003578
# [10,  1600] loss per section; Denoising: 0.000037, Upsampling: 0.001668, Disamiguation: 0.002272
# [10,  1600] loss : 0.003978
# [11,   400] loss per section; Denoising: 0.000029, Upsampling: 0.001458, Disamiguation: 0.001730
# [11,   400] loss : 0.003218
# [11,   800] loss per section; Denoising: 0.000070, Upsampling: 0.001507, Disamiguation: 0.001902
# [11,   800] loss : 0.003478
# [11,  1200] loss per section; Denoising: 0.000027, Upsampling: 0.001491, Disamiguation: 0.001792
# [11,  1200] loss : 0.003309
# [11,  1600] loss per section; Denoising: 0.000035, Upsampling: 0.001650, Disamiguation: 0.001959
# [11,  1600] loss : 0.003645
# [12,   400] loss per section; Denoising: 0.000029, Upsampling: 0.001447, Disamiguation: 0.001466
# [12,   400] loss : 0.002942
# [12,   800] loss per section; Denoising: 0.000068, Upsampling: 0.001499, Disamiguation: 0.001749
# [12,   800] loss : 0.003316
# [12,  1200] loss per section; Denoising: 0.000026, Upsampling: 0.001482, Disamiguation: 0.001620
# [12,  1200] loss : 0.003127
# [12,  1600] loss per section; Denoising: 0.000034, Upsampling: 0.001643, Disamiguation: 0.001772
# [12,  1600] loss : 0.003449
# [13,   400] loss per section; Denoising: 0.000027, Upsampling: 0.001432, Disamiguation: 0.001352
# [13,   400] loss : 0.002811
# [13,   800] loss per section; Denoising: 0.000066, Upsampling: 0.001484, Disamiguation: 0.001504
# [13,   800] loss : 0.003053
# [13,  1200] loss per section; Denoising: 0.000024, Upsampling: 0.001441, Disamiguation: 0.001449
# [13,  1200] loss : 0.002915
# [13,  1600] loss per section; Denoising: 0.000033, Upsampling: 0.001617, Disamiguation: 0.001557
# [13,  1600] loss : 0.003207
# [14,   400] loss per section; Denoising: 0.000027, Upsampling: 0.001391, Disamiguation: 0.001224
# [14,   400] loss : 0.002642
# [14,   800] loss per section; Denoising: 0.000065, Upsampling: 0.001469, Disamiguation: 0.001302
# [14,   800] loss : 0.002836
# [14,  1200] loss per section; Denoising: 0.000024, Upsampling: 0.001421, Disamiguation: 0.001318
# [14,  1200] loss : 0.002763
# [14,  1600] loss per section; Denoising: 0.000032, Upsampling: 0.001604, Disamiguation: 0.001361
# [14,  1600] loss : 0.002997
# [15,   400] loss per section; Denoising: 0.000026, Upsampling: 0.001376, Disamiguation: 0.001100
# [15,   400] loss : 0.002501
# [15,   800] loss per section; Denoising: 0.000064, Upsampling: 0.001464, Disamiguation: 0.001244
# [15,   800] loss : 0.002772
# [15,  1200] loss per section; Denoising: 0.000023, Upsampling: 0.001410, Disamiguation: 0.001221
# [15,  1200] loss : 0.002654
# [15,  1600] loss per section; Denoising: 0.000031, Upsampling: 0.001593, Disamiguation: 0.001297
# [15,  1600] loss : 0.002921
# [16,   400] loss per section; Denoising: 0.000025, Upsampling: 0.001366, Disamiguation: 0.001045
# [16,   400] loss : 0.002437
# [16,   800] loss per section; Denoising: 0.000062, Upsampling: 0.001448, Disamiguation: 0.001146
# [16,   800] loss : 0.002657
# [16,  1200] loss per section; Denoising: 0.000023, Upsampling: 0.001385, Disamiguation: 0.001129
# [16,  1200] loss : 0.002537
# [16,  1600] loss per section; Denoising: 0.000031, Upsampling: 0.001568, Disamiguation: 0.001175
# [16,  1600] loss : 0.002774
# [17,   400] loss per section; Denoising: 0.000024, Upsampling: 0.001343, Disamiguation: 0.000983
# [17,   400] loss : 0.002351
# [17,   800] loss per section; Denoising: 0.000062, Upsampling: 0.001431, Disamiguation: 0.001063
# [17,   800] loss : 0.002556
# [17,  1200] loss per section; Denoising: 0.000023, Upsampling: 0.001379, Disamiguation: 0.001097
# [17,  1200] loss : 0.002499
# [17,  1600] loss per section; Denoising: 0.000030, Upsampling: 0.001554, Disamiguation: 0.001057
# [17,  1600] loss : 0.002641
# [18,   400] loss per section; Denoising: 0.000024, Upsampling: 0.001333, Disamiguation: 0.000943
# [18,   400] loss : 0.002300
# [18,   800] loss per section; Denoising: 0.000059, Upsampling: 0.001425, Disamiguation: 0.000979
# [18,   800] loss : 0.002464
# [18,  1200] loss per section; Denoising: 0.000023, Upsampling: 0.001376, Disamiguation: 0.000959
# [18,  1200] loss : 0.002358
# [18,  1600] loss per section; Denoising: 0.000030, Upsampling: 0.001543, Disamiguation: 0.000983
# [18,  1600] loss : 0.002555
# [19,   400] loss per section; Denoising: 0.000023, Upsampling: 0.001325, Disamiguation: 0.000880
# [19,   400] loss : 0.002227
# [19,   800] loss per section; Denoising: 0.000059, Upsampling: 0.001421, Disamiguation: 0.000921
# [19,   800] loss : 0.002401
# [19,  1200] loss per section; Denoising: 0.000022, Upsampling: 0.001373, Disamiguation: 0.000920
# [19,  1200] loss : 0.002315
# [19,  1600] loss per section; Denoising: 0.000028, Upsampling: 0.001531, Disamiguation: 0.000904
# [19,  1600] loss : 0.002463
# [20,   400] loss per section; Denoising: 0.000023, Upsampling: 0.001316, Disamiguation: 0.000807
# [20,   400] loss : 0.002146
# [20,   800] loss per section; Denoising: 0.000057, Upsampling: 0.001415, Disamiguation: 0.000862
# [20,   800] loss : 0.002335
# [20,  1200] loss per section; Denoising: 0.000023, Upsampling: 0.001363, Disamiguation: 0.000838
# [20,  1200] loss : 0.002224
# [20,  1600] loss per section; Denoising: 0.000028, Upsampling: 0.001515, Disamiguation: 0.000874
# [20,  1600] loss : 0.002417
# [21,   400] loss per section; Denoising: 0.000022, Upsampling: 0.001300, Disamiguation: 0.000769
# [21,   400] loss : 0.002091
# [21,   800] loss per section; Denoising: 0.000056, Upsampling: 0.001404, Disamiguation: 0.000818
# [21,   800] loss : 0.002277
# [21,  1200] loss per section; Denoising: 0.000022, Upsampling: 0.001357, Disamiguation: 0.000858
# [21,  1200] loss : 0.002236
# [21,  1600] loss per section; Denoising: 0.000027, Upsampling: 0.001507, Disamiguation: 0.000813
# [21,  1600] loss : 0.002346
# [22,   400] loss per section; Denoising: 0.000022, Upsampling: 0.001290, Disamiguation: 0.000744
# [22,   400] loss : 0.002055
# [22,   800] loss per section; Denoising: 0.000055, Upsampling: 0.001398, Disamiguation: 0.000755
# [22,   800] loss : 0.002208
# [22,  1200] loss per section; Denoising: 0.000021, Upsampling: 0.001347, Disamiguation: 0.000768
# [22,  1200] loss : 0.002136
# [22,  1600] loss per section; Denoising: 0.000027, Upsampling: 0.001495, Disamiguation: 0.000775
# [22,  1600] loss : 0.002296
# [23,   400] loss per section; Denoising: 0.000021, Upsampling: 0.001269, Disamiguation: 0.000675
# [23,   400] loss : 0.001965
# [23,   800] loss per section; Denoising: 0.000054, Upsampling: 0.001385, Disamiguation: 0.000745
# [23,   800] loss : 0.002184
# [23,  1200] loss per section; Denoising: 0.000021, Upsampling: 0.001331, Disamiguation: 0.000736
# [23,  1200] loss : 0.002088
# [23,  1600] loss per section; Denoising: 0.000025, Upsampling: 0.001477, Disamiguation: 0.000718
# [23,  1600] loss : 0.002221
# [24,   400] loss per section; Denoising: 0.000021, Upsampling: 0.001259, Disamiguation: 0.000675
# [24,   400] loss : 0.001955
# [24,   800] loss per section; Denoising: 0.000053, Upsampling: 0.001376, Disamiguation: 0.000707
# [24,   800] loss : 0.002136
# [24,  1200] loss per section; Denoising: 0.000021, Upsampling: 0.001325, Disamiguation: 0.000698
# [24,  1200] loss : 0.002044
# [24,  1600] loss per section; Denoising: 0.000025, Upsampling: 0.001466, Disamiguation: 0.000686
# [24,  1600] loss : 0.002178
# [25,   400] loss per section; Denoising: 0.000020, Upsampling: 0.001251, Disamiguation: 0.000635
# [25,   400] loss : 0.001906
# [25,   800] loss per section; Denoising: 0.000052, Upsampling: 0.001369, Disamiguation: 0.000668
# [25,   800] loss : 0.002089
# [25,  1200] loss per section; Denoising: 0.000021, Upsampling: 0.001320, Disamiguation: 0.000689
# [25,  1200] loss : 0.002029
# [25,  1600] loss per section; Denoising: 0.000024, Upsampling: 0.001455, Disamiguation: 0.000684
# [25,  1600] loss : 0.002163
# [26,   400] loss per section; Denoising: 0.000020, Upsampling: 0.001241, Disamiguation: 0.000604
# [26,   400] loss : 0.001865
# [26,   800] loss per section; Denoising: 0.000052, Upsampling: 0.001351, Disamiguation: 0.000637
# [26,   800] loss : 0.002039
# [26,  1200] loss per section; Denoising: 0.000020, Upsampling: 0.001308, Disamiguation: 0.000664
# [26,  1200] loss : 0.001991
# [26,  1600] loss per section; Denoising: 0.000024, Upsampling: 0.001437, Disamiguation: 0.000633
# [26,  1600] loss : 0.002094
# [27,   400] loss per section; Denoising: 0.000020, Upsampling: 0.001227, Disamiguation: 0.000564
# [27,   400] loss : 0.001811
# [27,   800] loss per section; Denoising: 0.000050, Upsampling: 0.001336, Disamiguation: 0.000615
# [27,   800] loss : 0.002002
# [27,  1200] loss per section; Denoising: 0.000020, Upsampling: 0.001301, Disamiguation: 0.000621
# [27,  1200] loss : 0.001942
# [27,  1600] loss per section; Denoising: 0.000023, Upsampling: 0.001427, Disamiguation: 0.000606
# [27,  1600] loss : 0.002056
# [28,   400] loss per section; Denoising: 0.000020, Upsampling: 0.001220, Disamiguation: 0.000569
# [28,   400] loss : 0.001809
# [28,   800] loss per section; Denoising: 0.000050, Upsampling: 0.001330, Disamiguation: 0.000584
# [28,   800] loss : 0.001965
# [28,  1200] loss per section; Denoising: 0.000019, Upsampling: 0.001295, Disamiguation: 0.000620
# [28,  1200] loss : 0.001934
# [28,  1600] loss per section; Denoising: 0.000023, Upsampling: 0.001420, Disamiguation: 0.000589
# [28,  1600] loss : 0.002032
# [29,   400] loss per section; Denoising: 0.000019, Upsampling: 0.001215, Disamiguation: 0.000556
# [29,   400] loss : 0.001790
# [29,   800] loss per section; Denoising: 0.000049, Upsampling: 0.001323, Disamiguation: 0.000576
# [29,   800] loss : 0.001949
# [29,  1200] loss per section; Denoising: 0.000019, Upsampling: 0.001284, Disamiguation: 0.000586
# [29,  1200] loss : 0.001890
# [29,  1600] loss per section; Denoising: 0.000022, Upsampling: 0.001407, Disamiguation: 0.000574
# [29,  1600] loss : 0.002003
# [30,   400] loss per section; Denoising: 0.000019, Upsampling: 0.001209, Disamiguation: 0.000507
# [30,   400] loss : 0.001735
# [30,   800] loss per section; Denoising: 0.000049, Upsampling: 0.001311, Disamiguation: 0.000565
# [30,   800] loss : 0.001924
# [30,  1200] loss per section; Denoising: 0.000019, Upsampling: 0.001271, Disamiguation: 0.000586
# [30,  1200] loss : 0.001876
# [30,  1600] loss per section; Denoising: 0.000022, Upsampling: 0.001396, Disamiguation: 0.000528
# [30,  1600] loss : 0.001945
# [31,   400] loss per section; Denoising: 0.000018, Upsampling: 0.001202, Disamiguation: 0.000495
# [31,   400] loss : 0.001715
# [31,   800] loss per section; Denoising: 0.000048, Upsampling: 0.001299, Disamiguation: 0.000533
# [31,   800] loss : 0.001881
# [31,  1200] loss per section; Denoising: 0.000019, Upsampling: 0.001262, Disamiguation: 0.000567
# [31,  1200] loss : 0.001848
# [31,  1600] loss per section; Denoising: 0.000022, Upsampling: 0.001389, Disamiguation: 0.000529
# [31,  1600] loss : 0.001940
# [32,   400] loss per section; Denoising: 0.000019, Upsampling: 0.001194, Disamiguation: 0.000489
# [32,   400] loss : 0.001701
# [32,   800] loss per section; Denoising: 0.000048, Upsampling: 0.001289, Disamiguation: 0.000520
# [32,   800] loss : 0.001857
# [32,  1200] loss per section; Denoising: 0.000018, Upsampling: 0.001252, Disamiguation: 0.000558
# [32,  1200] loss : 0.001828
# [32,  1600] loss per section; Denoising: 0.000022, Upsampling: 0.001381, Disamiguation: 0.000515
# [32,  1600] loss : 0.001917
# [33,   400] loss per section; Denoising: 0.000018, Upsampling: 0.001185, Disamiguation: 0.000462
# [33,   400] loss : 0.001665
# [33,   800] loss per section; Denoising: 0.000047, Upsampling: 0.001273, Disamiguation: 0.000505
# [33,   800] loss : 0.001825
# [33,  1200] loss per section; Denoising: 0.000018, Upsampling: 0.001239, Disamiguation: 0.000525
# [33,  1200] loss : 0.001783
# [33,  1600] loss per section; Denoising: 0.000021, Upsampling: 0.001372, Disamiguation: 0.000474
# [33,  1600] loss : 0.001867
# [34,   400] loss per section; Denoising: 0.000018, Upsampling: 0.001177, Disamiguation: 0.000454
# [34,   400] loss : 0.001650
# [34,   800] loss per section; Denoising: 0.000047, Upsampling: 0.001267, Disamiguation: 0.000473
# [34,   800] loss : 0.001787
# [34,  1200] loss per section; Denoising: 0.000018, Upsampling: 0.001233, Disamiguation: 0.000502
# [34,  1200] loss : 0.001754
# [34,  1600] loss per section; Denoising: 0.000021, Upsampling: 0.001364, Disamiguation: 0.000466
# [34,  1600] loss : 0.001851
# [35,   400] loss per section; Denoising: 0.000019, Upsampling: 0.001171, Disamiguation: 0.000433
# [35,   400] loss : 0.001622
# [35,   800] loss per section; Denoising: 0.000046, Upsampling: 0.001262, Disamiguation: 0.000467
# [35,   800] loss : 0.001776
# [35,  1200] loss per section; Denoising: 0.000018, Upsampling: 0.001230, Disamiguation: 0.000488
# [35,  1200] loss : 0.001736
# [35,  1600] loss per section; Denoising: 0.000021, Upsampling: 0.001357, Disamiguation: 0.000468
# [35,  1600] loss : 0.001846
# [36,   400] loss per section; Denoising: 0.000018, Upsampling: 0.001165, Disamiguation: 0.000446
# [36,   400] loss : 0.001629
# [36,   800] loss per section; Denoising: 0.000046, Upsampling: 0.001257, Disamiguation: 0.000432
# [36,   800] loss : 0.001735
# [36,  1200] loss per section; Denoising: 0.000018, Upsampling: 0.001227, Disamiguation: 0.000483
# [36,  1200] loss : 0.001728
# [36,  1600] loss per section; Denoising: 0.000020, Upsampling: 0.001350, Disamiguation: 0.000452
# [36,  1600] loss : 0.001822
# [37,   400] loss per section; Denoising: 0.000018, Upsampling: 0.001160, Disamiguation: 0.000414
# [37,   400] loss : 0.001592
# [37,   800] loss per section; Denoising: 0.000045, Upsampling: 0.001253, Disamiguation: 0.000425
# [37,   800] loss : 0.001723
# [37,  1200] loss per section; Denoising: 0.000018, Upsampling: 0.001222, Disamiguation: 0.000460
# [37,  1200] loss : 0.001700
# [37,  1600] loss per section; Denoising: 0.000021, Upsampling: 0.001341, Disamiguation: 0.000444
# [37,  1600] loss : 0.001806
# [38,   400] loss per section; Denoising: 0.000017, Upsampling: 0.001154, Disamiguation: 0.000410
# [38,   400] loss : 0.001581
# [38,   800] loss per section; Denoising: 0.000045, Upsampling: 0.001246, Disamiguation: 0.000428
# [38,   800] loss : 0.001719
# [38,  1200] loss per section; Denoising: 0.000017, Upsampling: 0.001216, Disamiguation: 0.000467
# [38,  1200] loss : 0.001700
# [38,  1600] loss per section; Denoising: 0.000020, Upsampling: 0.001326, Disamiguation: 0.000409
# [38,  1600] loss : 0.001756
# [39,   400] loss per section; Denoising: 0.000017, Upsampling: 0.001146, Disamiguation: 0.000411
# [39,   400] loss : 0.001574
# [39,   800] loss per section; Denoising: 0.000045, Upsampling: 0.001237, Disamiguation: 0.000408
# [39,   800] loss : 0.001689
# [39,  1200] loss per section; Denoising: 0.000017, Upsampling: 0.001210, Disamiguation: 0.000456
# [39,  1200] loss : 0.001683
# [39,  1600] loss per section; Denoising: 0.000020, Upsampling: 0.001319, Disamiguation: 0.000399
# [39,  1600] loss : 0.001738
# [40,   400] loss per section; Denoising: 0.000017, Upsampling: 0.001144, Disamiguation: 0.000407
# [40,   400] loss : 0.001568
# [40,   800] loss per section; Denoising: 0.000045, Upsampling: 0.001233, Disamiguation: 0.000397
# [40,   800] loss : 0.001675
# [40,  1200] loss per section; Denoising: 0.000018, Upsampling: 0.001206, Disamiguation: 0.000430
# [40,  1200] loss : 0.001654
# [40,  1600] loss per section; Denoising: 0.000021, Upsampling: 0.001315, Disamiguation: 0.000394
# [40,  1600] loss : 0.001729
# [41,   400] loss per section; Denoising: 0.000017, Upsampling: 0.001142, Disamiguation: 0.000380
# [41,   400] loss : 0.001538
# [41,   800] loss per section; Denoising: 0.000044, Upsampling: 0.001231, Disamiguation: 0.000397
# [41,   800] loss : 0.001672
# [41,  1200] loss per section; Denoising: 0.000017, Upsampling: 0.001202, Disamiguation: 0.000424
# [41,  1200] loss : 0.001644
# [41,  1600] loss per section; Denoising: 0.000020, Upsampling: 0.001311, Disamiguation: 0.000371
# [41,  1600] loss : 0.001703
# [42,   400] loss per section; Denoising: 0.000017, Upsampling: 0.001139, Disamiguation: 0.000375
# [42,   400] loss : 0.001532
# [42,   800] loss per section; Denoising: 0.000044, Upsampling: 0.001230, Disamiguation: 0.000368
# [42,   800] loss : 0.001642
# [42,  1200] loss per section; Denoising: 0.000017, Upsampling: 0.001198, Disamiguation: 0.000434
# [42,  1200] loss : 0.001648
# [42,  1600] loss per section; Denoising: 0.000020, Upsampling: 0.001309, Disamiguation: 0.000363
# [42,  1600] loss : 0.001692
# [43,   400] loss per section; Denoising: 0.000017, Upsampling: 0.001137, Disamiguation: 0.000365
# [43,   400] loss : 0.001519
# [43,   800] loss per section; Denoising: 0.000043, Upsampling: 0.001229, Disamiguation: 0.000368
# [43,   800] loss : 0.001640
# [43,  1200] loss per section; Denoising: 0.000017, Upsampling: 0.001192, Disamiguation: 0.000410
# [43,  1200] loss : 0.001619
# [43,  1600] loss per section; Denoising: 0.000020, Upsampling: 0.001306, Disamiguation: 0.000368
# [43,  1600] loss : 0.001694
# [44,   400] loss per section; Denoising: 0.000017, Upsampling: 0.001134, Disamiguation: 0.000350
# [44,   400] loss : 0.001501
# [44,   800] loss per section; Denoising: 0.000043, Upsampling: 0.001228, Disamiguation: 0.000376
# [44,   800] loss : 0.001647
# [44,  1200] loss per section; Denoising: 0.000017, Upsampling: 0.001188, Disamiguation: 0.000414
# [44,  1200] loss : 0.001619
# [44,  1600] loss per section; Denoising: 0.000019, Upsampling: 0.001302, Disamiguation: 0.000344
# [44,  1600] loss : 0.001665
# [45,   400] loss per section; Denoising: 0.000016, Upsampling: 0.001128, Disamiguation: 0.000356
# [45,   400] loss : 0.001500
# [45,   800] loss per section; Denoising: 0.000043, Upsampling: 0.001223, Disamiguation: 0.000366
# [45,   800] loss : 0.001632
# [45,  1200] loss per section; Denoising: 0.000017, Upsampling: 0.001180, Disamiguation: 0.000373
# [45,  1200] loss : 0.001569
# [45,  1600] loss per section; Denoising: 0.000020, Upsampling: 0.001294, Disamiguation: 0.000342
# [45,  1600] loss : 0.001655
# [46,   400] loss per section; Denoising: 0.000017, Upsampling: 0.001114, Disamiguation: 0.000359
# [46,   400] loss : 0.001490
# [46,   800] loss per section; Denoising: 0.000043, Upsampling: 0.001212, Disamiguation: 0.000352
# [46,   800] loss : 0.001606
# [46,  1200] loss per section; Denoising: 0.000017, Upsampling: 0.001169, Disamiguation: 0.000367
# [46,  1200] loss : 0.001553
# [46,  1600] loss per section; Denoising: 0.000019, Upsampling: 0.001284, Disamiguation: 0.000323
# [46,  1600] loss : 0.001626
# [47,   400] loss per section; Denoising: 0.000016, Upsampling: 0.001096, Disamiguation: 0.000328
# [47,   400] loss : 0.001439
# [47,   800] loss per section; Denoising: 0.000042, Upsampling: 0.001198, Disamiguation: 0.000343
# [47,   800] loss : 0.001583
# [47,  1200] loss per section; Denoising: 0.000017, Upsampling: 0.001159, Disamiguation: 0.000365
# [47,  1200] loss : 0.001541
# [47,  1600] loss per section; Denoising: 0.000019, Upsampling: 0.001276, Disamiguation: 0.000315
# [47,  1600] loss : 0.001610
# [48,   400] loss per section; Denoising: 0.000016, Upsampling: 0.001088, Disamiguation: 0.000320
# [48,   400] loss : 0.001424
# [48,   800] loss per section; Denoising: 0.000042, Upsampling: 0.001192, Disamiguation: 0.000339
# [48,   800] loss : 0.001573
# [48,  1200] loss per section; Denoising: 0.000016, Upsampling: 0.001152, Disamiguation: 0.000367
# [48,  1200] loss : 0.001535
# [48,  1600] loss per section; Denoising: 0.000019, Upsampling: 0.001272, Disamiguation: 0.000311
# [48,  1600] loss : 0.001602
# [49,   400] loss per section; Denoising: 0.000016, Upsampling: 0.001083, Disamiguation: 0.000316
# [49,   400] loss : 0.001415
# [49,   800] loss per section; Denoising: 0.000042, Upsampling: 0.001189, Disamiguation: 0.000321
# [49,   800] loss : 0.001552
# [49,  1200] loss per section; Denoising: 0.000017, Upsampling: 0.001147, Disamiguation: 0.000356
# [49,  1200] loss : 0.001519
# [49,  1600] loss per section; Denoising: 0.000019, Upsampling: 0.001267, Disamiguation: 0.000292
# [49,  1600] loss : 0.001577
# [50,   400] loss per section; Denoising: 0.000016, Upsampling: 0.001081, Disamiguation: 0.000310
# [50,   400] loss : 0.001407
# [50,   800] loss per section; Denoising: 0.000041, Upsampling: 0.001185, Disamiguation: 0.000325
# [50,   800] loss : 0.001551
# [50,  1200] loss per section; Denoising: 0.000016, Upsampling: 0.001142, Disamiguation: 0.000353
# [50,  1200] loss : 0.001511
# [50,  1600] loss per section; Denoising: 0.000019, Upsampling: 0.001262, Disamiguation: 0.000303
# [50,  1600] loss : 0.001583
# The lowest was:  0.0012985114008188248
# Finished Training

# %%
#Print only the output images
def show_output_images(outputs):
    
    fig = plt.figure(figsize = (20, 14))
    rows = 4
    columns = 4
    j=0
    for i in range(1,columns*rows+1):
        #Denoising
        if i >= 1 and i < 5:
            fig.add_subplot(rows, columns, i)
            plt.imshow(outputs[0][i].cpu().detach().numpy().reshape(7,7), cmap='gray')
        
        #Upsampling
        if i >= 5 and i < 9:
            fig.add_subplot(rows, columns, i)
            plt.imshow(outputs[1][i-4].cpu().detach().numpy().reshape(28,28), cmap='gray')
        
        #Disambiguation
        if i >= 9 and i< 13:
            fig.add_subplot(rows, columns, i)
            plt.imshow(outputs[2][i-8][:784].cpu().detach().numpy().reshape(28,28), cmap='gray')
        if i >= 13 and i< 17:
            fig.add_subplot(rows, columns, i)
            plt.imshow(outputs[2][i-12][784:].cpu().detach().numpy().reshape(28,28), cmap='gray')

# %%
show_output_images(output)

# %%
#Print only the input images
def show_input_images(inputs):
    
    fig = plt.figure(figsize = (20, 14))
    rows = 5
    columns = 4
    j=0
    for i in range(1,columns*rows+1):
        # Denoising
        if i >=1 and i< 5:
            fig.add_subplot(rows, columns, i)
            plt.imshow(inputs[0][i].cpu().detach().numpy().reshape(7,7), cmap='gray')
            
        #Upsampling
        if i >=5 and i< 9:
            fig.add_subplot(rows, columns, i)
            plt.imshow(inputs[1][0][i-4].cpu().detach().numpy().reshape(7,7), cmap='gray')
            
        #Disambiguation
        if i >= 9 and i < 13:
            fig.add_subplot(rows, columns, i)
            plt.imshow(inputs[1][1][i-8].cpu().detach().numpy().reshape(28,28), cmap='gray')
        
        if i >= 13 and i < 17:
            fig.add_subplot(rows, columns, i)
            plt.imshow(inputs[1][2][i-12].cpu().detach().numpy().reshape(28,28), cmap='gray')
        
        if i >= 17 and i < 21:
            fig.add_subplot(rows, columns, i)
            plt.imshow(inputs[1][3][i-16].cpu().detach().numpy().reshape(28,28), cmap='gray')

# %%
show_input_images(inputs=data)

# %%
testing_superimposed = MNISTsuperimposed("./MNIST data/train", train = False, download = True, transform = transform, target_transform=target_transform)
testset = DataLoader(testing_superimposed, batch_size=batch, shuffle = False)
outputs, test_data, test_loss = train_test(AEnet, testset, False)
# Out:
# [   10] loss per image: 0.006111
# [   20] loss per image: 0.006155
# [   30] loss per image: 0.006381
# [   40] loss per image: 0.006065
# [   50] loss per image: 0.006253
# [   60] loss per image: 0.005951
# [   70] loss per image: 0.005809
# [   80] loss per image: 0.006287
# [   90] loss per image: 0.005557
# [  100] loss per image: 0.006260
# [  110] loss per image: 0.006148
# [  120] loss per image: 0.006701
# [  130] loss per image: 0.006504
# [  140] loss per image: 0.006326
# [  150] loss per image: 0.006090
# [  160] loss per image: 0.006072
# [  170] loss per image: 0.005927
# [  180] loss per image: 0.006664
# [  190] loss per image: 0.006399
# [  200] loss per image: 0.006260
# [  210] loss per image: 0.006748
# [  220] loss per image: 0.006091
# [  230] loss per image: 0.006221
# [  240] loss per image: 0.005492
# [  250] loss per image: 0.006570
# [  260] loss per image: 0.006187
# [  270] loss per image: 0.006263
# [  280] loss per image: 0.006221
# [  290] loss per image: 0.005976
# [  300] loss per image: 0.006276
# [  310] loss per image: 0.006170
# The lowest was:  0.00015784527931828052
# Finished Testing

# %%
show_output_images(outputs)

# %%
show_input_images(inputs = test_data)

# %%
#Print only the output images
def show_output_images(dataset, outputs, training = True):
    
    fig = plt.figure(figsize = (20, 38))
    rows = 7
    columns = 4
    offset = 11
    for i in range(1,columns*rows+1):
        if i >=1 and i< 5:
            fig.add_subplot(rows, columns, i)
            plt.axis('off')
            plt.title('True Image')
            if i == 1:
                plt.imshow(dataset[1][2][1].cpu().detach().numpy().reshape(28,28), cmap='gray')
            elif i == 2:
                plt.imshow(dataset[1][2][4].cpu().detach().numpy().reshape(28,28), cmap='gray')
            elif i == 3:
                plt.imshow(dataset[1][2][9].cpu().detach().numpy().reshape(28,28), cmap='gray')
            elif i == 4:
                plt.imshow(dataset[1][2][11].cpu().detach().numpy().reshape(28,28), cmap='gray')
            else:
                plt.imshow(dataset[1][2][i + offset].cpu().detach().numpy().reshape(28,28), cmap='gray')
        if i >=5 and i< 9:
            fig.add_subplot(rows, columns, i)
            plt.axis('off')
            plt.title("True Image'")
            if i == 5:
                plt.imshow(dataset[1][3][1].cpu().detach().numpy().reshape(28,28), cmap='gray')
            elif i==6:
                plt.imshow(dataset[1][3][4].cpu().detach().numpy().reshape(28,28), cmap='gray')
            elif i==7:
                plt.imshow(dataset[1][3][9].cpu().detach().numpy().reshape(28,28), cmap='gray')
            elif i == 8:
                plt.imshow(dataset[1][3][11].cpu().detach().numpy().reshape(28,28), cmap='gray')
            else:
                plt.imshow(dataset[1][3][i-4 + offset].cpu().detach().numpy().reshape(28,28), cmap='gray')
        if i >=9 and i < 13:
            fig.add_subplot(rows, columns, i)
            plt.axis('off')
            plt.title("Superimposed")
            if i == 9:
                plt.imshow(dataset[1][1][1].cpu().detach().numpy().reshape(28,28), cmap='gray')
            elif i==10:
                plt.imshow(dataset[1][1][4].cpu().detach().numpy().reshape(28,28), cmap='gray')
            elif i==11:
                plt.imshow(dataset[1][1][9].cpu().detach().numpy().reshape(28,28), cmap='gray')
            elif i == 12:
                plt.imshow(dataset[1][1][11].cpu().detach().numpy().reshape(28,28), cmap='gray')
            else:
                plt.imshow(dataset[1][1][i-8 + offset].cpu().detach().numpy().reshape(28,28), cmap='gray')
        if i >=13 and i < 17:
            fig.add_subplot(rows, columns, i)
            plt.axis('off')
            plt.title("Downsampled")
            if i == 13:
                plt.imshow(dataset[1][0][1].squeeze(0), cmap='gray')
            elif i==14:
                plt.imshow(dataset[1][0][4].squeeze(0), cmap='gray')
            elif i==15:
                plt.imshow(dataset[1][0][9].squeeze(0), cmap='gray')
            elif i == 16:
                plt.imshow(dataset[1][0][11].squeeze(0), cmap='gray')
            else:
                plt.imshow(dataset[1][0][i-12 + offset].squeeze(0), cmap = 'gray')
        if i >=17 and i < 21:
            fig.add_subplot(rows, columns, i)
            plt.axis('off')
            plt.title('Noisy')
            if i == 17:
                plt.imshow(dataset[0][1].cpu().detach().numpy().reshape(7,7), cmap='gray')
            elif i==18:
                plt.imshow(dataset[0][4].cpu().detach().numpy().reshape(7,7), cmap='gray')
            elif i==19:
                plt.imshow(dataset[0][9].cpu().detach().numpy().reshape(7,7), cmap='gray')
            elif i == 20:
                plt.imshow(dataset[0][11].cpu().detach().numpy().reshape(7,7), cmap='gray')
            else:
                plt.imshow(dataset[0][i-16 + offset].cpu().detach().numpy().reshape(7,7), cmap = 'gray')
        if i >=21 and i < 25:
            fig.add_subplot(rows, columns, i)
            plt.title("Recon Image")
            if i == 21:
                mse = criterion2(outputs[2][1][:784].float().to(device),torch.flatten(data[1][2],1).float().to(device))
                plt.xlabel('MSE: {:6f}'.format(mse/32))
                plt.imshow(outputs[2][1][:784].cpu().detach().numpy().reshape(28,28), cmap='gray')
            elif i==22:
                mse = criterion2(outputs[2][4][:784].float().to(device),torch.flatten(data[1][2],1).float().to(device))
                plt.xlabel('MSE: {:6f}'.format(mse/32))
                plt.imshow(outputs[2][4][:784].cpu().detach().numpy().reshape(28,28), cmap='gray')
            elif i==23:
                mse = criterion2(outputs[2][9][:784].float().to(device),torch.flatten(data[1][2],1).float().to(device))
                plt.xlabel('MSE: {:6f}'.format(mse/32))
                plt.imshow(outputs[2][9][:784].cpu().detach().numpy().reshape(28,28), cmap='gray')
            elif i == 24:
                mse = criterion2(outputs[2][11][:784].float().to(device),torch.flatten(data[1][2],1).float().to(device))
                plt.xlabel('MSE: {:6f}'.format(mse/32))
                plt.imshow(outputs[2][11][:784].cpu().detach().numpy().reshape(28,28), cmap='gray')
            else:
                mse = criterion2(outputs[2][i-20 + offset][:784].float().to(device),torch.flatten(data[1][2],1).float().to(device))
                plt.xlabel('MSE: {:6f}'.format(mse/32))
                plt.imshow(outputs[2][i-20 + offset][:784].cpu().detach().numpy().reshape(28,28), cmap='gray')
        if i >=25 and i < 29:    
            fig.add_subplot(rows, columns, i)
            plt.title("Recon Image")
            if i == 25:
                mse = criterion2(outputs[2][1][784:].float().to(device),torch.flatten(data[1][3],1).float().to(device))
                plt.xlabel('MSE: {:6f}'.format(mse/32))
                plt.imshow(outputs[2][1][784:].cpu().detach().numpy().reshape(28,28), cmap='gray')
            elif i==26:
                mse = criterion2(outputs[2][4][784:].float().to(device),torch.flatten(data[1][3],1).float().to(device))
                plt.xlabel('MSE: {:6f}'.format(mse/32))
                plt.imshow(outputs[2][4][784:].cpu().detach().numpy().reshape(28,28), cmap='gray')
            elif i==27:
                mse = criterion2(outputs[2][9][784:].float().to(device),torch.flatten(data[1][3],1).float().to(device))
                plt.xlabel('MSE: {:6f}'.format(mse/32))
                plt.imshow(outputs[2][9][784:].cpu().detach().numpy().reshape(28,28), cmap='gray')
            elif i == 28:
                mse = criterion2(outputs[2][11][784:].float().to(device),torch.flatten(data[1][3],1).float().to(device))
                plt.xlabel('MSE: {:6f}'.format(mse/32))
                plt.imshow(outputs[2][11][784:].cpu().detach().numpy().reshape(28,28), cmap='gray')
            else:
                mse = criterion2(outputs[2][i-24 + offset][784:].float().to(device),torch.flatten(data[1][3],1).float().to(device))
                plt.xlabel('MSE: {:6f}'.format(mse/32))
                plt.imshow(outputs[2][i-24 + offset][784:].cpu().detach().numpy().reshape(28,28), cmap='gray')
    plt.savefig('RNN_with_Noise_1e-4.PNG')

# %%
show_output_images(test_data, outputs)
# Out:
# /opt/conda/lib/python3.8/site-packages/torch/nn/modules/loss.py:447: UserWarning: Using a target size (torch.Size([32, 784])) that is different to the input size (torch.Size([784])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)

# %% [markdown]
# ## Loss Plots

# %%
def plot_loss(loss, Training = True):
    fig = plt.figure(figsize = (10, 7))
    
    if Training == True:
        x = list(np.arange(0.0, 50.0, 0.25))
        plt.axis("on")
        plt.ylabel('Loss')
        plt.xlabel('Epoch')
        plt.title("Training Loss")
        plt.plot(x, loss)
        plt.savefig('RNN_with_Noise_1e-4_training_loss.PNG')
    else:
        x = list(range(0, len(loss), 1))
        plt.axis("on")
        plt.ylabel('Loss')
        plt.xlabel('Epoch')
        plt.title("Test Loss")
        plt.scatter(x, loss)
        plt.plot(x, loss)

# %%
plot_loss(training_loss)

# %%
plot_loss(test_loss, False)
