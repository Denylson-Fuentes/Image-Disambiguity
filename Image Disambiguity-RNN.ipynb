# %%
import torch as torch
import torchvision as tv
import torch.nn.functional as F
from torchvision import datasets
from torchvision import transforms
import matplotlib.pyplot as plt
import matplotlib.image as image
import cv2 as cv
from PIL import Image
import numpy as np
from torchvision.datasets.vision import VisionDataset
from typing import Any, Callable, Dict, List, Optional, Tuple
import os
import os.path
from torch import nn
from torchvision.datasets.mnist import read_image_file, read_label_file
from torchvision.datasets.utils import download_and_extract_archive, extract_archive, verify_str_arg, check_integrity
from skimage.util import random_noise

# %%
class MNISTsuperimposed(VisionDataset):
    """`MNIST <http://yann.lecun.com/exdb/mnist/>`_ Dataset.

    Args:
        root (string): Root directory of dataset where ``MNIST/processed/training.pt``
            and  ``MNIST/processed/test.pt`` exist.
        train (bool, optional): If True, creates dataset from ``training.pt``,
            otherwise from ``test.pt``.
        download (bool, optional): If true, downloads the dataset from the internet and
            puts it in root directory. If dataset is already downloaded, it is not
            downloaded again.
        transform (callable, optional): A function/transform that  takes in an PIL image
            and returns a transformed version. E.g, ``transforms.RandomCrop``
        target_transform (callable, optional): A function/transform that takes in the
            target and transforms it.
    """

    mirrors = [
        'http://yann.lecun.com/exdb/mnist/',
        'https://ossci-datasets.s3.amazonaws.com/mnist/',
    ]

    resources = [
        ("train-images-idx3-ubyte.gz", "f68b3c2dcbeaaa9fbdd348bbdeb94873"),
        ("train-labels-idx1-ubyte.gz", "d53e105ee54ea40749a09fcbcd1e9432"),
        ("t10k-images-idx3-ubyte.gz", "9fb629c4189551a2d022fa330f9573f3"),
        ("t10k-labels-idx1-ubyte.gz", "ec29112dd5afa0611ce80d1b7f02629c")
    ]

    training_file = 'training.pt'
    test_file = 'test.pt'
    classes = ['0 - zero', '1 - one', '2 - two', '3 - three', '4 - four',
               '5 - five', '6 - six', '7 - seven', '8 - eight', '9 - nine']

    @property
    def train_labels(self):
        warnings.warn("train_labels has been renamed targets")
        return self.targets

    @property
    def test_labels(self):
        warnings.warn("test_labels has been renamed targets")
        return self.targets

    @property
    def train_data(self):
        warnings.warn("train_data has been renamed data")
        return self.data

    @property
    def test_data(self):
        warnings.warn("test_data has been renamed data")
        return self.data

    def __init__(
            self,
            root,
            train= True,
            transform = None,
            target_transform = None,
            download = False,
    ):
        super(MNISTsuperimposed, self).__init__(root, transform=transform,
                                    target_transform=target_transform)
        self.train = train  # training set or test set

        if self._check_legacy_exist():
            self.data, self.targets, self.targets = self._load_legacy_data()

        if download:
            self.download()

        if not self._check_exists():
            raise RuntimeError('Dataset not found.' +
                               ' You can use download=True to download it')

        self.data, self.targets = self._load_data()
        
    def _check_legacy_exist(self):
        processed_folder_exists = os.path.exists(self.processed_folder)
        if not processed_folder_exists:
            return False

        return all(
            check_integrity(os.path.join(self.processed_folder, file)) for file in (self.training_file, self.test_file)
        )

    def _load_legacy_data(self):
        # This is for BC only. We no longer cache the data in a custom binary, but simply read from the raw data
        # directly.
        data_file = self.training_file if self.train else self.test_file
        return torch.load(os.path.join(self.processed_folder, data_file))

    def _load_data(self):
        image_file = f"{'train' if self.train else 't10k'}-images-idx3-ubyte"
        data = read_image_file(os.path.join(self.raw_folder, image_file))
        #Technically, we do not even need the labels for now
        # We just need the clean images of both types
        randata = data[torch.randperm(data.shape[0]),:,:]
        targets = (data, randata)
        
        
        # Now do the ambiguation here
        data1 = data + randata
        targets = (data1, data, randata)
        return data1, targets

    def __getitem__(self, index):
        """
        Args:
            index (int): Index

        Returns:
            tuple: (image, target) where target is index of the target class.
        """
        img, target = self.data[index], (self.targets[0][index], self.targets[1][index], self.targets[2][index])
        # doing this so that it is consistent with all other datasets
        # to return a PIL Imagedata[torch.randperm(data.shape[0]),:,:]
        img = Image.fromarray(img.numpy(), mode='L')
        target0 = Image.fromarray(target[0].numpy(), mode='L')
        target1 = Image.fromarray(target[1].numpy(), mode='L')
        target2 = Image.fromarray(target[2].numpy(), mode='L')

        if self.transform is not None:
            img = self.transform(img)

        if self.target_transform is not None:
            target = (self.target_transform[0](target0), self.target_transform[1](target0), self.target_transform[1](target1), self.target_transform[1](target2))
            

        return img, target

    def __len__(self):
        return len(self.data)

    @property
    def raw_folder(self):
        return os.path.join(self.root, self.__class__.__name__, 'raw')

    @property
    def processed_folder(self) -> str:
        return os.path.join(self.root, self.__class__.__name__, 'processed')

    @property
    def class_to_idx(self):
        return {_class: i for i, _class in enumerate(self.classes)}

    def _check_exists(self):
        return all(
            check_integrity(os.path.join(self.raw_folder, os.path.splitext(os.path.basename(url))[0]))
            for url, _ in self.resources
        )

    def download(self):
        """Download the MNIST data if it doesn't exist already."""

        if self._check_exists():
            return

        os.makedirs(self.raw_folder, exist_ok=True)

        # download files
        for filename, md5 in self.resources:
            for mirror in self.mirrors:
                url = "{}{}".format(mirror, filename)
                try:
                    print("Downloading {}".format(url))
                    download_and_extract_archive(
                        url, download_root=self.raw_folder,
                        filename=filename,
                        md5=md5
                    )
                except URLError as error:
                    print(
                        "Failed to download (trying next):\n{}".format(error)
                    )
                    continue
                finally:
                    print()
                break
            else:
                raise RuntimeError("Error downloading {}".format(filename))

    def extra_repr(self) -> str:
        return "Split: {}".format("Train" if self.train is True else "Test")

# %%
class Downsample(object):
    def __init__(self, size=[1,196]):
        self.size=size

    def __call__(self, tensor):
        img = np.squeeze(tensor)
        m = torch.nn.AvgPool2d(2, stride=2)
        return m(img.unsqueeze(0))

    def __repr__(self):
        return self.__class__.__name__+'({})'.format(self.size)

# %%
class AddGaussNoise(object):
    def __init__(self, mean=0, std=0.001):
        self.std=std
        self.mean=mean
        
    def __call__(self, tensor):
#         print(tensor + torch.randn(tensor.size()) * self.std + self.mean)
        return torch.tensor(random_noise(tensor,mean=self.mean,var=self.std))

    def __repr__(self):
        return self.__class__.__name__+'(mean={0},std={1})'.format(self.mean, self.std)

# %%
transform = transforms.Compose(
    [transforms.Grayscale(),
     transforms.ToTensor(),
     Downsample(),
     AddGaussNoise(0,1e-2)
     ])
target1_transform= transforms.Compose(
    [transforms.Grayscale(),
     transforms.ToTensor(),
     Downsample(),
     ])
target2_transform = transforms.Compose(
    [transforms.Grayscale(),
     transforms.ToTensor(),
     ])

target_transform = [target1_transform, target2_transform]
mnist_superimposed = MNISTsuperimposed("./MNIST data/train", train = True, download = True, transform = transform, target_transform=target_transform)
# Out:
# /opt/conda/lib/python3.8/site-packages/torchvision/datasets/mnist.py:480: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  ../torch/csrc/utils/tensor_numpy.cpp:137.)
#   return torch.from_numpy(parsed.astype(m[2], copy=False)).view(*s)

# %%
from torch.utils.data import DataLoader
trainset = DataLoader(mnist_superimposed, batch_size=32, shuffle = False)

# %%
def show_images(dataset, training = True):
    
    fig = plt.figure(figsize = (20, 14))
    rows = 5
    columns = 4
    j=0
    for i in range(1,columns*rows+1):
        
        if i >=1 and i<5:
            fig.add_subplot(rows, columns, i)
            plt.imshow(dataset[i][0].squeeze(0), cmap='gray')
            
        if i >=5 and i<9:
            fig.add_subplot(rows, columns, i)
            plt.imshow(dataset[i-4][1][0].squeeze(0), cmap='gray')
            
        if i >=9 and i < 13:
            fig.add_subplot(rows, columns, i)
            plt.imshow(dataset[i-8][1][1].squeeze(0), cmap='gray')
            
        if i >= 13 and i<17:
            fig.add_subplot(rows, columns, i)
            plt.imshow(dataset[i-12][1][2].squeeze(0), cmap='gray')
        
        if i >= 17 and i<21:
            fig.add_subplot(rows, columns, i)
            plt.imshow(dataset[i-16][1][3].squeeze(0), cmap='gray')

# %%
show_images(mnist_superimposed)

# %%
import torch
from torch import nn as nn
from torch.nn import Conv2d, ConvTranspose2d, Linear, Sequential, Flatten, ReLU

# %%
print(torch.cuda.is_available())
# Out:
# True

# %%
class Trash(nn.Module):
    def __init__(self, inplace = False):
        super(Trash,self).__init__()
            
        self.Encoder = nn.Sequential(
            nn.Conv2d(1, 32, kernel_size = 3, padding = 1, stride = 1),
            nn.BatchNorm2d(32),
            nn.ReLU(inplace),
            nn.Conv2d(32, 64, kernel_size = 3, padding = 1, stride = 1),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace),

            nn.Conv2d(64, 128, kernel_size = 3, padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.Conv2d(128, 256, kernel_size = 3, padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.MaxPool2d(kernel_size = (2, 2)),                      
        )

        self.Decoder = nn.Sequential(
            nn.Conv2d(256, 128, kernel_size = 3, padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.Conv2d(128, 64, kernel_size = 3, padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.ConvTranspose2d(in_channels = 64, out_channels = 64, kernel_size = (2, 2), stride = 2), 
            
            nn.Conv2d(64, 8, kernel_size = 3, padding = 1, stride = 1),
            nn.BatchNorm2d(8),
            nn.ReLU(inplace),
            nn.Conv2d(8, 1, kernel_size = 3, padding = 1, stride = 1),
            nn.ReLU(inplace),
        )
        
        self.Upsample = nn.Sequential(
            nn.Flatten(start_dim = 1),
            nn.Linear(196, 256),
            nn.Linear(256, 256),
            nn.ReLU(inplace),
            
            nn.Linear(256, 512),
            nn.Linear(512, 784),
            nn.Linear(784, 784),
            nn.Sigmoid(),
        )
        
        self.initial_Processing = nn.Sequential(
            nn.Conv2d(in_channels = 1, out_channels = 64, kernel_size = 3, padding = 1, stride = 1),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace),
            nn.Conv2d(in_channels = 64, out_channels = 128, kernel_size = 3, padding =1, stride = 1),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace),
        )

        self.Down_1 = nn.Sequential(
            nn.Conv2d(in_channels = 128, out_channels = 512, kernel_size = (3, 3), padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.Conv2d(in_channels = 512, out_channels = 512, kernel_size = (3, 3), padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.MaxPool2d(kernel_size = (2, 2)),
        )

        self.Down_2 = nn.Sequential(
            nn.Conv2d(in_channels = 512, out_channels = 256, kernel_size = (3, 3), padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.Conv2d(in_channels = 256, out_channels = 256, kernel_size = (3, 3), padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.MaxPool2d(kernel_size = (2, 2)),
        )


        self.Down_3 = nn.Sequential(
            nn.Conv2d(in_channels = 256, out_channels = 128, kernel_size = (3, 3), padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.Conv2d(in_channels = 128, out_channels = 128, kernel_size = (3, 3), padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.MaxPool2d(kernel_size = (2, 2)),
        )

        self.Down_4 = nn.Sequential(
            nn.Conv2d(in_channels = 128, out_channels = 64, kernel_size = (3, 3), padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.Conv2d(in_channels = 64, out_channels = 64, kernel_size = (3, 3), padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.MaxPool2d(kernel_size = (2, 2)),
        )

        self.Up_1 = nn.Sequential(
            nn.Conv2d(in_channels = 64, out_channels = 64, kernel_size = (3, 3), padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.Conv2d(in_channels = 64, out_channels = 32, kernel_size = (3, 3), padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.ConvTranspose2d(in_channels = 32, out_channels = 64, kernel_size = (2, 2))
        )

        self.Up_2 = nn.Sequential(
            nn.Conv2d(in_channels = 128, out_channels = 128, kernel_size = (3, 3), padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.Conv2d(in_channels = 128, out_channels = 64, kernel_size = (3, 3), padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.ConvTranspose2d(in_channels = 64, out_channels = 128, kernel_size = (2, 2))
        )

        self.Up_3 = nn.Sequential(
            nn.Conv2d(in_channels = 256, out_channels = 256, kernel_size = (3, 3), padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.Conv2d(in_channels = 256, out_channels = 128, kernel_size = (3, 3), padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.ConvTranspose2d(in_channels = 128, out_channels = 256, kernel_size = (2, 2))
        )

        self.Up_4 = nn.Sequential(
            nn.Conv2d(in_channels = 512, out_channels = 512, kernel_size = (3, 3), padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.Conv2d(in_channels = 512, out_channels = 256, kernel_size = (3, 3), padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.ConvTranspose2d(in_channels = 256, out_channels = 512, kernel_size = (2, 2))
        )

        self.Up_5 = nn.Sequential(
            nn.Conv2d(in_channels = 1024, out_channels = 512, kernel_size = (3, 3), padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.Conv2d(in_channels = 512, out_channels = 512, kernel_size = (3, 3), padding = 1, stride = 1),
            nn.ReLU(inplace),
            nn.ConvTranspose2d(in_channels = 512, out_channels = 2, kernel_size = (1, 1)),
        )
        
        self.Final = nn.Sequential(
            nn.Flatten(start_dim = 1),
            nn.Linear(392, 512),
            nn.Linear(512, 512),
            nn.ReLU(inplace),
            
            nn.Linear(512, 1024),
            nn.Linear(1024, 1568),
            nn.Linear(1568, 1568),
            nn.Sigmoid(),
        )
        
    def forward(self,x, flag):
#         print(x[0].shape, x[1].shape, x[2].shape)
        outputs=[]
        
        
        if flag:
            
            # ENCODER
            output = self.Encoder[:6](x[0])
            output = self.Encoder[6:](output)
            
            # DECODER
            output = self.Decoder[:5](output)
            output = self.Decoder[5:](output)
            
            outputs.append(output)
            
            # UPSAMPLE
            
            output = self.Upsample[:2](x[1])
            output = self.Upsample[3:6](output + self.Upsample[2](output))
            output = self.Upsample[7](output + self.Upsample[6](output))
            outputs.append(output)
            
            
            # DISAMBIGUATION
            
            output = self.initial_Processing(x[2])
            
            output = self.Down_1(output)
            output_1 = output


            output = self.Down_2(output)
            output_2 = output

            output = self.Down_3(output)
            output_3 = output

            output = self.Down_4(output)
            output_4 = output




            output = self.Up_1(output)
            diffY = output_4.size()[2] - output.size()[2]
            diffX = output_4.size()[3] - output.size()[3]
            output = F.pad(output, [diffX // 2, diffX - diffX // 2,
                            diffY // 2, diffY - diffY // 2])
            output = torch.cat([output_4, output], dim=1)


            output = self.Up_2(output)
            diffY = output_3.size()[2] - output.size()[2]
            diffX = output_3.size()[3] - output.size()[3]
            output = F.pad(output, [diffX // 2, diffX - diffX // 2,
                            diffY // 2, diffY - diffY // 2])
            output = torch.cat([output_3, output], dim=1)


            output = self.Up_3(output)
            diffY = output_2.size()[2] - output.size()[2]
            diffX = output_2.size()[3] - output.size()[3]
            output = F.pad(output, [diffX // 2, diffX - diffX // 2,
                            diffY // 2, diffY - diffY // 2])
            output = torch.cat([output_2, output], dim=1)


            output = self.Up_4(output)
            diffY = output_1.size()[2] - output.size()[2]
            diffX = output_1.size()[3] - output.size()[3]
            output = F.pad(output, [diffX // 2, diffX - diffX // 2,
                            diffY // 2, diffY - diffY // 2])
            output = torch.cat([output_1, output], dim=1)


            output = self.Up_5(output)  
            
            output = self.Final(output)
            
            outputs.append(output)
            
        
            
        else:
            # ENCODER
            output = self.Encoder[:6](x)
            output = self.Encoder[6:](output)
            
            # DECODER
            output = self.Decoder[:5](output)
            output = self.Decoder[5:](output)
            
            outputs.append(output)
            
            # UPSAMPLE
            
            output = self.Upsample(output)
            outputs.append(output)
            
            output = output.reshape(output.shape[0], 1, 28, 28)
            # DISAMBIGUATION
            
            output = self.initial_Processing(output)
            
            output = self.Down_1(output)
            output_1 = output


            output = self.Down_2(output)
            output_2 = output

            output = self.Down_3(output)
            output_3 = output

            output = self.Down_4(output)
            output_4 = output




            output = self.Up_1(output)
            diffY = output_4.size()[2] - output.size()[2]
            diffX = output_4.size()[3] - output.size()[3]
            output = F.pad(output, [diffX // 2, diffX - diffX // 2,
                            diffY // 2, diffY - diffY // 2])
            output = torch.cat([output_4, output], dim=1)


            output = self.Up_2(output)
            diffY = output_3.size()[2] - output.size()[2]
            diffX = output_3.size()[3] - output.size()[3]
            output = F.pad(output, [diffX // 2, diffX - diffX // 2,
                            diffY // 2, diffY - diffY // 2])
            output = torch.cat([output_3, output], dim=1)


            output = self.Up_3(output)
            diffY = output_2.size()[2] - output.size()[2]
            diffX = output_2.size()[3] - output.size()[3]
            output = F.pad(output, [diffX // 2, diffX - diffX // 2,
                            diffY // 2, diffY - diffY // 2])
            output = torch.cat([output_2, output], dim=1)


            output = self.Up_4(output)
            diffY = output_1.size()[2] - output.size()[2]
            diffX = output_1.size()[3] - output.size()[3]
            output = F.pad(output, [diffX // 2, diffX - diffX // 2,
                            diffY // 2, diffY - diffY // 2])
            output = torch.cat([output_1, output], dim=1)


            output = self.Up_5(output)      
            
            output = self.Final(output)
            
            outputs.append(output)
            
        
#         print(outputs[0].shape, outputs[1].shape, outputs[2].shape)
            
        return outputs

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
AEnet = Trash(inplace = True).to(device)
optimizer = torch.optim.Adam(AEnet.parameters(), lr=0.000035)
# criterion2 = nn.BCEWithLogitsLoss()
criterion2 = nn.MSELoss()
print(device)
# Out:
# cuda

# %%
def train_test(AEnet, dataset, Training = True):

    if Training:
        epochs = 100
        train_loss = []
        t_loss = []
        flag = True
        for epoch in range(epochs):
            running_loss = 0.0
            for i, data in enumerate(dataset):
                optimizer.zero_grad()
                outputs = AEnet((data[0].float().to(device) , data[1][0].float().to(device), data[1][1].float().to(device)), flag=True)

                loss1 = criterion2(torch.flatten(outputs[0],1).float().to(device),torch.flatten(data[1][0],1).float().to(device))
                loss2 = criterion2(outputs[1].float().to(device),torch.flatten(data[1][1],1).float().to(device))
                loss3 = criterion2(outputs[2][:, :784].float().to(device),torch.flatten(data[1][2],1).float().to(device))
                loss4 = criterion2(outputs[2][:, 784:].float().to(device),torch.flatten(data[1][3],1).float().to(device))

                loss =  loss1 + loss2 + loss3 + loss4
                loss.backward()
                optimizer.step()
                train_loss.append(loss.item())
                running_loss += loss.item()
                if i % 400 == 399:
                    print('[%d, %5d] loss : %.6f' %
                          (epoch + 1, i + 1, loss.item()))
                    t_loss.append(loss.item())
                
            

            
        print("The lowest was: ", min(train_loss)/32)

        print('Finished Training')
        flag = False
        return outputs, data, t_loss
            
    else:
        testing_loss = []
        t_loss = []
        with torch.no_grad():
            for i, data in enumerate(dataset):
                    optimizer.zero_grad()
                    outputs = AEnet(data[0].float().to(device), flag = False)
                    loss1 = criterion2(torch.flatten(outputs[0],1).float().to(device),torch.flatten(data[1][0],1).float().to(device))
                    loss2 = criterion2(outputs[1].float().to(device),torch.flatten(data[1][1],1).float().to(device))
                    loss3 = criterion2(outputs[2][:, :784].float().to(device),torch.flatten(data[1][2],1).float().to(device))
                    loss4 = criterion2(outputs[2][:, 784:].float().to(device),torch.flatten(data[1][3],1).float().to(device))

                    loss =  loss1 + loss2 + loss3 + loss4
                    testing_loss.append(loss.item())
                    if i % 10 == 9:
                        print('[%5d] loss per image: %.6f' %
                              (i + 1, loss.item()/32))
                        t_loss.append(loss.item()/32)
                    
        print("The lowest was: ", min(testing_loss)/32)
        print('Finished Testing')
        return outputs, data, t_loss

# %%
output, data, training_loss= train_test(AEnet, trainset)
# Out:
# [1,   400] loss : 0.177832
# [1,   800] loss : 0.159356
# [1,  1200] loss : 0.151497
# [1,  1600] loss : 0.144107
# [2,   400] loss : 0.130693
# [2,   800] loss : 0.127250
# [2,  1200] loss : 0.128538
# [2,  1600] loss : 0.123776
# [3,   400] loss : 0.117519
# [3,   800] loss : 0.115587
# [3,  1200] loss : 0.118418
# [3,  1600] loss : 0.114081
# [4,   400] loss : 0.109114
# [4,   800] loss : 0.109409
# [4,  1200] loss : 0.112747
# [4,  1600] loss : 0.109557
# [5,   400] loss : 0.104871
# [5,   800] loss : 0.105498
# [5,  1200] loss : 0.108977
# [5,  1600] loss : 0.106220
# [6,   400] loss : 0.101642
# [6,   800] loss : 0.103297
# [6,  1200] loss : 0.106317
# [6,  1600] loss : 0.103785
# [7,   400] loss : 0.099557
# [7,   800] loss : 0.101357
# [7,  1200] loss : 0.104276
# [7,  1600] loss : 0.101919
# [8,   400] loss : 0.097659
# [8,   800] loss : 0.099849
# [8,  1200] loss : 0.102334
# [8,  1600] loss : 0.100547
# [9,   400] loss : 0.095944
# [9,   800] loss : 0.098556
# [9,  1200] loss : 0.100550
# [9,  1600] loss : 0.099163
# [10,   400] loss : 0.094269
# [10,   800] loss : 0.096921
# [10,  1200] loss : 0.099335
# [10,  1600] loss : 0.097105
# [11,   400] loss : 0.089189
# [11,   800] loss : 0.094838
# [11,  1200] loss : 0.096496
# [11,  1600] loss : 0.094290
# [12,   400] loss : 0.083819
# [12,   800] loss : 0.087122
# [12,  1200] loss : 0.090656
# [12,  1600] loss : 0.089143
# [13,   400] loss : 0.078447
# [13,   800] loss : 0.084014
# [13,  1200] loss : 0.088380
# [13,  1600] loss : 0.086171
# [14,   400] loss : 0.075252
# [14,   800] loss : 0.079149
# [14,  1200] loss : 0.082510
# [14,  1600] loss : 0.080432
# [15,   400] loss : 0.069899
# [15,   800] loss : 0.074386
# [15,  1200] loss : 0.074488
# [15,  1600] loss : 0.074450
# [16,   400] loss : 0.065629
# [16,   800] loss : 0.071520
# [16,  1200] loss : 0.071863
# [16,  1600] loss : 0.070272
# [17,   400] loss : 0.063421
# [17,   800] loss : 0.064916
# [17,  1200] loss : 0.068826
# [17,  1600] loss : 0.064748
# [18,   400] loss : 0.060133
# [18,   800] loss : 0.060988
# [18,  1200] loss : 0.064764
# [18,  1600] loss : 0.061603
# [19,   400] loss : 0.058316
# [19,   800] loss : 0.057293
# [19,  1200] loss : 0.063279
# [19,  1600] loss : 0.058432
# [20,   400] loss : 0.055317
# [20,   800] loss : 0.054077
# [20,  1200] loss : 0.061264
# [20,  1600] loss : 0.056132
# [21,   400] loss : 0.052311
# [21,   800] loss : 0.052062
# [21,  1200] loss : 0.058037
# [21,  1600] loss : 0.054739
# [22,   400] loss : 0.050264
# [22,   800] loss : 0.050043
# [22,  1200] loss : 0.055938
# [22,  1600] loss : 0.053135
# [23,   400] loss : 0.048597
# [23,   800] loss : 0.049911
# [23,  1200] loss : 0.054111
# [23,  1600] loss : 0.051146
# [24,   400] loss : 0.049053
# [24,   800] loss : 0.046319
# [24,  1200] loss : 0.052768
# [24,  1600] loss : 0.048517
# [25,   400] loss : 0.047401
# [25,   800] loss : 0.045202
# [25,  1200] loss : 0.050297
# [25,  1600] loss : 0.048698
# [26,   400] loss : 0.046751
# [26,   800] loss : 0.044806
# [26,  1200] loss : 0.051318
# [26,  1600] loss : 0.048155
# [27,   400] loss : 0.045402
# [27,   800] loss : 0.043549
# [27,  1200] loss : 0.048116
# [27,  1600] loss : 0.045422
# [28,   400] loss : 0.043174
# [28,   800] loss : 0.041587
# [28,  1200] loss : 0.053643
# [28,  1600] loss : 0.044463
# [29,   400] loss : 0.042359
# [29,   800] loss : 0.041200
# [29,  1200] loss : 0.045864
# [29,  1600] loss : 0.042314
# [30,   400] loss : 0.041554
# [30,   800] loss : 0.039956
# [30,  1200] loss : 0.044111
# [30,  1600] loss : 0.041094
# [31,   400] loss : 0.042206
# [31,   800] loss : 0.039156
# [31,  1200] loss : 0.043005
# [31,  1600] loss : 0.041032
# [32,   400] loss : 0.040089
# [32,   800] loss : 0.039340
# [32,  1200] loss : 0.042904
# [32,  1600] loss : 0.039515
# [33,   400] loss : 0.039916
# [33,   800] loss : 0.037531
# [33,  1200] loss : 0.041691
# [33,  1600] loss : 0.039709
# [34,   400] loss : 0.039664
# [34,   800] loss : 0.036992
# [34,  1200] loss : 0.042296
# [34,  1600] loss : 0.039017
# [35,   400] loss : 0.039518
# [35,   800] loss : 0.036283
# [35,  1200] loss : 0.040175
# [35,  1600] loss : 0.039926
# [36,   400] loss : 0.038038
# [36,   800] loss : 0.035856
# [36,  1200] loss : 0.038711
# [36,  1600] loss : 0.037953
# [37,   400] loss : 0.036269
# [37,   800] loss : 0.034684
# [37,  1200] loss : 0.040609
# [37,  1600] loss : 0.040986
# [38,   400] loss : 0.037453
# [38,   800] loss : 0.034764
# [38,  1200] loss : 0.040373
# [38,  1600] loss : 0.036866
# [39,   400] loss : 0.035918
# [39,   800] loss : 0.034066
# [39,  1200] loss : 0.037233
# [39,  1600] loss : 0.035036
# [40,   400] loss : 0.034906
# [40,   800] loss : 0.033762
# [40,  1200] loss : 0.036894
# [40,  1600] loss : 0.049101
# [41,   400] loss : 0.045782
# [41,   800] loss : 0.035540
# [41,  1200] loss : 0.038236
# [41,  1600] loss : 0.036955
# [42,   400] loss : 0.034699
# [42,   800] loss : 0.032571
# [42,  1200] loss : 0.036063
# [42,  1600] loss : 0.034183
# [43,   400] loss : 0.033275
# [43,   800] loss : 0.031878
# [43,  1200] loss : 0.035018
# [43,  1600] loss : 0.033486
# [44,   400] loss : 0.045100
# [44,   800] loss : 0.041387
# [44,  1200] loss : 0.039065
# [44,  1600] loss : 0.035087
# [45,   400] loss : 0.034745
# [45,   800] loss : 0.032525
# [45,  1200] loss : 0.035437
# [45,  1600] loss : 0.033204
# [46,   400] loss : 0.032664
# [46,   800] loss : 0.031621
# [46,  1200] loss : 0.033382
# [46,  1600] loss : 0.031711
# [47,   400] loss : 0.031171
# [47,   800] loss : 0.031157
# [47,  1200] loss : 0.036960
# [47,  1600] loss : 0.038475
# [48,   400] loss : 0.035543
# [48,   800] loss : 0.032055
# [48,  1200] loss : 0.036024
# [48,  1600] loss : 0.032524
# [49,   400] loss : 0.031855
# [49,   800] loss : 0.030591
# [49,  1200] loss : 0.033356
# [49,  1600] loss : 0.031109
# [50,   400] loss : 0.030438
# [50,   800] loss : 0.029549
# [50,  1200] loss : 0.032410
# [50,  1600] loss : 0.030935
# [51,   400] loss : 0.039178
# [51,   800] loss : 0.034623
# [51,  1200] loss : 0.037131
# [51,  1600] loss : 0.035297
# [52,   400] loss : 0.032120
# [52,   800] loss : 0.031080
# [52,  1200] loss : 0.033891
# [52,  1600] loss : 0.032332
# [53,   400] loss : 0.030481
# [53,   800] loss : 0.029569
# [53,  1200] loss : 0.032088
# [53,  1600] loss : 0.030652
# [54,   400] loss : 0.029817
# [54,   800] loss : 0.028490
# [54,  1200] loss : 0.033206
# [54,  1600] loss : 0.041431
# [55,   400] loss : 0.033251
# [55,   800] loss : 0.033353
# [55,  1200] loss : 0.033143
# [55,  1600] loss : 0.033050
# [56,   400] loss : 0.031552
# [56,   800] loss : 0.029839
# [56,  1200] loss : 0.038422
# [56,  1600] loss : 0.033143
# [57,   400] loss : 0.032102
# [57,   800] loss : 0.030398
# [57,  1200] loss : 0.032587
# [57,  1600] loss : 0.030991
# [58,   400] loss : 0.029842
# [58,   800] loss : 0.028475
# [58,  1200] loss : 0.031890
# [58,  1600] loss : 0.032555
# [59,   400] loss : 0.035425
# [59,   800] loss : 0.031752
# [59,  1200] loss : 0.033737
# [59,  1600] loss : 0.037163
# [60,   400] loss : 0.030442
# [60,   800] loss : 0.029384
# [60,  1200] loss : 0.032678
# [60,  1600] loss : 0.032348
# [61,   400] loss : 0.030880
# [61,   800] loss : 0.034258
# [61,  1200] loss : 0.033284
# [61,  1600] loss : 0.032192
# [62,   400] loss : 0.030710
# [62,   800] loss : 0.030564
# [62,  1200] loss : 0.032055
# [62,  1600] loss : 0.032455
# [63,   400] loss : 0.032787
# [63,   800] loss : 0.035112
# [63,  1200] loss : 0.033338
# [63,  1600] loss : 0.033491
# [64,   400] loss : 0.030842
# [64,   800] loss : 0.030252
# [64,  1200] loss : 0.032307
# [64,  1600] loss : 0.031636
# [65,   400] loss : 0.030155
# [65,   800] loss : 0.029555
# [65,  1200] loss : 0.032966
# [65,  1600] loss : 0.034779
# [66,   400] loss : 0.034356
# [66,   800] loss : 0.030294
# [66,  1200] loss : 0.033109
# [66,  1600] loss : 0.035456
# [67,   400] loss : 0.031046
# [67,   800] loss : 0.029785
# [67,  1200] loss : 0.039288
# [67,  1600] loss : 0.032186
# [68,   400] loss : 0.030621
# [68,   800] loss : 0.029816
# [68,  1200] loss : 0.038217
# [68,  1600] loss : 0.031667
# [69,   400] loss : 0.030446
# [69,   800] loss : 0.029301
# [69,  1200] loss : 0.032832
# [69,  1600] loss : 0.031600
# [70,   400] loss : 0.029882
# [70,   800] loss : 0.030980
# [70,  1200] loss : 0.033251
# [70,  1600] loss : 0.031689
# [71,   400] loss : 0.029582
# [71,   800] loss : 0.029291
# [71,  1200] loss : 0.032137
# [71,  1600] loss : 0.034594
# [72,   400] loss : 0.032235
# [72,   800] loss : 0.029459
# [72,  1200] loss : 0.031888
# [72,  1600] loss : 0.031997
# [73,   400] loss : 0.030082
# [73,   800] loss : 0.031713
# [73,  1200] loss : 0.031839
# [73,  1600] loss : 0.031907
# [74,   400] loss : 0.029840
# [74,   800] loss : 0.029207
# [74,  1200] loss : 0.032636
# [74,  1600] loss : 0.031053
# [75,   400] loss : 0.029339
# [75,   800] loss : 0.033163
# [75,  1200] loss : 0.035590
# [75,  1600] loss : 0.031357
# [76,   400] loss : 0.029805
# [76,   800] loss : 0.034214
# [76,  1200] loss : 0.032595
# [76,  1600] loss : 0.030904
# [77,   400] loss : 0.029842
# [77,   800] loss : 0.029207
# [77,  1200] loss : 0.032099
# [77,  1600] loss : 0.031676
# [78,   400] loss : 0.029586
# [78,   800] loss : 0.036117
# [78,  1200] loss : 0.034399
# [78,  1600] loss : 0.030633
# [79,   400] loss : 0.030748
# [79,   800] loss : 0.031703
# [79,  1200] loss : 0.033091
# [79,  1600] loss : 0.031641
# [80,   400] loss : 0.031393
# [80,   800] loss : 0.031498
# [80,  1200] loss : 0.032286
# [80,  1600] loss : 0.029948
# [81,   400] loss : 0.029807
# [81,   800] loss : 0.028674
# [81,  1200] loss : 0.032349
# [81,  1600] loss : 0.031238
# [82,   400] loss : 0.029783
# [82,   800] loss : 0.028762
# [82,  1200] loss : 0.031571
# [82,  1600] loss : 0.029891
# [83,   400] loss : 0.031422
# [83,   800] loss : 0.034221
# [83,  1200] loss : 0.032172
# [83,  1600] loss : 0.029980
# [84,   400] loss : 0.033156
# [84,   800] loss : 0.029625
# [84,  1200] loss : 0.032440
# [84,  1600] loss : 0.029682
# [85,   400] loss : 0.032187
# [85,   800] loss : 0.028531
# [85,  1200] loss : 0.031422
# [85,  1600] loss : 0.036894
# [86,   400] loss : 0.029804
# [86,   800] loss : 0.034251
# [86,  1200] loss : 0.038323
# [86,  1600] loss : 0.029308
# [87,   400] loss : 0.029588
# [87,   800] loss : 0.030181
# [87,  1200] loss : 0.031032
# [87,  1600] loss : 0.029508
# [88,   400] loss : 0.028760
# [88,   800] loss : 0.034964
# [88,  1200] loss : 0.031889
# [88,  1600] loss : 0.033923
# [89,   400] loss : 0.028724
# [89,   800] loss : 0.028112
# [89,  1200] loss : 0.030445
# [89,  1600] loss : 0.029991
# [90,   400] loss : 0.030819
# [90,   800] loss : 0.031796
# [90,  1200] loss : 0.031194
# [90,  1600] loss : 0.030973
# [91,   400] loss : 0.029118
# [91,   800] loss : 0.028658
# [91,  1200] loss : 0.030670
# [91,  1600] loss : 0.029592
# [92,   400] loss : 0.028692
# [92,   800] loss : 0.028854
# [92,  1200] loss : 0.030475
# [92,  1600] loss : 0.033420
# [93,   400] loss : 0.032372
# [93,   800] loss : 0.031813
# [93,  1200] loss : 0.031170
# [93,  1600] loss : 0.029384
# [94,   400] loss : 0.028590
# [94,   800] loss : 0.027667
# [94,  1200] loss : 0.031159
# [94,  1600] loss : 0.029115
# [95,   400] loss : 0.036807
# [95,   800] loss : 0.028329
# [95,  1200] loss : 0.030809
# [95,  1600] loss : 0.029235
# [96,   400] loss : 0.028614
# [96,   800] loss : 0.027734
# [96,  1200] loss : 0.030051
# [96,  1600] loss : 0.032219
# [97,   400] loss : 0.029358
# [97,   800] loss : 0.028163
# [97,  1200] loss : 0.030437
# [97,  1600] loss : 0.031103
# [98,   400] loss : 0.027812
# [98,   800] loss : 0.029777
# [98,  1200] loss : 0.029709
# [98,  1600] loss : 0.030694
# [99,   400] loss : 0.029054
# [99,   800] loss : 0.028516
# [99,  1200] loss : 0.030150
# [99,  1600] loss : 0.030203
# [100,   400] loss : 0.031049
# [100,   800] loss : 0.027386
# [100,  1200] loss : 0.030088
# [100,  1600] loss : 0.028887
# The lowest was:  0.0007289509521797299
# Finished Training

# %%
#Print only the output images
def show_output_images(outputs):
    
    fig = plt.figure(figsize = (20, 14))
    rows = 4
    columns = 4
    j=0
    for i in range(1,columns*rows+1):
        #Denoising
        if i >= 1 and i < 5:
            fig.add_subplot(rows, columns, i)
            plt.imshow(outputs[0][i].cpu().detach().numpy().reshape(14,14), cmap='gray')
        
        #Upsampling
        if i >= 5 and i < 9:
            fig.add_subplot(rows, columns, i)
            plt.imshow(outputs[1][i-4].cpu().detach().numpy().reshape(28,28), cmap='gray')
        
        #Disambiguation
        if i >= 9 and i< 13:
            fig.add_subplot(rows, columns, i)
            plt.imshow(outputs[2][i-8][:784].cpu().detach().numpy().reshape(28,28), cmap='gray')
        if i >= 13 and i< 17:
            fig.add_subplot(rows, columns, i)
            plt.imshow(outputs[2][i-12][784:].cpu().detach().numpy().reshape(28,28), cmap='gray')

# %%
show_output_images(output)

# %%
#Print only the input images
def show_input_images(inputs):
    
    fig = plt.figure(figsize = (20, 14))
    rows = 5
    columns = 4
    j=0
    for i in range(1,columns*rows+1):
        # Denoising
        if i >=1 and i< 5:
            fig.add_subplot(rows, columns, i)
            plt.imshow(data[0][i].cpu().detach().numpy().reshape(14,14), cmap='gray')
            
        #Upsampling
        if i >=5 and i< 9:
            fig.add_subplot(rows, columns, i)
            plt.imshow(data[1][0][i-4].cpu().detach().numpy().reshape(14,14), cmap='gray')
            
        #Disambiguation
        if i >= 9 and i < 13:
            fig.add_subplot(rows, columns, i)
            plt.imshow(data[1][1][i-8].cpu().detach().numpy().reshape(28,28), cmap='gray')
        
        if i >= 13 and i < 17:
            fig.add_subplot(rows, columns, i)
            plt.imshow(data[1][2][i-12].cpu().detach().numpy().reshape(28,28), cmap='gray')
        
        if i >= 17 and i < 21:
            fig.add_subplot(rows, columns, i)
            plt.imshow(data[1][3][i-16].cpu().detach().numpy().reshape(28,28), cmap='gray')

# %%
show_input_images(inputs=data)

# %%
testing_superimposed = MNISTsuperimposed("./MNIST data/train", train = False, download = True, transform = transform, target_transform=target_transform)
testset = DataLoader(testing_superimposed, batch_size=128, shuffle = False)
outputs, test_data, test_loss = train_test(AEnet, testset, False)
# Out:
# [   10] loss per image: 0.007497
# [   20] loss per image: 0.007630
# [   30] loss per image: 0.007690
# [   40] loss per image: 0.007855
# [   50] loss per image: 0.007865
# [   60] loss per image: 0.007503
# [   70] loss per image: 0.007818
# The lowest was:  0.007331967353820801
# Finished Testing

# %%
print(outputs[0][1].shape)
# Out:
# torch.Size([1, 14, 14])

# %%
show_output_images(outputs)

# %%
show_input_images(test_data)

# %% [markdown]
# ## Loss Plots

# %%
def plot_loss(loss, Training = True):
    fig = plt.figure(figsize = (10, 7))
    
    if Training == True:
        x = list(np.arange(0.0, 100.0, 0.25))
        plt.axis("on")
        plt.ylabel('Loss')
        plt.xlabel('Epoch')
        plt.title("Training Loss")
        plt.plot(x, loss)
    else:
        x = list(range(0, 7, 1))
        plt.axis("on")
        plt.ylabel('Loss')
        plt.xlabel('Epoch')
        plt.title("Test Loss")
        plt.plot(x, loss)

# %%
plot_loss(training_loss)

# %%
plot_loss(test_loss, False)
